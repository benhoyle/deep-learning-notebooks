# %% [markdown]
# This code is adapted from the Keras tutorial on using pre-trained word embeddings.

# %%
'''
GloVe embedding data can be found at:
http://nlp.stanford.edu/data/glove.6B.zip
(source page: http://nlp.stanford.edu/projects/glove/)

'''

import os
import sys
import numpy as np
import pickle
import random

from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Dense, Input, Flatten
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.models import Model

from patentdata.corpus import USPublications
# Probably need to move the patentcorpus.py file into the main patentdata directory
from patentdata.models.patentcorpus import LazyPatentCorpus

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Questions:
# - What is our maximum word length? This becomes our maximum sequence length.
# *English words max out at around 30 characters with most words (95%+) being less than 15 in length.*
# - How many words in a typical set of (patent) documents are out of dictionary?

# %% [markdown]
# So currently most word embedding takes a one-hot vector or dictionary index of a word and converts it into an n-dimensional vector (where n=50-300).
#
# One issue with this technique is out of dictionary or rare words. Sometimes these are typos. Sometimes they contain information.
#
# One question is can we output our word embeddings as the end hidden state of an RNN? This appears similar to the charLSTM described here: https://aclweb.org/anthology/D16-1157 .

# %%
BASE_DIR = ''
GLOVE_DIR = BASE_DIR + 'glove.6B/'

# %% [markdown]
# We will start with the smallest GloVe vector (50d) and work up to larger dimensions as we test.

# %%
# first, build index mapping words in the embeddings set
# to their embedding vector

print('Indexing word vectors.')

embeddings_index = {}
f = open(os.path.join(GLOVE_DIR, 'glove.6B.50d.txt'), 'rb') # Added 'rb' for Python 3
for line in f:
    values = line.decode('utf-8').split() # Added decode for Python 3
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Indexing word vectors.
# Found 400000 word vectors.

# %%
embeddings_index['the']
# Out:
# array([  4.18000013e-01,   2.49679998e-01,  -4.12420005e-01,
#          1.21699996e-01,   3.45270008e-01,  -4.44569997e-02,
#         -4.96879995e-01,  -1.78619996e-01,  -6.60229998e-04,
#         -6.56599998e-01,   2.78430015e-01,  -1.47670001e-01,
#         -5.56770027e-01,   1.46579996e-01,  -9.50950012e-03,
#          1.16579998e-02,   1.02040000e-01,  -1.27920002e-01,
#         -8.44299972e-01,  -1.21809997e-01,  -1.68009996e-02,
#         -3.32789987e-01,  -1.55200005e-01,  -2.31309995e-01,
#         -1.91809997e-01,  -1.88230002e+00,  -7.67459989e-01,
#          9.90509987e-02,  -4.21249986e-01,  -1.95260003e-01,
#          4.00710011e+00,  -1.85939997e-01,  -5.22870004e-01,
#         -3.16810012e-01,   5.92130003e-04,   7.44489999e-03,
#          1.77780002e-01,  -1.58969998e-01,   1.20409997e-02,
#         -5.42230010e-02,  -2.98709989e-01,  -1.57490000e-01,
#         -3.47579986e-01,  -4.56370004e-02,  -4.42510009e-01,
#          1.87849998e-01,   2.78489990e-03,  -1.84110001e-01,
#         -1.15139998e-01,  -7.85809994e-01], dtype=float32)

# %%
list(embeddings_index.keys())[0:100]
# Out:
# ['pierotti',
#  'thie',
#  'glenda',
#  'cohocton',
#  '1985-1993',
#  'lavazza',
#  'eliatamby',
#  'sabarno',
#  'mohammadpur',
#  'zuria',
#  'cted',
#  'co-ruler',
#  'rebelling',
#  'duma',
#  'hajia',
#  'kryszalowicz',
#  'camiones',
#  'atlanta-based',
#  'silvermane',
#  'flügge',
#  'basica',
#  'remek',
#  'physiatrists',
#  'auvsi',
#  'kulthum',
#  '1879',
#  'tawang',
#  'darvill',
#  'potsdamer',
#  'sitte',
#  'fonthill',
#  'stf',
#  'kawaihae',
#  'nbc',
#  'biocompatible',
#  'interwar',
#  'riversharks',
#  'breds',
#  '64.22',
#  'rvs',
#  'best-of-five',
#  'djordje',
#  'kagetora',
#  'arisa',
#  'musala',
#  'kaklamanakis',
#  'tartt',
#  'tchicaya',
#  'byte',
#  'bayou',
#  'intuitiveness',
#  'edis',
#  'female-only',
#  'walternate',
#  'pasteurized',
#  'feare',
#  'murambi',
#  '1865',
#  '27,250',
#  'tracings',
#  'ndt',
#  'jetmaker',
#  'eponyms',
#  'bielawy',
#  'aufdenblatten',
#  'dumaine',
#  'tsakonian',
#  'doyle-murray',
#  'cubbie',
#  'resubmitting',
#  'ivanovitch',
#  'hieber',
#  '38,900',
#  'community-level',
#  'okuyama',
#  'kukla',
#  'elabed',
#  'non-unionized',
#  '0-for-8',
#  'ryszard',
#  'festinger',
#  'c-130h',
#  'coley',
#  'myszków',
#  'searles',
#  'hypochlorite',
#  'bielefeld',
#  'motivation',
#  'tikva',
#  'firmin',
#  'camerer',
#  'arregui',
#  'nocenti',
#  '67.80',
#  'batting_lwalker',
#  'aana',
#  'segen',
#  'gracile',
#  'billvirginseattlepi.com',
#  'solveig']

# %% [markdown]
# Embeddings are all lower case. In this list of 100, most are not relevant. It would be interesting to see how many patent words are in the dictionary and how many out of dictionary terms we have. We may want to generate a patent-specific set of embeddings.

# %%
# Load our list of G06 records
PIK = "G06records.data"

if os.path.isfile(PIK):
    with open(PIK, "rb") as f:
        print("Loading data")
        records = pickle.load(f)
        print("{0} records loaded".format(len(records)))
else:
    records = ds.get_records(["G", "06"])
    with open(PIK, "wb") as f:
        pickle.dump(records, f)
        
# Get data from 100 random records across the data
records_random_sample = random.sample(records, 100)
print("Random sample of {0} records".format(len(records_random_sample)))
print(records_random_sample[0:5])

# Initialise datasource that lazily loads the document data
path = '/media/SAMSUNG1/Patent_Downloads'
ds = USPublications(path)

lzy = LazyPatentCorpus()
lzy.init_by_filenames(ds, records_random_sample)
# Out:
# Loading data
# 554570 records loaded
# Random sample of 100 records
# [(2530564, '2010/I20100923.ZIP', 'project/pdds/ICEApplication/I20100923/UTIL0242/US20100242046A1-20100923.ZIP'), (2775521, '2011/I20110623.tar', 'I20110623/UTIL0153/US20110153778A1-20110623.ZIP'), (1946766, '2008/I20081211.ZIP', 'project/pdds/ICEApplication/I20081211/UTIL0307/US20080307084A1-20081211.ZIP'), (2840466, '2011/I20110908.tar', 'I20110908/UTIL0218/US20110218704A1-20110908.ZIP'), (2601001, '2010/I20101209.tar', 'I20101209/UTIL0312/US20100312484A1-20101209.ZIP')]

# %%
# See if we have a saved copy of stats for 10,000 records else create it
# Note stats may be for a different set of 10,000 records
filename = "first10kg06.pkl"

if os.path.isfile(filename):
    with open(filename, "rb") as f:
        print("Loading data")
        stats = pickle.load(f)
        print("Stats loaded")
else:
    stats = lzy.get_statistics()
    with open(filename, "wb") as f:
        pickle.dump(stats, f)
# Out:
# Loading data
# Stats loaded

# %% [markdown]
# Can get an unfiltered token dictionary as first item in lzy.get_statistics() (unfiltered_vocabulary).
#
# This will have a mixture of upper and lower case. We can thus post process to combine upper and lower case entries.

# %%
def lowerise(counter_in):
    """ Convert a term counter in mixed case to a counter in lower case.
        Combine any entries that are the same after removing case.
    """
    filtered_counter = Counter()
    for i, token in enumerate(counter_in.keys()):
        if token.lower() in filtered_counter.keys():
            filtered_counter[token.lower()] += counter_in[token]
        else:
            filtered_counter[token.lower()] = counter_in[token]
        if (i%100) == 0:
            logging.info("Processing {0}th token - {1}".format(i, token))
    return filtered_counter

# %%
from collections import Counter
test_list = ['a', 'a', 'a', 'b', 'b', 'c', 'A', 'A', 'C']
c = Counter(test_list)
print(c)
c2 = lowerise(c)
print(c2)
# Out:
# Counter({'a': 3, 'A': 2, 'b': 2, 'C': 1, 'c': 1})
# Counter({'a': 5, 'b': 2, 'c': 2})

# %%
stats[0]
# Out:
# Counter({'communize': 2,
#          'maintenance/check': 1,
#          '1,108,125': 2,
#          'S1218': 12,
#          'ADF': 123,
#          'Mixer/amplifier': 1,
#          'L2V0F2': 2,
#          '35.489': 1,
#          '72.884': 1,
#          '5,987,425': 1,
#          'DoseIndex_For_Case_xxx': 2,
#          '8.52': 1,
#          'fiis': 1,
#          '230B': 57,
#          'cted': 1,
#          'siganalname3': 1,
#          'media/transport': 4,
#          'tobe': 4,
#          'Korfmacher': 2,
#          '0k': 3,
#          'FrameOvf': 1,
#          'operation/processing': 1,
#          '60/265,875': 1,
#          '1879': 13,
#          'positioners': 34,
#          'ST826': 1,
#          'IWBWrap1': 2,
#          '1/RC': 1,
#          '09/327,966': 2,
#          'nanoprocessors': 4,
#          'Subscriptions': 21,
#          'old_posM1': 1,
#          'row-pulse': 2,
#          'pricelist': 2,
#          'Cherokee': 5,
#          'codeCWC001.class': 1,
#          'same-direction': 1,
#          'Characters': 94,
#          '13X.XXX.2.13': 1,
#          '49.607': 2,
#          "billers'statements": 1,
#          'causal-based': 1,
#          'WebForce': 1,
#          '31.600': 2,
#          'UpKUF': 1,
#          'Pv3P3': 1,
#          'Heatpipes': 1,
#          'byte': 7792,
#          'intuitiveness': 2,
#          '648b': 1,
#          'DynamicDataVersion': 7,
#          '4.7E21': 2,
#          '3.fpx': 4,
#          'AUTOMATIC': 42,
#          '1865': 15,
#          'In-Patient': 5,
#          'CawE': 1,
#          'f1B': 1,
#          'tracings': 3,
#          '34,790': 5,
#          'Dots': 16,
#          'plural-bit': 37,
#          'frame/header': 7,
#          '34.6wks': 2,
#          '306-1': 1,
#          'WINT1': 2,
#          '2013.9812': 1,
#          'AA1/p': 1,
#          'H11-34145': 1,
#          'OCTP': 2,
#          'Gwinn': 1,
#          '3068': 4,
#          ':1009-22': 1,
#          'resubmitting': 14,
#          'blast-pressure': 2,
#          'NT/Windows': 2,
#          'U5U0': 1,
#          'Media-specific': 1,
#          'DriverControl': 4,
#          'microproccessor': 1,
#          'BCS': 26,
#          'ERROR_ALREADY_EXISTS': 2,
#          'logoff': 36,
#          '09/481,477': 1,
#          'Cylinder': 55,
#          '14-4b': 1,
#          '5A-6F': 6,
#          'METER': 22,
#          'RIPEMD-160': 3,
#          'CB111': 1,
#          'mail_queue': 14,
#          '1IGT': 8,
#          '98273028763-32954-19990714024528265': 1,
#          'POWERED': 4,
#          '460a-f': 6,
#          'GE-21': 1,
#          'S2ad22bd2c': 1,
#          '69.475': 1,
#          'remove_file': 1,
#          'outD': 6,
#          'puppies': 2,
#          'IN101': 2,
#          '2-field': 1,
#          'Cooktop': 32,
#          'point-pressing': 1,
#          '60/217,182': 1,
#          'multimodem': 1,
#          'intense': 86,
#          'S32-017': 3,
#          'SAMBA': 38,
#          'ZeroPort': 1,
#          'xxRadioNetwork': 1,
#          'c1e': 2,
#          'ions/cm3': 1,
#          '5,999,318': 1,
#          'legband': 1,
#          'processing/display': 1,
#          'g2A1f2': 7,
#          'SNMP_bridge_poller': 1,
#          'Last/': 1,
#          '5-pin': 1,
#          '1.096': 1,
#          'on-train': 1,
#          'insolvable': 2,
#          'n-context': 1,
#          'cilium': 81,
#          'ask/receive': 1,
#          '410g': 1,
#          'Display-shared': 3,
#          'Reglementierung': 1,
#          '157-158': 1,
#          'EC2': 53,
#          'g-number': 1,
#          '41.423': 1,
#          '3.91': 1,
#          'Globally': 32,
#          'CarPoint': 1,
#          'Raffles': 1,
#          'server-class': 2,
#          '60/018,921': 2,
#          'Len5': 3,
#          '6180': 4,
#          'recent-type': 1,
#          'ORCL4045MCF/SES': 1,
#          'fault-diagnosing': 2,
#          'SUMDIF1': 6,
#          'ECX': 7,
#          '76.354': 1,
#          '10-080982': 1,
#          'D16': 135,
#          'Timestamp-Master': 1,
#          'IDD_D_GOTO': 3,
#          'Pythagorean': 7,
#          '2000-78125': 1,
#          'ZrO2': 1,
#          'ecosystems': 7,
#          'sub-environments': 12,
#          'FSW': 147,
#          '36.CHAT_FILE': 2,
#          'KAB-space': 1,
#          'P18': 35,
#          '-removing': 1,
#          'y_org': 2,
#          'ADIWWW.MUSIK.COM': 2,
#          'countertop': 43,
#          'ALU.Forwarding': 2,
#          'collision-related': 1,
#          'multi-faceted': 11,
#          'USOUT': 2,
#          'H6-95302': 1,
#          'DLLF0': 11,
#          '0/1/2/3-bit': 3,
#          'pCppEnv_': 1,
#          'paradoxical': 2,
#          'Regulates': 1,
#          'CurrentLocation': 10,
#          'lifestyle': 226,
#          'Pei': 6,
#          'tD2tD1': 1,
#          'process/methodology': 1,
#          'debt-balance': 2,
#          '51.51': 2,
#          'ST112': 12,
#          'ingredients/nutrition': 5,
#          'gmax': 19,
#          'Hei-6-28459': 2,
#          'web-site/portal': 1,
#          'smartLinks': 3,
#          'fixed-end': 2,
#          'academic/technology': 1,
#          'DCW': 11,
#          '73-74-069': 1,
#          '712g': 2,
#          'ScoringCompleted': 1,
#          'state2': 2,
#          'TI111': 12,
#          'kbit/s': 19,
#          '34:15291-15300': 1,
#          '01-02-35-67/00': 1,
#          'DIAGNOSES': 1,
#          '31.169': 2,
#          'producttheir': 1,
#          '83.998': 1,
#          'Putzolu': 1,
#          'Halide': 1,
#          '116a-c': 12,
#          'Offer-managing': 2,
#          'idea/intellectual': 2,
#          '13102': 1,
#          'RulesAllows': 1,
#          '144144': 13,
#          'regionThe': 1,
#          'non-SET': 1,
#          'hix': 1,
#          '5,706,813': 1,
#          'fonts/styles': 1,
#          'multi-panel': 4,
#          'PCWorld': 1,
#          'palpating': 4,
#          'X3,2': 1,
#          'retrograde': 3,
#          'disengageable': 2,
#          'Pakistan': 2,
#          'Elektron': 1,
#          '//fixed': 2,
#          '165-175': 1,
#          '36*': 1,
#          '7-146854': 1,
#          'MODULE_NANESx,0': 1,
#          'mark/sweep': 6,
#          '2-amino-5-iodoacetamido-pentanoic': 1,
#          'id': 1555,
#          'SC3': 32,
#          'chartered': 10,
#          '132-137': 1,
#          'dome-like': 2,
#          'entry/integration': 1,
#          'ZFF1': 1,
#          '8281': 6,
#          '6001b': 2,
#          's01': 15,
#          '18.551': 1,
#          '2.0pFNo.': 2,
#          'ten-count': 2,
#          'RC12': 3,
#          '11.368': 2,
#          '1.NC': 2,
#          'b0.clkclock': 2,
#          'Deedshares': 1,
#          'EVATTR_PATTERN1': 5,
#          'N-dimensions': 1,
#          '38.434': 1,
#          'awaits': 247,
#          'a4b4': 1,
#          '28.52': 2,
#          'widened': 89,
#          'knowledge/organization': 20,
#          'http-equivCache-Control': 2,
#          'system/asynchronous': 1,
#          'triparty': 1,
#          'disc-changer': 1,
#          'iraq': 54,
#          'limitationHDDs': 1,
#          'debugConditionsNode': 2,
#          'etiologies': 2,
#          'HKEY_CLASSES_ROOTFileTypes': 1,
#          '2.067243': 1,
#          'confounds': 2,
#          'Strict-Z': 1,
#          'seattleintairport.com': 1,
#          'RR-93-03': 1,
#          '0XXX': 1,
#          'interface/adaptor': 2,
#          '40.7526': 1,
#          'Pre-scalers': 5,
#          '82.31072': 1,
#          'Xq0': 2,
#          'Seeds': 5,
#          '124.833': 1,
#          'Human/Computer': 3,
#          'Wylie': 3,
#          'transactionThe': 1,
#          'whitelight': 1,
#          'LDAP.version': 1,
#          'non-published': 2,
#          'trestle': 2,
#          '391-1b': 1,
#          '15-N': 8,
#          '09/441,819': 1,
#          'broadcast-program-listing': 25,
#          'TD_REVERSE': 1,
#          '21.221': 2,
#          'pluralized': 8,
#          'BN7': 2,
#          'OpCodes': 1,
#          'GR-1248-CORE': 7,
#          'Annunciator': 41,
#          'J73-D-I': 1,
#          'libraryId': 2,
#          'AS': 569,
#          'sampler': 207,
#          'HS_L': 1,
#          '532such': 1,
#          'edu.sg': 1,
#          'ciSi*': 1,
#          '5A-D.': 3,
#          'Cd2': 2,
#          'OPTIMUM': 2,
#          '1-write': 1,
#          'p0.01': 6,
#          'GeneralNames': 1,
#          'Merchant-Text-2': 4,
#          '0.680552': 1,
#          '57.0': 3,
#          '1D3G': 3,
#          'Kestrel': 2,
#          'cooker': 12,
#          'Surgery': 36,
#          'Cradle': 12,
#          'length30': 1,
#          'lastly': 86,
#          '5052-5232': 4,
#          'configuration/improvement': 1,
#          'BUD': 2,
#          'Obj1-Obj5': 1,
#          'checksamong': 1,
#          'NSAPI': 15,
#          'Strand': 11,
#          'TUT_ERR_LOD_NO_COACHTOPICS_FOUND': 3,
#          'sub-interface': 7,
#          'card': 71245,
#          'suggested/described': 1,
#          'CMD_SETDATATYPEThis': 1,
#          'user.location.building': 4,
#          'probationary': 7,
#          'elementID.className': 1,
#          'Reagent': 10,
#          '0.3187b': 1,
#          'neko1.gif': 1,
#          'FIELD_ID': 1,
#          'memorialization': 5,
#          'S61-3': 2,
#          'display-causing': 4,
#          '102.9': 2,
#          'intensity/chroma': 1,
#          'non-PartitionNone': 1,
#          'gfu_sethi': 1,
#          'well-depth': 2,
#          'group-B': 1,
#          'program*/': 1,
#          '21.48': 1,
#          'problem-independent': 1,
#          'Corporate/Global': 1,
#          '13A1/A3': 4,
#          'submitForm': 2,
#          'geodemographics': 1,
#          'faxmachinen36': 1,
#          'error-detection': 14,
#          'Bosacchi': 1,
#          'OutX2': 1,
#          '13.248': 1,
#          'sor': 1,
#          '/210': 1,
#          'Hq': 3,
#          'NameEXE_DIRwinword.exe': 1,
#          '163Bh': 2,
#          'ValidDate': 2,
#          'OUT7': 5,
#          '2000-147760': 1,
#          'C2*Att_pol*Att_pol': 1,
#          'website/page': 1,
#          'SF01': 14,
#          'MIDIOutOpen': 4,
#          '22.424': 2,
#          '5081-n': 3,
#          '790103': 1,
#          'IMAP4': 57,
#          'NhNv': 2,
#          'OkPk1': 2,
#          'monetizable': 1,
#          'application/pdf': 1,
#          'height30': 3,
#          'supervisor': 1010,
#          'CIF2': 3,
#          'crystal-based': 1,
#          'effect/functions': 1,
#          'sub-routing': 1,
#          '8-76885': 1,
#          'trianglel': 1,
#          'Bitmap/Untagged': 1,
#          'PENTIUM-based': 3,
#          'clipc': 1,
#          'posted': 2210,
#          'rrwIf': 1,
#          'Competitive': 52,
#          'Counterfeits': 1,
#          '2.192063': 1,
#          'Shoukoudou': 1,
#          'ninety-six': 3,
#          'furniture': 295,
#          '2/27/01': 2,
#          '68.3378': 1,
#          'Premix': 1,
#          'vvertex': 3,
#          'edge-long': 1,
#          '/SourceLocation': 2,
#          'preview-displayed': 1,
#          '87.931': 1,
#          'CS12': 5,
#          '18.385': 1,
#          '365-2-1': 2,
#          'MESH': 2,
#          '964B': 1,
#          '4-7a': 1,
#          '15.713': 2,
#          'Nobuyoshi': 1,
#          'graphic-image-data': 2,
#          '69.3': 1,
#          '78.039': 2,
#          'analyzedRocket': 1,
#          'T1-T2': 8,
#          'bartered': 73,
#          '1.9,19': 1,
#          '52.814': 2,
#          '42.040': 2,
#          'A13O2HbiB13RHbiC13COHbi13mi': 1,
#          '3176': 5,
#          '-max': 2,
#          'Airpot': 1,
#          '09/698,471': 3,
#          't5-2': 2,
#          'Predict/DLI': 2,
#          'assetsnot': 1,
#          'pacific': 5,
#          'date-': 10,
#          'Symbol-rate': 1,
#          'notifications/objects': 3,
#          'purchase-buying': 1,
#          'VNB': 24,
#          '58.110': 1,
#          'utilitiy': 1,
#          '/wavelength': 1,
#          'answer-back': 1,
#          'current_start': 1,
#          'DataBroadcastPkts': 2,
#          'abcvsmainvimx.h': 1,
#          'Actionargs': 2,
#          'change/evolve': 1,
#          'Active-List': 2,
#          'AE19': 2,
#          '721a': 4,
#          '*loop': 1,
#          'via-magazine': 16,
#          'at-which': 1,
#          'Avg2delta2': 2,
#          'Ps1n': 6,
#          'payback': 118,
#          'powers-up': 3,
#          '5,913,210': 1,
#          'non-sloping': 6,
#          'FI-1': 6,
#          'Structured-Document': 2,
#          'GPAs': 6,
#          'OUTOF-ORDER': 1,
#          'ORDERLINE_SUM': 1,
#          'entry-like': 4,
#          'S018': 5,
#          'WSi': 1,
#          'Reassembly': 13,
#          'ClickMe': 2,
#          '696D': 1,
#          'COVERAGE_AREA': 2,
#          'Direct-Talk': 1,
#          'litre': 7,
#          'VoiceXMLetc': 1,
#          'near-ubiquity': 1,
#          'management/oversight': 1,
#          '000000b': 1,
#          '1zaa': 8,
#          'BBS': 207,
#          'other/additional': 3,
#          'methylphenylcyclotetrasiloxane': 1,
#          'Gazoshori': 1,
#          'interactor-state': 2,
#          'xx30': 1,
#          'Messmer': 2,
#          '89/10651': 1,
#          'reply3': 1,
#          'rt1': 2,
#          '550A': 11,
#          '55.024': 2,
#          '0111999': 1,
#          'net-listed': 2,
#          '27.020': 5,
#          '91.796': 2,
#          'saturate/minimum': 1,
#          'LEDDescriptor': 1,
#          'D71': 17,
#          'COL1': 8,
#          'recursiveness': 1,
#          'WPV': 8,
#          'Radiographing': 2,
#          'e-h': 2,
#          'Raj': 1,
#          'CIELAB': 26,
#          'circuit1001': 1,
#          'AeTransportSend': 6,
#          'Chosakai': 2,
#          '17.299': 2,
#          'knowledge/information': 1,
#          'a_excesst_bbone.t_fldlist': 1,
#          'reconfigurable': 615,
#          'TXM0': 1,
#          'RTEV2': 1,
#          'GetReply': 2,
#          'Proceeded': 2,
#          'XX1': 11,
#          'SolveFor': 3,
#          'AN1tN1hN1': 5,
#          'non-redirected': 1,
#          'insatiable': 4,
#          '023FFxxEB': 1,
#          '14.3.1': 2,
#          'halibot': 2,
#          'emcodingiso-8859-1': 1,
#          'DES': 265,
#          'far-near': 2,
#          'quantity-adjusted': 3,
#          '1538': 34,
#          'Ytrans': 2,
#          'ISS-brand': 1,
#          'Scheduled-Discount': 7,
#          'deblocking': 6,
#          '15-50': 1,
#          'Delete-All': 5,
#          '8.44ASAap31.4ASApol': 1,
#          'rejecting/unloading': 1,
#          'defmes': 1,
#          'B_Xz': 1,
#          'REFcos': 1,
#          '52.024': 1,
#          'user-MIPS': 1,
#          'display/start': 4,
#          '1547.12': 1,
#          'transaction-approval-information': 1,
#          'Q6': 72,
#          'code-violation': 1,
#          'PBAREPLACEMENT': 2,
#          'temp12': 2,
#          'function/use': 1,
#          'SJ15': 4,
#          'To0': 6,
#          'DI': 258,
#          '60/189,893': 1,
#          '825a': 1,
#          'site-licensed': 4,
#          'embrittling': 1,
#          '/Dvb': 1,
#          'Authorize.net': 7,
#          'blindness': 29,
#          'EDVAC': 1,
#          'handbooks': 8,
#          '16.126': 1,
#          'PAPB': 2,
#          'MSbytes': 1,
#          '413from': 1,
#          'subsidizes': 4,
#          'z102.4': 1,
#          're-assembly': 7,
#          'Satoru': 1,
#          'Corning': 6,
#          'light-wave': 2,
#          'S58-8': 2,
#          '76d-76j': 1,
#          'Bordeaux': 2,
#          'very-low-order-rate': 62,
#          'wavelength': 1378,
#          'Affiliate-referred': 1,
#          'WebTek.com': 1,
#          'Interface': 4439,
#          'DAQs': 28,
#          'Open/single': 1,
#          'diag_dcfg1:0': 1,
#          'SHRAM': 1,
#          'Atmospheric': 11,
#          'Server-to-ClientInvalid': 1,
#          'TRANS': 6,
#          'UNICASTa': 1,
#          'MTr': 1,
#          'STLIN': 2,
#          'Polynucleotides': 1,
#          'setTextSize': 2,
#          'ticksleftthe': 1,
#          'slot/8.00': 1,
#          '60/187,137': 1,
#          'MAP/': 1,
#          '08/828,368': 1,
#          'II.5': 2,
#          'recvfrom': 1,
#          'pattern-reading': 1,
#          'alt-clicking': 1,
#          'predefined': 5054,
#          '00001111': 8,
#          'AER': 1,
#          '0000115200198': 1,
#          'nint': 1,
#          'dlg.m_3_COMP1:0': 1,
#          'UnRegister': 3,
#          'high-interest': 1,
#          '118.1': 4,
#          'SIID': 9,
#          'PRIN12': 1,
#          '12806': 1,
#          'fortify': 1,
#          'C03Cgs': 1,
#          'VLT': 6,
#          'regresses': 1,
#          'smokes': 15,
#          'WRITE-BEHIND': 2,
#          'pragma': 30,
#          'ioctl': 14,
#          'instancefor': 1,
#          'r.p.m': 9,
#          'Meatloaf': 9,
#          'ECWUHVQ': 1,
#          '/m100': 1,
#          'DREG1-n': 2,
#          'Tblock': 1,
#          'typelib_TypeDescriptionReference': 4,
#          'LFdLiquidity': 1,
#          'WM_CHAR': 1,
#          'eighty-ninth': 1,
#          'Base2': 1,
#          'IDC_E_PEL_SURG_DATE4': 1,
#          'Modernly': 1,
#          'depen-': 4,
#          'Pre-cured': 1,
#          'non-vulcanized': 1,
#          'cancelFilter': 1,
#          'two-phased': 1,
#          'residental': 1,
#          '26108': 2,
#          'portZ': 4,
#          'non-ionic': 4,
#          'in-housing': 1,
#          'mSetUp,2400,10,0': 3,
#          'VDR_INFO': 1,
#          'paraphrased': 2,
#          "Jun'ichiro": 1,
#          '169-177': 1,
#          'JM2': 9,
#          '11-355386': 1,
#          'HostsApplication': 1,
#          'lockup': 100,
#          'turfgrasses': 1,
#          'www.swedishinfo.se/12345/67890': 1,
#          'resuming': 219,
#          '15,64': 1,
#          '50.13': 2,
#          'lastreverse': 1,
#          'Xbase': 4,
#          'Job': 506,
#          'Beellman-Ford': 1,
#          'ParseOutput': 23,
#          '350-380': 1,
#          'palettized/consumer': 2,
#          'a-x': 4,
#          'cache-enabled': 1,
#          'F138': 5,
#          'self-annealing': 2,
#          '18-8': 7,
#          'circuit/component': 1,
#          'lim2lim40.3': 2,
#          'ROMs': 312,
#          'Departments': 20,
#          '12VDC': 6,
#          '1018-1021': 2,
#          'NetClient': 15,
#          'taxi.bmp': 1,
#          'r1pQt1': 1,
#          'tofrom': 1,
#          'GMM_INFORMATION': 9,
#          '73-75': 7,
#          '1.NIT': 4,
#          '8-25': 1,
#          'T2AB': 2,
#          '09/387,728': 1,
#          'Permission-Before': 1,
#          'congresswomen': 1,
#          '10t': 4,
#          'Recolouring': 2,
#          'm_StorageTypeStudent': 1,
#          'W/m2': 1,
#          'Exp_ROR': 5,
#          '509B': 1,
#          '410/66.66': 1,
#          'F4-2A': 2,
#          'moveServoAbs': 10,
#          'request/response': 136,
#          'BwC': 1,
#          'endless-shaped': 1,
#          'Recs': 1,
#          'DCVals1128': 2,
#          'spacedescML_ADNETML_SITE': 1,
#          'MAYBEDEFAULT': 3,
#          '1429a': 4,
#          '16MAY97': 4,
#          '17.661': 1,
#          'P1.htm1': 4,
#          'VP4': 1,
#          'S71-3': 1,
#          'nameB2': 1,
#          'History/Chart': 6,
#          'C-334': 1,
#          'information-providing': 102,
#          'informacionaeropuerto.com': 1,
#          'sent10': 1,
#          'PreCare': 1,
#          'scanners/pens': 1,
#          'STARTF_USESHOWWINDOW': 2,
#          'ATS_C_IXN': 5,
#          '24-Hour': 1,
#          'PEOPLE': 23,
#          '702-5': 1,
#          'printer-based': 3,
#          'Dclock': 1,
#          'cur_ndp': 1,
#          'misalligned': 1,
#          '317b': 5,
#          '107/cm': 1,
#          'dnx2n1': 1,
#          'GENCPU': 2,
#          'ImageLocation': 1,
#          'clockwise-rotating': 1,
#          'loosening': 12,
#          'EtotEE': 1,
#          'Uni2': 2,
#          '52.380': 2,
#          'globulin': 1,
#          'tabstop': 2,
#          'TB_BES': 4,
#          'registration/check-in': 1,
#          'pDc2': 2,
#          'subsidy': 34,
#          '41-6': 4,
#          'Sformed': 1,
#          'battery-testing': 1,
#          '111.121.131.111:53': 1,
#          '8650R': 1,
#          'bulletin-board-style': 1,
#          'dispatch/execute': 1,
#          'Cab2': 1,
#          'Namestr': 3,
#          'expx': 1,
#          '36.343': 1,
#          'casename.pre': 2,
#          'FOCUS': 33,
#          'OPC_OPENLIC': 2,
#          '5,335,292': 1,
#          '66.595': 1,
#          'COBRA': 16,
#          '17Implementation': 1,
#          'Auto-init': 1,
#          'Starts': 13,
#          '424-bit': 17,
#          'inner-level': 2,
#          'GDI/CaPSL': 1,
#          'control-code': 3,
#          'Av': 35,
#          'G0ABMMZB001': 1,
#          '5,841,980': 2,
#          'sub-wiring': 4,
#          'correcting': 3097,
#          'dosers': 1,
#          'Comprises': 5,
#          'monocolor': 4,
#          'non-secret': 1,
#          'plan-by-plan': 1,
#          '71.270': 1,
#          'Intersystem': 2,
#          'wrapped': 370,
#          '51.01': 8,
#          'citizenship': 11,
#          'organizing/categorizing': 1,
#          'ACAW': 1,
#          'NameZ': 1,
#          'Shriver': 2,
#          'EntityTmpltDefinition': 1,
#          '15-4': 7,
#          '1/250': 2,
#          'm_AGOG_SYNPTOMS': 1,
#          '3032': 20,
#          'S1-7': 6,
#          'url.txta': 1,
#          'GL_PROJECTION': 2,
#          'SUPPLIERS': 4,
#          '1,768,334': 6,
#          'ServiceName': 9,
#          'X1,1': 6,
#          'F-mark': 41,
#          '42.S30': 1,
#          '5,712,760': 1,
#          '5,477,827': 1,
#          'increase-window': 2,
#          '8am-6pm': 1,
#          '9EB': 2,
#          'district/sales': 1,
#          '14N': 15,
#          '1FH': 1,
#          'Typedeclaration': 1,
#          'Meglumine': 1,
#          'Sorg': 32,
#          'Mar-98': 4,
#          'CCD-defect': 1,
#          '32.001': 1,
#          'Design-1': 2,
#          'N/2k12': 1,
#          '60/100,951': 1,
#          'ESIs': 17,
#          'oversmoothing': 1,
#          'ERICKSON': 2,
#          'io1io2': 2,
#          'gramophone': 2,
#          'm_ETHNIC_ORIGIN_NATIVE_AME': 1,
#          'painfully': 1,
#          'Governing': 5,
#          '80.913': 1,
#          'SC2-0': 10,
#          'two-scale': 11,
#          'no-captioning': 2,
#          'ns15': 1,
#          'prolog': 63,
#          'RTCPConnection': 1,
#          'emissionone': 1,
#          '06d': 2,
#          '2000-210599': 1,
#          'Cries': 2,
#          '35567': 1,
#          '21.773': 1,
#          'V_i': 2,
#          'URL-1': 2,
#          '71.376': 1,
#          'skip-locating': 2,
#          'salted': 1,
#          'k*n2': 1,
#          'Time-modulated': 1,
#          '516,522': 1,
#          'cordlessphonescordless': 1,
#          'odd-sized': 5,
#          'PND': 1,
#          'Drummond': 1,
#          '33.7345': 1,
#          'deliveryalso': 1,
#          '39.016': 1,
#          'charcoal': 2,
#          'three-predictor': 2,
#          'power-down': 338,
#          'DriveSeagate': 1,
#          'DOS-compatible': 2,
#          'frames30': 1,
#          'ASICs': 539,
#          'evenly-distributed': 1,
#          '79.3': 2,
#          'someCondition': 4,
#          'PO_SAID': 2,
#          'compression-encodes': 2,
#          'QTIME': 4,
#          'measurement/indicator': 1,
#          'inadvertently': 208,
#          'Grainger': 13,
#          'Nup': 39,
#          'VerificationsVer': 1,
#          'name-server': 43,
#          'error-recovery': 2,
#          'URL-selection': 1,
#          'justntime': 1,
#          '256M': 12,
#          'non-VLIW': 2,
#          'Xert': 2,
#          '5,659,306': 1,
#          'SMAttrMapping': 15,
#          'Miles': 18,
#          'e-HMO': 1,
#          'rookie': 4,
#          'S77-S84': 1,
#          '56_10': 2,
#          '1889': 12,
#          'informationcommunication': 1,
#          'bimodally': 2,
#          'next-node': 64,
#          'TAHDOT': 1,
#          '00hs': 2,
#          '0857': 29,
#          '50-5b4': 1,
#          'GREENCTRL': 1,
#          'appoint-': 1,
#          'TexttoSpeech': 1,
#          'isp1_subs': 10,
#          'selectedthe': 6,
#          'mosaic-like': 2,
#          'S56-4': 3,
#          '27.BORDER-STYLE': 1,
#          'Americas': 3,
#          '346all': 1,
#          'r9*': 2,
#          '34-8': 7,
#          'Dickinson': 2,
#          '65.68': 4,
#          '5,856,991': 1,
#          'fast-food': 71,
#          'burning': 107,
#          'quanitity': 2,
#          'RMPsocket': 1,
#          'e.button': 1,
#          'Asp30': 1,
#          'currentElement': 7,
#          'XYCk': 4,
#          'Qn2Pn1': 1,
#          '242-245': 2,
#          'URLab': 3,
#          'D3-D7': 1,
#          '08/895,282': 2,
#          'PG2': 6,
#          '68.20': 1,
#          'forfunctioning': 2,
#          '5B': 2276,
#          'RIFF': 1,
#          'Hames': 1,
#          'KL1': 9,
#          'e-speak': 2,
#          '972d-f': 1,
#          'server4': 3,
#          '15.00': 13,
#          'ESR2': 1,
#          'Landegren': 1,
#          '08/846,011': 1,
#          'industru': 1,
#          '325-336': 1,
#          '0.625387': 1,
#          'packagers': 3,
#          'non-elastomer': 3,
#          'Netgear': 1,
#          'G.A': 4,
#          'v0x11.11.a5': 1,
#          'TAG_POINT_PROPERTY': 1,
#          'nickels': 9,
#          'Reels': 1,
#          'WIA_DATA_GRAYSCALE': 2,
#          'side-calculation': 1,
#          'multi-tiered': 100,
#          'F-37000': 1,
#          'deductibility': 5,
#          '2000-050972': 1,
#          '366A': 2,
#          '33.255': 2,
#          'pendingFiag': 1,
#          '64.8': 1,
#          '4.983': 2,
#          'raincheck': 1,
#          'freeing': 188,
#          'Carlton': 1,
#          '6.858': 1,
#          'Lockers': 3,
#          'coding-theory': 1,
#          '6,034,740': 1,
#          'Key1-1': 1,
#          'ROR14': 1,
#          'h_ptr': 6,
#          'S2053': 1,
#          'publish': 564,
#          '269.70': 1,
#          '91011': 3,
#          '2,045': 1,
#          'e21,21': 2,
#          'injection-moulded': 4,
#          'intake-air': 2,
#          'timeframe': 65,
#          'DGRSCOR': 44,
#          'phrase': 2252,
#          'four-bits': 2,
#          '0-bytes': 1,
#          '47.610': 2,
#          'DEAD/ACTIVE': 1,
#          '33-6': 1,
#          'micro-architecture': 21,
#          'SHP': 27,
#          '8005551212thinfax.com': 1,
#          'engine-driven': 1,
#          '24jic': 3,
#          'hubbed': 1,
#          'S63-13': 2,
#          'xmm4': 20,
#          '0.827188': 1,
#          'matchup': 3,
#          '11.975': 2,
#          'RNIF': 16,
#          'Guengerich': 1,
#          '7410': 1,
#          'public-key/private-key': 8,
#          'reoperation': 117,
#          ...})

# %% [markdown]
# For initial learning - maybe take 100,000 most common tokens as data is very noisy.
#
# Issues:
# - Lots of numbers as separate tokens;
#     - Also mixture of digits and symbols e.g. '7\*29,352\*29' or '3-5-3' or '0..255'.
#     - Patent numbers of various types.
#     - Reference numerals such as '100', '74a', '300a'.
# - Variable names such as 'c1C.sub.r' or 'cfgFile';
# - Web addresses or paths such as '//sahara.biospace.com/idev_cybermall/plsql'.
#
# Do we filter these out of the learning?
#
# Most of these are dataset specific.
#
# May want to perform the following processing:
# - punctuation split;
# - replace patent numbers.
#
# Can we use POS tags to identify numbers?
#
# Using embeddings for numbers seems foolish - each number is treated as a separate token. But embedding as \_NUMBER\_ also seems to lose some of the information in the number.

# %%
unique_tokens = list(stats[0].keys())
print(unique_tokens[0:20])

print(len(stats[0].keys()))
# Out:
# ['communize', 'maintenance/check', '1,108,125', 'S1218', 'ADF', 'Mixer/amplifier', 'L2V0F2', '35.489', '72.884', '5,987,425', 'DoseIndex_For_Case_xxx', 'feedback/measurements', 'support/laser', 'CurMorph.vert_arr', 'cted', 'siganalname3', 'media/transport', 'sender-information', 'Korfmacher', '0k']
# 464724

# %%
lower_counts = lowerise(stats[0])

# %%
lower_counts
# Out:
# Counter({'request.form': 3,
#          'communize': 2,
#          'maintenance/check': 1,
#          '1,108,125': 2,
#          'ft/f2': 3,
#          'yhi': 1,
#          'medical/health': 3,
#          '35.489': 1,
#          '72.884': 1,
#          '5,987,425': 1,
#          'feedback/measurements': 1,
#          'welbilt': 2,
#          'cted': 1,
#          'siganalname3': 1,
#          'media/transport': 4,
#          'tobe': 4,
#          'dt2e': 3,
#          'animationnode': 2,
#          '0k': 6,
#          'ho-4': 7,
#          's1425': 7,
#          'operation/processing': 1,
#          '60/265,875': 1,
#          '1879': 13,
#          'positioners': 34,
#          'drivera': 1,
#          'systemout': 1,
#          '15v': 2,
#          'nbc': 54,
#          '09/327,966': 2,
#          'nanoprocessors': 4,
#          '5,734,152': 1,
#          'pricelist': 2,
#          'rvs': 3,
#          'requiredresources': 6,
#          'same-direction': 1,
#          '49.607': 2,
#          "billers'statements": 1,
#          'causal-based': 1,
#          'nt*': 1,
#          '31.600': 2,
#          'userfegistration': 1,
#          'ctpdiscardparams': 1,
#          'bus-described': 1,
#          'schutze': 5,
#          'bayou': 1,
#          'deletion/alteration': 1,
#          'intuitiveness': 2,
#          '648b': 2,
#          'tagobjectdescrtag': 1,
#          'jp-a-8-278279': 1,
#          'edis': 15,
#          'hassrcip': 3,
#          '3.fpx': 4,
#          '1865': 15,
#          'suggested/described': 1,
#          'heeco': 1,
#          'tracings': 3,
#          '34,790': 5,
#          'meta-inf': 5,
#          'plural-bit': 37,
#          'frame/header': 7,
#          '34.6wks': 2,
#          'srccanyon.gif': 1,
#          '306-1': 1,
#          'effect/functions': 1,
#          '2013.9812': 1,
#          '375-n': 1,
#          'datagramsocket': 5,
#          'cr/main/17': 3,
#          'resubmitting': 14,
#          'slaveend': 1,
#          '/yi': 1,
#          'blast-pressure': 2,
#          'microproccessor': 1,
#          'diffract': 7,
#          'medd': 5,
#          '1144a': 1,
#          'logoff': 52,
#          '3002.00': 1,
#          'coley': 3,
#          '14-4b': 1,
#          'motivation': 181,
#          'setmenubar': 1,
#          'mail_queue': 14,
#          'user-to-system': 1,
#          '98273028763-32954-19990714024528265': 1,
#          '460a-f': 6,
#          'directory/item-detail.asppartnonetvendor_embrace_part_id': 1,
#          'pciclkt': 8,
#          '69.475': 1,
#          'remove_file': 1,
#          'segen': 1,
#          'bowser': 1,
#          '.commonnew1': 1,
#          '2-field': 1,
#          'point-pressing': 1,
#          'yq0': 2,
#          '60/217,182': 1,
#          'cab2tr': 1,
#          'multimodem': 1,
#          'intense': 91,
#          'bf2.13': 1,
#          'c1e': 2,
#          'ions/cm3': 1,
#          '5,999,318': 1,
#          'legband': 1,
#          'processing/display': 1,
#          'db_map_initial': 6,
#          'pct/ib00/01560': 1,
#          '5-pin': 3,
#          '1.096': 1,
#          'on-train': 1,
#          'insolvable': 2,
#          'n-context': 1,
#          'cilium': 83,
#          'photostimulable': 6,
#          'pc101a': 23,
#          '410g': 1,
#          '35567': 1,
#          'fno1.1': 1,
#          '157-158': 1,
#          'frames30': 1,
#          '41.423': 1,
#          '3.91': 1,
#          'ptli': 2,
#          'server-class': 2,
#          'addi-': 1,
#          'wdpf': 1,
#          '60/018,921': 2,
#          '6180': 4,
#          'recent-type': 1,
#          'nnstart': 1,
#          '15.00': 13,
#          'v0x11.11.a5': 1,
#          'bitsis': 1,
#          'edit/add': 2,
#          '76.354': 1,
#          'exch-nm': 1,
#          '10-080982': 1,
#          '2000-78125': 1,
#          'ecosystems': 7,
#          'pflumm': 1,
#          'sub-environments': 12,
#          '39b-2': 1,
#          'biocompatible': 1,
#          '-removing': 1,
#          'y_org': 2,
#          'botton': 1,
#          'collision-related': 1,
#          'multi-faceted': 11,
#          '13.532': 2,
#          'device-driven': 6,
#          'breakpoint/trap': 1,
#          '0/1/2/3-bit': 3,
#          '60/160,790': 6,
#          'lifestyle': 240,
#          'process/methodology': 1,
#          'debt-balance': 2,
#          '51.51': 2,
#          'writelockguard': 5,
#          'ingredients/nutrition': 5,
#          'gmax': 26,
#          'xme': 1,
#          'web-site/portal': 1,
#          'fixed-end': 2,
#          'academic/technology': 1,
#          'normnal': 1,
#          '73-74-069': 1,
#          '63272': 1,
#          'state2': 4,
#          'sumz30xff': 2,
#          'nts': 17,
#          'kbit/s': 27,
#          '34:15291-15300': 1,
#          '602a-c': 3,
#          '83.998': 1,
#          '116a-c': 12,
#          'street-corner': 1,
#          'idea/intellectual': 2,
#          '0930': 21,
#          '144144': 13,
#          'unreplaceable': 1,
#          'hix': 2,
#          '5,706,813': 1,
#          'fonts/styles': 1,
#          'multi-panel': 4,
#          'palpating': 4,
#          'retrograde': 3,
#          'clk_e': 3,
#          'disengageable': 2,
#          'auto/trade': 3,
#          '//fixed': 2,
#          '60/184,897': 1,
#          '36*': 1,
#          '7-146854': 1,
#          'programming-ipg': 1,
#          'hal-1000': 8,
#          '46.224': 1,
#          '2-amino-5-iodoacetamido-pentanoic': 1,
#          'id': 43100,
#          'high-z': 3,
#          '132-137': 1,
#          'dome-like': 2,
#          'entry/integration': 1,
#          '8281': 6,
#          '6001b': 2,
#          's01': 69,
#          'ten-count': 2,
#          '11.368': 2,
#          'pwsacompletion': 2,
#          '4,647,143': 1,
#          'pkj': 3,
#          '38.434': 1,
#          'awaits': 247,
#          'a4b4': 1,
#          'c2cd2n': 1,
#          'bezerk': 2,
#          'uet': 1,
#          'widened': 90,
#          'knowledge/organization': 20,
#          'system/asynchronous': 1,
#          'triparty': 1,
#          'disc-changer': 1,
#          'iraq': 57,
#          'win_bid': 3,
#          'etiologies': 2,
#          ':xpropertychangelistener': 2,
#          '2.067243': 1,
#          'confounds': 2,
#          'seattleintairport.com': 1,
#          '32.203': 1,
#          'cowlings': 2,
#          'interface/adaptor': 2,
#          '40.7526': 1,
#          '8201-90': 13,
#          'storage-reduction': 70,
#          'rflrf5': 1,
#          '124.833': 1,
#          'enddimension-1': 4,
#          's1002': 124,
#          'objtype': 4,
#          'whitelight': 1,
#          'maxrminr': 1,
#          'non-published': 2,
#          'trestle': 2,
#          '391-1b': 1,
#          'netgenwarts': 7,
#          'xsel-u1': 2,
#          '09/441,819': 1,
#          'broadcast-program-listing': 25,
#          '21.221': 2,
#          'mlfn': 1,
#          'wfslock': 1,
#          'ber-induced': 1,
#          'rcams': 2,
#          'cdrs': 56,
#          'sampler': 239,
#          '1.1toreq.t.sub.1': 1,
#          '532such': 1,
#          '2u2l2sbr': 2,
#          'slq': 2,
#          'trace41': 1,
#          '1-write': 1,
#          'p0.01': 6,
#          'evtreply': 1,
#          '0.680552': 1,
#          '57.0': 3,
#          'prfestq': 1,
#          'read-controlling': 1,
#          'luisa': 2,
#          'st513': 2,
#          'cooker': 12,
#          'key.': 1,
#          'length30': 1,
#          'lastly': 564,
#          's031': 9,
#          'linde': 3,
#          '5052-5232': 4,
#          'configuration/improvement': 1,
#          '6-signature': 2,
#          'smoothing': 2046,
#          'sub-interface': 7,
#          'card': 72801,
#          'circumstances': 2028,
#          'gmv': 6,
#          'user.location.building': 4,
#          'probationary': 7,
#          '0.3187b': 1,
#          'neko1.gif': 1,
#          'b230': 10,
#          'memorialization': 5,
#          'display-causing': 4,
#          '102.9': 2,
#          'intensity/chroma': 1,
#          'jlive': 1,
#          'gfu_sethi': 1,
#          'well-depth': 2,
#          'uai': 101,
#          'middleinitial': 2,
#          'program*/': 1,
#          '21.48': 1,
#          'geodemographics': 1,
#          'flavortype': 8,
#          'faxmachinen36': 1,
#          'richmond': 11,
#          'error-detection': 14,
#          'spa.display': 1,
#          'referencewindows': 1,
#          '13.248': 1,
#          '/210': 1,
#          '110h': 11,
#          '3g-sgsn': 1,
#          'ma0': 1,
#          '100crsu_in': 4,
#          '2000-147760': 1,
#          'res3': 4,
#          'website/page': 1,
#          'aztec': 8,
#          '22.424': 2,
#          '5081-n': 3,
#          'fftdefaultmaincontroller_h': 3,
#          'timed-availability': 1,
#          'radiol.': 1,
#          'pd1-pdl': 8,
#          'iggs': 1,
#          'monetizable': 1,
#          'application/pdf': 1,
#          'height30': 3,
#          'supervisor': 1085,
#          'crystal-based': 1,
#          'snmp/mip': 1,
#          'seg_close': 5,
#          'c300': 4,
#          'mapsubdrawable': 3,
#          'sub-routing': 1,
#          'number_in': 1,
#          'trianglel': 1,
#          'bf4.7': 2,
#          'clipc': 1,
#          'gettable': 8,
#          'posted': 2228,
#          'nameradios': 2,
#          '0.230': 3,
#          '652-655': 1,
#          '2.192063': 1,
#          'ninety-six': 3,
#          'furniture': 310,
#          '2/27/01': 2,
#          '68.3378': 1,
#          'vvertex': 3,
#          'edge-long': 1,
#          'preview-displayed': 1,
#          '87.931': 1,
#          'jc8': 1,
#          'ctds': 13,
#          '18.385': 1,
#          '365-2-1': 2,
#          '15.713': 2,
#          'metaphysical': 3,
#          'graphic-image-data': 2,
#          '69.3': 1,
#          '78.039': 2,
#          'sporadic': 17,
#          'locka': 4,
#          'allroutesbroadcastpkts': 1,
#          'bartered': 73,
#          'iv-a': 2,
#          '1.9,19': 1,
#          'eetimes.com': 1,
#          '52.814': 2,
#          '42.040': 2,
#          'poly-lines': 1,
#          'name-to-address': 1,
#          '3176': 5,
#          '-max': 2,
#          '09/698,471': 3,
#          't5-2': 2,
#          'assetsnot': 1,
#          'pacific': 71,
#          'mtp': 42,
#          'sgetstat': 3,
#          'date-': 10,
#          'notifications/objects': 3,
#          'purchase-buying': 1,
#          'lunsigned': 1,
#          'cricir': 1,
#          '85.9602': 1,
#          '58.110': 1,
#          'utilitiy': 1,
#          '/wavelength': 1,
#          'current_start': 1,
#          'paks': 2,
#          'abcvsmainvimx.h': 1,
#          'change/evolve': 1,
#          's67456': 1,
#          'securityenhancer': 1,
#          '*loop': 1,
#          'ballard': 12,
#          'via-magazine': 21,
#          'at-which': 1,
#          'ig1u1g2u2': 1,
#          'payback': 118,
#          'powers-up': 3,
#          'zsxac': 1,
#          '5,913,210': 1,
#          'non-sloping': 6,
#          'p5occfree': 1,
#          'entry-like': 4,
#          'midportion': 1,
#          '63.68': 2,
#          'timeoutoccurs': 2,
#          'dkyykmmkcc': 1,
#          'ageprovider': 6,
#          'onoccur': 2,
#          '31e': 18,
#          'litre': 8,
#          'clearcoat': 1,
#          'near-ubiquity': 1,
#          'sga2': 15,
#          'bak0': 3,
#          'management/oversight': 1,
#          '000000b': 1,
#          'xsw365': 1,
#          '1zaa': 8,
#          'other/additional': 3,
#          'methylphenylcyclotetrasiloxane': 1,
#          'interactor-state': 2,
#          'xx30': 1,
#          'averageimagecolor_l': 3,
#          '89/10651': 1,
#          'reply3': 1,
#          'rt1': 92,
#          'rwthumbnil.tob': 7,
#          'fails.7bank': 1,
#          '55.024': 2,
#          '0111999': 1,
#          'eludt': 13,
#          'qaa1ar': 1,
#          '27.020': 5,
#          '91.796': 2,
#          'saturate/minimum': 1,
#          'errok': 8,
#          '502-510': 4,
#          's2v2': 1,
#          'ip4addresstype': 1,
#          'yokoya': 2,
#          'xlogin': 5,
#          '5,675,797': 1,
#          'circuit1001': 1,
#          'level1n': 10,
#          'f10xxq': 1,
#          '17.299': 2,
#          'adminbatchcheckde': 1,
#          'watermarked': 751,
#          'reconfigurable': 651,
#          '291-1-n': 1,
#          'baystars': 9,
#          '2498': 4,
#          'tgz': 24,
#          'dout_risex': 1,
#          'insatiable': 4,
#          '14.3.1': 2,
#          'halibot': 2,
#          'emcodingiso-8859-1': 1,
#          'dtp/tp0': 1,
#          'far-near': 2,
#          'quantity-adjusted': 3,
#          'cable/twisted': 2,
#          '1538': 34,
#          'cyber-dollars': 1,
#          '*next_win_stte': 1,
#          'deblocking': 6,
#          '15-50': 1,
#          'argl_type': 1,
#          'rejecting/unloading': 1,
#          'defmes': 1,
#          'tr22a': 1,
#          '52.024': 1,
#          'display/start': 4,
#          '1547.12': 1,
#          'transaction-approval-information': 1,
#          'telephone-devices': 1,
#          'fc01': 3,
#          'zqz6898': 4,
#          'temp12': 2,
#          'function/use': 1,
#          '14-5': 3,
#          'productcode802,808,802,816': 3,
#          'temp_opt_prem': 1,
#          '60/189,893': 1,
#          'current_bid': 1,
#          '825a': 2,
#          'site-licensed': 4,
#          'missing_in_src': 1,
#          '312a-c.': 1,
#          'blindness': 29,
#          'handbooks': 9,
#          '16.126': 1,
#          'trailblazers': 2,
#          '413from': 1,
#          'subsidizes': 4,
#          'z102.4': 1,
#          'feb-1996': 1,
#          're-assembly': 13,
#          'enc_dt': 1,
#          '76d-76j': 1,
#          '38ab': 2,
#          'very-low-order-rate': 62,
#          'wavelength': 1399,
#          'prottrembl': 1,
#          'idc_r_other_cur1': 1,
#          'diag_dcfg1:0': 1,
#          'verison': 1,
#          'msasp': 25,
#          '1900555-1212': 1,
#          'maximumposition': 1,
#          'change_trackingcrctimestampchange_counter': 1,
#          'ticksleftthe': 1,
#          '6.3x': 1,
#          'single-kind': 1,
#          'slot/8.00': 1,
#          '60/187,137': 1,
#          'non-spatial': 7,
#          'recvfrom': 1,
#          'pattern-reading': 1,
#          'recipient-by-recipient': 2,
#          'predefined': 5098,
#          '00001111': 8,
#          'jun-1996': 1,
#          'dispursal': 1,
#          'nint': 17,
#          'dxdxtx': 1,
#          'spu/siu': 1,
#          'vinvcm': 4,
#          'high-interest': 1,
#          'rainin': 2,
#          '118.1': 4,
#          'eput': 5,
#          '12806': 1,
#          'fortify': 1,
#          'regresses': 1,
#          'smokes': 15,
#          'tila': 10,
#          '0-201-30998-x': 1,
#          'pragma': 31,
#          'ioctl': 45,
#          'instancefor': 1,
#          'r.p.m': 9,
#          '54.076': 1,
#          'n-1:0': 2,
#          'contracticatj': 1,
#          'bblue/255.0': 1,
#          'eighty-ninth': 1,
#          '52x': 1,
#          'typar': 6,
#          'non-vulcanized': 1,
#          'iidas': 6,
#          'specifing': 5,
#          'qsd-to-gp': 1,
#          'two-phased': 1,
#          'residental': 1,
#          'sms-driven': 1,
#          'r2rx': 1,
#          '51.103': 2,
#          'in-housing': 1,
#          'tn3270': 1,
#          'registerpom': 2,
#          'paraphrased': 2,
#          '169-177': 1,
#          '11-355386': 1,
#          'mutiplexing': 1,
#          'gyx': 4,
#          'lockup': 100,
#          'turfgrasses': 1,
#          'faceit': 12,
#          'neninb': 1,
#          'www.swedishinfo.se/12345/67890': 1,
#          'resuming': 220,
#          '15,64': 1,
#          'fig.1g': 1,
#          '50.13': 2,
#          'lastreverse': 1,
#          'srmax': 1,
#          'queryrangeprice': 2,
#          'ws_visible': 2,
#          '350-380': 1,
#          'palettized/consumer': 2,
#          'a-x': 5,
#          'cinos-enhanced': 3,
#          'cache-enabled': 1,
#          'bn4.1': 2,
#          'self-annealing': 2,
#          '18-8': 7,
#          'circuit/component': 1,
#          'lim2lim40.3': 2,
#          'bucketsnsizes': 1,
#          '1018-1021': 2,
#          '102100': 2,
#          'tofrom': 1,
#          '1319': 70,
#          'html/wml': 3,
#          'mlcc': 1,
#          'caroot1': 6,
#          '8-25': 1,
#          'congresswomen': 1,
#          '10t': 12,
#          'ldi_imed': 3,
#          'target-a': 1,
#          '2f1': 20,
#          '410/66.66': 1,
#          'discount/coupon': 1,
#          'request/response': 146,
#          'endless-shaped': 1,
#          'located': 19283,
#          'instructions/second': 5,
#          'cgats/ansi': 1,
#          'drive/robotic': 1,
#          'id_label': 5,
#          '1429a': 4,
#          '17.661': 1,
#          'blistdest': 1,
#          'appealed': 9,
#          'mex1': 11,
#          'information-providing': 102,
#          'sent10': 1,
#          'scanners/pens': 1,
#          'eff_end_date': 1,
#          '702-5': 1,
#          'fsyssortsequence': 2,
#          'printer-based': 3,
#          'cur_ndp': 1,
#          'misalligned': 1,
#          '317b': 6,
#          'how-': 1,
#          '107/cm': 1,
#          'dnx2n1': 1,
#          'blkid-nm1': 1,
#          '8227': 2,
#          'dekey': 7,
#          'if4': 3,
#          'loosening': 13,
#          'pe01': 4,
#          '52.380': 2,
#          'globulin': 1,
#          'tabstop': 3,
#          'registration/check-in': 1,
#          'subsidy': 34,
#          'tbtb1tb2': 1,
#          '41-6': 4,
#          'vob_id': 5,
#          'battery-testing': 1,
#          '111.121.131.111:53': 1,
#          'vandamessagingobjecttype.ejb_object': 2,
#          'r255': 3,
#          'bulletin-board-style': 1,
#          'dispatch/execute': 1,
#          '60/071,392': 1,
#          'expx': 1,
#          'in-real-time': 1,
#          'casename.pre': 2,
#          'laying-open': 78,
#          '5,335,292': 1,
#          '66.595': 1,
#          's1-4': 12,
#          '424-bit': 17,
#          'inner-level': 2,
#          'control-code': 3,
#          'md35': 4,
#          '5,841,980': 2,
#          'sub-wiring': 4,
#          'correcting': 3130,
#          'dosers': 1,
#          'monocolor': 4,
#          '4,146,792': 1,
#          'non-secret': 1,
#          'rresvold': 3,
#          'plan-by-plan': 1,
#          'idevent_contact': 1,
#          'physikalische': 1,
#          'typeclass_any': 1,
#          '71.270': 1,
#          'wrapped': 375,
#          '51.01': 8,
#          'wnt': 31,
#          'citizenship': 11,
#          'organizing/categorizing': 1,
#          'parametrizes': 2,
#          'spells': 5,
#          '15-4': 7,
#          '1/250': 2,
#          '3032': 20,
#          'nfk22': 2,
#          'url.txta': 1,
#          '1,768,334': 6,
#          '4,728,469': 1,
#          's59-6': 2,
#          'getmodels': 1,
#          'blendb1': 2,
#          '60/273,033': 1,
#          '5,712,760': 1,
#          '5,477,827': 1,
#          'increase-window': 2,
#          'cab2': 1,
#          'district/sales': 1,
#          's3608': 3,
#          '32.001': 1,
#          'corres-': 1,
#          '60/100,951': 1,
#          'oversmoothing': 1,
#          'soeder': 1,
#          'io1io2': 2,
#          'gramophone': 2,
#          'painfully': 1,
#          '80.913': 1,
#          'two-scale': 11,
#          'divisive': 1,
#          'ns15': 1,
#          'prolog': 96,
#          'one-to-n': 3,
#          'emissionone': 1,
#          '06d': 2,
#          'getsysload': 1,
#          '6,044,449': 1,
#          '21.773': 1,
#          'dstbn0': 1,
#          'implemention': 6,
#          '71.376': 1,
#          'skip-locating': 2,
#          'salted': 1,
#          'k*n2': 1,
#          'iil4': 3,
#          'tmdirect': 1,
#          ':increment': 2,
#          '516,522': 1,
#          'cordlessphonescordless': 1,
#          'odd-sized': 5,
#          'ssda': 3,
#          '33.7345': 1,
#          'em6': 1,
#          'deliveryalso': 1,
#          '39.016': 1,
#          'charcoal': 2,
#          'three-predictor': 2,
#          'power-down': 354,
#          '0.508087': 1,
#          'g-number': 1,
#          'evenly-distributed': 1,
#          '79.3': 2,
#          'request-issuing': 2,
#          'measurement/indicator': 1,
#          'inadvertently': 208,
#          'userbuswritemap': 3,
#          '0.377': 1,
#          'name-server': 44,
#          'error-recovery': 2,
#          'justntime': 3,
#          'curheadingindex': 4,
#          '5,659,306': 1,
#          '58.40': 6,
#          'rookie': 4,
#          '56_10': 2,
#          'informationcommunication': 11,
#          '4*n': 10,
#          'bimodally': 2,
#          'next-node': 64,
#          'taatta': 1,
#          '00hs': 2,
#          '3200k': 1,
#          'km1': 87,
#          'ioo': 1,
#          'mds-dl1-1': 5,
#          '167qg4167d': 9,
#          'pfd_main_plane': 1,
#          '50-5b4': 1,
#          '36.818': 1,
#          'appoint-': 1,
#          '184y': 2,
#          'separating': 1574,
#          'isp1_subs': 10,
#          'selectedthe': 6,
#          'mosaic-like': 2,
#          's2103': 30,
#          '346all': 1,
#          'r9*': 4,
#          '34-8': 7,
#          '65.68': 4,
#          '184360': 4,
#          'fast-food': 77,
#          'burning': 113,
#          'quanitity': 2,
#          'e.button': 1,
#          'jmax1': 4,
#          'sg8': 11,
#          '242-245': 2,
#          'athineos': 2,
#          '08/895,282': 2,
#          '68.20': 1,
#          'forfunctioning': 2,
#          'r0x09.116': 1,
#          '26.15': 1,
#          'e-speak': 13,
#          '972d-f': 1,
#          '3446': 6,
#          'server4': 3,
#          'fault-diagnosing': 2,
#          'pulp': 83,
#          'orn_': 5,
#          '08/846,011': 1,
#          'benedrylr': 1,
#          '325-336': 1,
#          '0.625387': 1,
#          'packagers': 3,
#          'appnameparamsversionlanguage': 1,
#          'non-elastomer': 3,
#          'etts': 18,
#          'activeacknowledged': 2,
#          'ascline5': 1,
#          'lauthorizationnumber': 2,
#          'thumb2-3': 1,
#          '60/240,402': 1,
#          'nickels': 9,
#          'side-calculation': 1,
#          'multi-tiered': 103,
#          'se3b': 1,
#          '60.494': 2,
#          '2000-050972': 1,
#          '33.255': 2,
#          '326a-326c': 1,
#          'sendkey': 2,
#          '64.8': 1,
#          '4.983': 2,
#          'raincheck': 1,
#          'freeing': 189,
#          'coding-theory': 1,
#          '50/': 1,
#          'registerobjectparam': 1,
#          'h_ptr': 6,
#          'anfisgnu': 1,
#          '269.70': 1,
#          '91011': 3,
#          '2,045': 1,
#          'e21,21': 2,
#          'equijoin': 2,
#          'intake-air': 2,
#          'phrase': 2351,
#          'four-bits': 2,
#          '0-bytes': 1,
#          '47.610': 2,
#          '33-6': 1,
#          'list/sublists': 1,
#          '8005551212thinfax.com': 1,
#          'engine-driven': 1,
#          '24jic': 3,
#          'hubbed': 1,
#          'xmm4': 20,
#          '0.827188': 1,
#          'matchup': 3,
#          'gmbl': 2,
#          '1.1511': 1,
#          'alingap': 6,
#          'ic-recorder': 1,
#          '7410': 1,
#          'public-key/private-key': 8,
#          'reoperation': 117,
#          'scattering/reflectance': 1,
#          '10.36': 6,
#          'r1iin': 2,
#          '.ak.wkak1': 1,
#          'actnfy.idl': 1,
#          '3041d': 2,
#          'cellgate': 1,
#          'addererror': 15,
#          'script-processing': 4,
#          'ws_tabstop,362,59,29,10': 1,
#          'sendwithrbox': 19,
#          'sights': 12,
#          'rms_ememfree': 1,
#          'lod_clipoff': 5,
#          'energy-value': 1,
#          '55.86': 2,
#          'relatively-fast': 1,
#          'use_filter': 7,
#          'jp-a-10-21322': 2,
#          'spread-out': 1,
#          '2000-172043': 1,
#          'etc.involves': 1,
#          'field.isdate': 3,
#          'methodsset': 1,
#          '123.206': 1,
#          '1874': 16,
#          'beset': 2,
#          'power-generation': 7,
#          'morphemic': 6,
#          '10low': 1,
#          'inter-canine': 1,
#          'eight-hundred': 3,
#          'ceh': 2,
#          'url/sip': 2,
#          'synchronism': 850,
#          '2a/b': 2,
#          'coupon_name': 9,
#          '.b.c': 1,
#          '1526': 94,
#          'sub-millimeter': 1,
#          'revaluation': 46,
#          'oper': 46,
#          '60/108,319': 1,
#          'c_iad.type': 1,
#          'x-decoder': 5,
#          'program/internet': 1,
#          '51.852': 1,
#          'cg-rom': 10,
#          's4701': 1,
#          'coupon_x': 1,
#          'down-open': 6,
#          'mulitimedia': 1,
#          'register-addressing': 69,
#          'lj15': 2,
#          'redeeming': 187,
#          'error_urlhttp': 1,
#          'network-side': 21,
#          'string20': 1,
#          'qtmhhttp': 2,
#          'stone-washed': 1,
#          'battalion': 1,
#          'operationsthis': 4,
#          'bvsubvoxel': 1,
#          'option_': 1,
#          'deisenhofer': 5,
#          'tcp/usp': 1,
#          '73.517': 1,
#          '99.427': 1,
#          'productcode010111': 1,
#          're-grouping': 7,
#          'unworkably': 1,
#          'utensils': 6,
#          'searchpointer': 19,
#          'stratastudio': 1,
#          'execution/stoppage': 1,
#          '58.594': 1,
#          'pseudo-personality': 1,
#          'v1f': 20,
#          'srcresize.is': 1,
#          'ethnicity': 31,
#          '450,000': 8,
#          '976f': 1,
#          'accomodated': 6,
#          'combined-order': 1,
#          '96.194': 3,
#          'ml_mthdjs_vl': 4,
#          '800982.pdf': 1,
#          '92/3': 1,
#          '330objective': 2,
#          'depacketizing': 9,
#          'point-vector': 1,
#          '5,467,433': 1,
#          'ipropertypage': 6,
#          'voltage-divider': 1,
#          'unfrequently': 1,
#          'birthday-related': 2,
#          'article/coupon': 2,
#          'locally-computed': 9,
#          'associations/organizations': 1,
#          'non-reverse': 2,
#          '60/185,964': 2,
#          'jp-a-6-290125': 1,
#          '*allserver-instance-name': 1,
#          'mistakes': 343,
#          'bridgeport': 3,
#          '20.shall': 1,
#          '18.380': 3,
#          'msterofffield': 1,
#          'forklifts': 6,
#          'ramana': 1,
#          '5,373,146': 1,
#          'optionally-provided': 1,
#          '58.928': 1,
#          'functional-rtm': 1,
#          'dest_port': 1,
#          'lec_esi': 1,
#          'f3-fn': 1,
#          '022222222': 1,
#          'members-present': 1,
#          'boost': 223,
#          'tan99': 8,
#          'generate-subject-sequence': 2,
#          'contextualcommerceurl': 1,
#          'matrix-addressable': 3,
#          'bidder/supplier': 1,
#          'fuzzed': 8,
#          'spoiler': 3,
#          '420e': 6,
#          'nhps': 2,
#          'video-mail': 2,
#          'vaf': 17,
#          'sion': 2,
#          'counter0': 8,
#          'store-and': 6,
#          'incandescence': 1,
#          ...})

# %%
print('the' in stats[0])
print('The' in stats[0])
print('THe' in stats[0])
print('THE' in stats[0])
print(stats[0]['the'])
print(stats[0]['The'])
print(stats[0]['THe'])
print(stats[0]['THE'])

print('the' in lower_counts)
print('The' in lower_counts)
print('THe' in lower_counts)
print('THE' in lower_counts)
print(lower_counts['the'])
# Out:
# True
# True
# True
# True
# 7683723
# 800541
# 2
# 1116
# True
# False
# False
# False
# 8485384

# %%
7683723+800541+2+1116
# Out:
# 8485382

# %%
print("Number of original mixed case tokens: {0}".format(len(stats[0])))
print("Number of lower case tokens: {0}".format(len(lower_counts)))
# Out:
# Number of original mixed case tokens: 464724
# Number of lower case tokens: 410697

# %%
total = 0
shared_terms = list()
for k in lower_counts.keys():
    if k in embeddings_index.keys():
        total += 1
        shared_terms.append(k)

print("There are {0} terms in our patent count that are in the GloVe embeddings".format(total))
print("There are {0} terms in our patent count that are NOT in the GloVe embeddings".format(len(lower_counts)-total))
print("A sample of shared terms: {0}".format(random.sample(shared_terms, 100)))
# Out:
# There are 77364 terms in our patent count that are in the GloVe embeddings
# There are 333333 terms in our patent count that are NOT in the GloVe embeddings
# A sample of shared terms: ['46.57', '4.45', 'x87', 'ambiguity', 'up-down', 'diadem', 'decommissioning', 'gof', 'affluent', 'vhf', '1476', 'assimilated', 'aprs', '43.35', 'tmds', 're-appear', 'lsn', 'rollerblade', 'illusion', 'smg', 'lc3', 'dvd-ram', 'avows', 'clan', 'telemarketer', '91.7', 'hinote', 'grail', 'ajka', 'otcbb', 'locater', 'krawczyk', 'impermissible', 'cushioning', 'abc', 'plunkett', '2890', 're-writing', 'am1', '2220', 'slamon', 'gritz', '83.58', 'rinsing', 'edmondson', 'branching', 'alcs', 'substrings', 'counteroffers', 'rans', '050', 'immature', 'reduces', 'arash', 'power-law', 'etf', '1737', 'creatives', '60.57', 'wounds', 'warsaw', 'xray', 'agronomist', 'comprehend', 'duels', 'limitless', 'conformably', 'convolutional', 'serendipitous', 'buckle', '.1', 'duryea', 'protesting', 'formulary', 'autoclave', 'cryptosystems', 'urologist', 'man-to-man', 'online', '1302', 'easy', 'perceptive', 'tolerant', 'murrah', 'taggants', 'seventy-four', 'analytically', 'ideas', 'whipple', '39.5', 'nannies', 'refocus', '307,000', 'wheelbarrows', 'dispersing', 'nicola', 'feynman', 'dak', 'sarg', 'contravened']

# %%
random.sample(shared_terms, 100)
# Out:
# ['rifai',
#  'amalgams',
#  'wash',
#  'airfare',
#  'liquified',
#  'demographically',
#  'delimiter',
#  'cuvette',
#  'succinic',
#  'plf',
#  'open-source',
#  'visitable',
#  'fulfillment',
#  'am3',
#  'ya',
#  'scpc',
#  'solidification',
#  'coordinator',
#  'v-4',
#  '2216',
#  'svr',
#  'torok',
#  'decision-makers',
#  'redundantly',
#  'hla',
#  'soeder',
#  'one-by-one',
#  'plug-and-play',
#  '42.92',
#  'color-coded',
#  '45.14',
#  'seafood',
#  'levinthal',
#  '125-1',
#  'beli',
#  'become',
#  'pusic',
#  'synergies',
#  'similar',
#  'psos',
#  'pecuniary',
#  'brinch',
#  'unravels',
#  'bathes',
#  '2181',
#  'embraces',
#  'vois',
#  'hp-ux',
#  'lrs',
#  'palettes',
#  'provo',
#  'indispensable',
#  'equitation',
#  'vil',
#  'expense',
#  'fbs',
#  'arty',
#  'everywhere',
#  'pilot',
#  '93.33',
#  'symptomatic',
#  'undisputed',
#  'climates',
#  'expectancies',
#  'kraemer',
#  'well-timed',
#  'res',
#  'lace',
#  '72.1',
#  '5-0',
#  'tempered',
#  'puccini',
#  'caglayan',
#  'overtones',
#  'masaoka',
#  'kotler',
#  'mbw',
#  'dispatching',
#  'offset',
#  'cautiously',
#  'ofe',
#  '80c',
#  'blooded',
#  'yoshiharu',
#  'auditioning',
#  'dsi',
#  'zigzag',
#  'billo',
#  'precluding',
#  'nemaha',
#  'd3a',
#  'hard-pressed',
#  'farms',
#  'embarrassment',
#  'snows',
#  '30.9',
#  'firn',
#  'quenched',
#  'idly',
#  'dolt']

# %%
lower_counts.most_common(1)
# Out:
# [('the', 8485384)]

# %%
# How many of the shared terms are in the most common patent term counts
total = 0
common_terms = list()
for term, count in lower_counts.most_common(100000):
    if term in embeddings_index.keys():
        total += 1
        common_terms.append(term)
        
print("There are {0} of the top 100,000 terms in our patent count that are in the GloVe embeddings".format(total))
# Out:
# There are 45298 of the top 100,000 terms in our patent count that are in the GloVe embeddings

# %% [markdown]
# It looks like we will need to generate our own set of word embeddings! Maybe we can use gensim to do this.
#
# However, can we use the overlapping terms to seed our weights?

# %%
common_terms
# Out:
# ['the',
#  ',',
#  '.',
#  'a',
#  'of',
#  'to',
#  'and',
#  'in',
#  'is',
#  'for',
#  ')',
#  '(',
#  'data',
#  'be',
#  'an',
#  'as',
#  'by',
#  'or',
#  'that',
#  'information',
#  'with',
#  'are',
#  'from',
#  'on',
#  'fig',
#  'system',
#  'said',
#  'which',
#  ';',
#  'at',
#  'may',
#  'user',
#  'can',
#  'one',
#  'this',
#  'step',
#  'invention',
#  'image',
#  'each',
#  'it',
#  '1',
#  'device',
#  'not',
#  'first',
#  'method',
#  'such',
#  'if',
#  'present',
#  'processing',
#  'when',
#  'server',
#  'wherein',
#  'computer',
#  'memory',
#  'unit',
#  'claim',
#  'embodiment',
#  ':',
#  'other',
#  'example',
#  'control',
#  'second',
#  'means',
#  'according',
#  'number',
#  'signal',
#  'has',
#  'network',
#  'time',
#  'process',
#  'used',
#  '2',
#  'will',
#  'program',
#  'value',
#  'shown',
#  'also',
#  'input',
#  'set',
#  'then',
#  'further',
#  'apparatus',
#  'object',
#  'display',
#  'more',
#  'address',
#  'using',
#  'into',
#  'operation',
#  'stored',
#  'storage',
#  'application',
#  'code',
#  "'s",
#  'described',
#  'block',
#  '3',
#  'between',
#  'output',
#  'includes',
#  'circuit',
#  'any',
#  'plurality',
#  'service',
#  'access',
#  'through',
#  'database',
#  'all',
#  'comprising',
#  'request',
#  'file',
#  'client',
#  'interface',
#  'based',
#  '10',
#  'least',
#  'terminal',
#  'have',
#  '4',
#  'been',
#  'corresponding',
#  'communication',
#  'web',
#  'order',
#  'table',
#  'provided',
#  'above',
#  'having',
#  'use',
#  'reference',
#  'selected',
#  'so',
#  'area',
#  '5',
#  'section',
#  'content',
#  'same',
#  'within',
#  'another',
#  'software',
#  'these',
#  'message',
#  'processor',
#  'function',
#  'case',
#  'only',
#  'line',
#  'being',
#  'no',
#  'where',
#  'associated',
#  'state',
#  'including',
#  'than',
#  'two',
#  'card',
#  'via',
#  'page',
#  'type',
#  'comprises',
#  'electronic',
#  'management',
#  '12',
#  'there',
#  'instruction',
#  'bus',
#  'diagram',
#  'module',
#  'result',
#  'whether',
#  'connected',
#  '6',
#  'controller',
#  'received',
#  'part',
#  'product',
#  'different',
#  'internet',
#  'after',
#  'document',
#  'customer',
#  'particular',
#  'include',
#  'receiving',
#  'devices',
#  'new',
#  'list',
#  'out',
#  'thus',
#  'provide',
#  'digital',
#  'its',
#  'values',
#  'screen',
#  'b',
#  'performed',
#  'point',
#  'accordance',
#  '11',
#  'portion',
#  '7',
#  'position',
#  'steps',
#  'displayed',
#  '20',
#  'predetermined',
#  '8',
#  'read',
#  'response',
#  'field',
#  '14',
#  'and/or',
#  'form',
#  'transaction',
#  'register',
#  'medium',
#  'command',
#  'mode',
#  'storing',
#  'specific',
#  'level',
#  'node',
#  'name',
#  'but',
#  'made',
#  'current',
#  'structure',
#  'various',
#  'connection',
#  'shows',
#  'component',
#  '16',
#  'determined',
#  'signals',
#  'search',
#  'transfer',
#  'transmission',
#  'flow',
#  'showing',
#  'systems',
#  'source',
#  'provides',
#  'however',
#  'over',
#  'host',
#  'next',
#  '0',
#  'following',
#  'providing',
#  '100',
#  'power',
#  '9',
#  'pixel',
#  'location',
#  'preferred',
#  'contents',
#  'possible',
#  'logic',
#  'amount',
#  'while',
#  'bit',
#  'color',
#  '13',
#  'available',
#  'group',
#  'key',
#  'obtained',
#  'upon',
#  'objects',
#  'element',
#  'description',
#  'generated',
#  'third',
#  'video',
#  'item',
#  'operating',
#  'id',
#  'site',
#  'embodiments',
#  'e.g.',
#  'like',
#  'configuration',
#  'their',
#  'during',
#  'view',
#  'cpu',
#  'required',
#  'those',
#  'some',
#  'model',
#  'images',
#  'cache',
#  'recording',
#  'identification',
#  'clock',
#  '30',
#  'figs',
#  'pattern',
#  'components',
#  'c',
#  'users',
#  'size',
#  '15',
#  'target',
#  'disk',
#  'transmitted',
#  'generating',
#  'defined',
#  'event',
#  'therefore',
#  'frame',
#  'instructions',
#  'without',
#  '22',
#  'would',
#  'both',
#  'provider',
#  'given',
#  'art',
#  'buffer',
#  'end',
#  'addition',
#  'services',
#  'account',
#  'should',
#  'elements',
#  'format',
#  'region',
#  'n',
#  'local',
#  'execution',
#  'determining',
#  'selection',
#  'packet',
#  'store',
#  'preferably',
#  'about',
#  'link',
#  'operations',
#  'single',
#  'machine',
#  'external',
#  'personal',
#  'functions',
#  'related',
#  'record',
#  'since',
#  '18',
#  'entry',
#  'sent',
#  'remote',
#  'specified',
#  'up',
#  'side',
#  'change',
#  'additional',
#  'text',
#  'desired',
#  'sequence',
#  'determine',
#  'character',
#  'they',
#  'does',
#  'media',
#  'individual',
#  'executed',
#  'virtual',
#  '24',
#  'condition',
#  'receives',
#  'items',
#  'either',
#  'protocol',
#  'high',
#  '21',
#  'main',
#  'x',
#  'bits',
#  '>',
#  'communications',
#  'results',
#  'below',
#  'space',
#  'i',
#  'multiple',
#  'was',
#  'status',
#  'well',
#  '<',
#  'test',
#  'engine',
#  'receive',
#  's',
#  'error',
#  'respective',
#  'manner',
#  'configured',
#  'path',
#  'way',
#  'because',
#  'write',
#  'price',
#  'setting',
#  'illustrates',
#  'design',
#  'center',
#  'printer',
#  'direction',
#  'print',
#  'illustrated',
#  '17',
#  'units',
#  'stores',
#  'period',
#  '32',
#  'necessary',
#  'light',
#  'window',
#  'select',
#  'purchase',
#  'mail',
#  '110',
#  'types',
#  'coupled',
#  'channel',
#  'before',
#  'parameters',
#  'button',
#  'manager',
#  'selecting',
#  'known',
#  'standard',
#  'layer',
#  'files',
#  'could',
#  'business',
#  'points',
#  'must',
#  'hardware',
#  'agent',
#  'appropriate',
#  'perform',
#  'herein',
#  '40',
#  'audio',
#  'analysis',
#  'aspect',
#  'etc',
#  'reading',
#  'base',
#  'limited',
#  'many',
#  'identifier',
#  'even',
#  'range',
#  'payment',
#  'distribution',
#  'rate',
#  'port',
#  'physical',
#  'length',
#  'methods',
#  'destination',
#  'applications',
#  'basis',
#  'allows',
#  'frequency',
#  'transmitting',
#  'd',
#  'blocks',
#  'lines',
#  'requests',
#  'similar',
#  'products',
#  'printing',
#  'automatically',
#  'browser',
#  'indicating',
#  'pixels',
#  'referring',
#  'central',
#  'procedure',
#  '102',
#  '50',
#  'variable',
#  'need',
#  'i.e.',
#  'determines',
#  'respectively',
#  'exemplary',
#  'typically',
#  'consumer',
#  'work',
#  'three',
#  'processes',
#  'telephone',
#  'now',
#  'e-mail',
#  'delivery',
#  '26',
#  'original',
#  'included',
#  'cell',
#  'conventional',
#  'detection',
#  'date',
#  'performing',
#  'surface',
#  'speed',
#  'drive',
#  'vehicle',
#  'implemented',
#  'displaying',
#  'contains',
#  '23',
#  '200',
#  'thereby',
#  'bar',
#  'prior',
#  'map',
#  'performance',
#  'applied',
#  'detail',
#  'resource',
#  'back',
#  'member',
#  'controlling',
#  'array',
#  'equipment',
#  'under',
#  'registered',
#  '19',
#  'generate',
#  'once',
#  'switch',
#  'certain',
#  'indicates',
#  'generally',
#  'general',
#  'credit',
#  'optical',
#  'conditions',
#  'picture',
#  'internal',
#  'ip',
#  'advertisement',
#  'changes',
#  'added',
#  'respect',
#  'feature',
#  'assigned',
#  'start',
#  'recorded',
#  'registration',
#  'computers',
#  'class',
#  'most',
#  'conversion',
#  'illustrating',
#  'generation',
#  'portable',
#  'word',
#  'programs',
#  'language',
#  'detected',
#  'servers',
#  'security',
#  'who',
#  'support',
#  '-',
#  'parts',
#  'common',
#  'sets',
#  '120',
#  '25',
#  'calculated',
#  'directly',
#  'attribute',
#  'among',
#  'station',
#  'parameter',
#  'created',
#  'mechanism',
#  'identifying',
#  'messages',
#  'indicated',
#  'features',
#  'large',
#  'records',
#  'identified',
#  'outputs',
#  'logical',
#  'processed',
#  'capable',
#  'sensor',
#  'environment',
#  'flowchart',
#  'distance',
#  'containing',
#  '28',
#  'game',
#  'written',
#  'call',
#  'mobile',
#  'company',
#  '104',
#  'nodes',
#  'total',
#  'patient',
#  'menu',
#  'person',
#  'pages',
#  'difference',
#  'check',
#  'operator',
#  'uses',
#  'determination',
#  '31',
#  'times',
#  'chart',
#  'sends',
#  'load',
#  '34',
#  'referred',
#  'located',
#  'decoding',
#  'cost',
#  'wireless',
#  'column',
#  'stream',
#  'requested',
#  'thereof',
#  'integrated',
#  'lower',
#  'profile',
#  'edge',
#  'accordingly',
#  'addresses',
#  'supply',
#  'executing',
#  'previously',
#  'y',
#  'box',
#  'transferred',
#  'do',
#  'along',
#  'numbers',
#  'performs',
#  'detecting',
#  'task',
#  'query',
#  'timing',
#  'low',
#  'm',
#  'voltage',
#  'filter',
#  'make',
#  'until',
#  'allow',
#  'segment',
#  'displays',
#  'financial',
#  'designated',
#  'right',
#  'delay',
#  'index',
#  'representing',
#  'how',
#  'although',
#  'coding',
#  'priority',
#  'driver',
#  'codes',
#  'stage',
#  'detailed',
#  'maximum',
#  'supplied',
#  'sending',
#  'formed',
#  'distributed',
#  'threshold',
#  'job',
#  'update',
#  'shape',
#  'string',
#  'printed',
#  'place',
#  'suitable',
#  'monitor',
#  'modules',
#  'alternatively',
#  'still',
#  'initial',
#  '60',
#  'return',
#  'encoding',
#  'generates',
#  'them',
#  'less',
#  'cycle',
#  'counter',
#  'furthermore',
#  'claims',
#  'documents',
#  'receiver',
#  'combination',
#  'registers',
#  'action',
#  'transmits',
#  'carried',
#  'unique',
#  'parallel',
#  'entity',
#  'master',
#  'calculation',
#  'computing',
#  'equal',
#  '101',
#  '42',
#  'selects',
#  'specifically',
#  'hand',
#  'programming',
#  'resources',
#  'match',
#  'managing',
#  'terminals',
#  'material',
#  'see',
#  'problem',
#  'obtain',
#  'updated',
#  'words',
#  'url',
#  'instance',
#  'send',
#  'pc',
#  'four',
#  'together',
#  'i/o',
#  'scanning',
#  'ram',
#  'moving',
#  'represents',
#  'sample',
#  '%',
#  'public',
#  'changed',
#  'areas',
#  'several',
#  'camera',
#  'representation',
#  'motion',
#  'actual',
#  'body',
#  'relates',
#  'represented',
#  'vector',
#  'tool',
#  'basic',
#  'create',
#  'found',
#  '300',
#  'returns',
#  'flag',
#  'party',
#  'enable',
#  'existing',
#  'sales',
#  'k',
#  'home',
#  'fields',
#  'buyer',
#  'calculating',
#  'symbol',
#  'called',
#  'patent',
#  'decision',
#  '36',
#  'bank',
#  'correction',
#  'subject',
#  'graphical',
#  'entered',
#  'directory',
#  'primary',
#  'matching',
#  'medical',
#  'creating',
#  'rules',
#  'transactions',
#  'presented',
#  't',
#  'monitoring',
#  'arrangement',
#  'completed',
#  'contained',
#  'greater',
#  'drawings',
#  'retrieval',
#  'board',
#  'chip',
#  'real',
#  'fourth',
#  'scope',
#  'layout',
#  'comparison',
#  'terms',
#  'due',
#  'history',
#  'active',
#  'pointer',
#  'left',
#  'p',
#  'small',
#  'here',
#  '106',
#  'tag',
#  'goods',
#  'tree',
#  'gate',
#  'exchange',
#  'proceeds',
#  'inputs',
#  'per',
#  'corresponds',
#  '--',
#  'version',
#  'domain',
#  'relative',
#  'every',
#  'password',
#  'routine',
#  'again',
#  'extracted',
#  'last',
#  'relationship',
#  'characteristics',
#  'compression',
#  'forth',
#  'separate',
#  'claimed',
#  'particularly',
#  'discussed',
#  'attributes',
#  'html',
#  'algorithm',
#  'becomes',
#  'implementation',
#  '27',
#  'j',
#  'option',
#  'commands',
#  'controlled',
#  'e',
#  'arranged',
#  'architecture',
#  'offer',
#  'complete',
#  '112',
#  'characteristic',
#  'semiconductor',
#  'fixed',
#  'functional',
#  'scan',
#  'transmit',
#  'encoded',
#  'identify',
#  'copy',
#  'context',
#  'shared',
#  'making',
#  'comprise',
#  'networks',
#  'higher',
#  'normal',
#  '33',
#  'automatic',
#  'controls',
#  '52',
#  'already',
#  'row',
#  'cells',
#  'reception',
#  '210',
#  '44',
#  'alternative',
#  'u.s.',
#  'what',
#  'serial',
#  '130',
#  'interest',
#  'reader',
#  'collection',
#  'potential',
#  'scanner',
#  'series',
#  'were',
#  'taken',
#  'market',
#  'report',
#  'hard',
#  'writing',
#  'previous',
#  'explained',
#  'skilled',
#  'needed',
#  'authentication',
#  'branch',
#  'relating',
#  'noted',
#  'circuits',
#  'specification',
#  'able',
#  'later',
#  'drawing',
#  'graphics',
#  'modified',
#  'queue',
#  'execute',
#  'category',
#  'rule',
#  'dynamic',
#  'regarding',
#  'indicate',
#  'term',
#  'locations',
#  'accessed',
#  'recognition',
#  'r',
#  '202',
#  'minimum',
#  'quality',
#  'depending',
#  'f',
#  'criteria',
#  'ic',
#  '108',
#  'merchant',
#  'template',
#  'count',
#  'session',
#  'examples',
#  'contact',
#  'placed',
#  'entire',
#  'contain',
#  'makes',
#  'understood',
#  'seller',
#  'effect',
#  'reduced',
#  'otherwise',
#  'schematic',
#  'top',
#  'details',
#  'obtaining',
#  '41',
#  'generator',
#  'switching',
#  'schedule',
#  'links',
#  'packets',
#  'compressed',
#  'bid',
#  'rom',
#  'portions',
#  'binary',
#  'subsequent',
#  'peripheral',
#  'attached',
#  'header',
#  'magnetic',
#  '35',
#  'readable',
#  'interrupt',
#  'accessing',
#  'notification',
#  'ratio',
#  'voice',
#  'purpose',
#  'his',
#  'resolution',
#  'events',
#  'technology',
#  'evaluation',
#  'employed',
#  'incorporated',
#  'limit',
#  'variety',
#  'similarly',
#  'divided',
#  'groups',
#  'long',
#  'become',
#  'patterns',
#  'techniques',
#  'e.g',
#  '29',
#  'definition',
#  ...]

# %%
#TEXT_DATA_DIR = BASE_DIR + '/20_newsgroup/'
MAX_SEQUENCE_LENGTH = 1000
MAX_NB_WORDS = 20000
EMBEDDING_DIM = 100
VALIDATION_SPLIT = 0.2

# %%
# Replace below with lines to get patent data



# second, prepare text samples and their labels
print('Processing text dataset')

texts = []  # list of text samples
labels_index = {}  # dictionary mapping label name to numeric id
labels = []  # list of label ids
for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        label_id = len(labels_index)
        labels_index[name] = label_id
        for fname in sorted(os.listdir(path)):
            if fname.isdigit():
                fpath = os.path.join(path, fname)
                if sys.version_info < (3,):
                    f = open(fpath)
                else:
                    f = open(fpath, encoding='latin-1')
                t = f.read()
                i = t.find('\n\n')  # skip header
                if 0 < i:
                    t = t[i:]
                texts.append(t)
                f.close()
                labels.append(label_id)

print('Found %s texts.' % len(texts))

# %%
# finally, vectorize the text samples into a 2D integer tensor
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Replace word_index 

data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)

labels = to_categorical(np.asarray(labels))
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', labels.shape)

# split the data into a training set and a validation set
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]
num_validation_samples = int(VALIDATION_SPLIT * data.shape[0])

x_train = data[:-num_validation_samples]
y_train = labels[:-num_validation_samples]
x_val = data[-num_validation_samples:]
y_val = labels[-num_validation_samples:]

# %%
print('Preparing embedding matrix.')

# prepare embedding matrix
num_words = min(MAX_NB_WORDS, len(word_index))
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

print('Training model.')

# %%
# train a 1D convnet with global maxpooling
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)
x = Conv1D(128, 5, activation='relu')(embedded_sequences)
x = MaxPooling1D(5)(x)
x = Conv1D(128, 5, activation='relu')(x)
x = MaxPooling1D(5)(x)
x = Conv1D(128, 5, activation='relu')(x)
x = MaxPooling1D(35)(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
preds = Dense(len(labels_index), activation='softmax')(x)

model = Model(sequence_input, preds)
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['acc'])

model.fit(x_train, y_train,
          batch_size=128,
          epochs=10,
          validation_data=(x_val, y_val))
