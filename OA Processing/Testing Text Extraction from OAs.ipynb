# %% [markdown]
# # Testing Textract (Functions) on OAs
#
# Here we look at extracting text information from PDF versions of office actions.

# %% [markdown]
# Textract is my preference but there appear to be issues when installing for Python 3. I can replicate the Textract PDF parsing functions here.

# %%
import os

# %%
import subprocess

def run(args):
    """ Run subprocess """
    pipe = subprocess.Popen(
                args,
                stdout=subprocess.PIPE, stderr=subprocess.PIPE,
            )
    stdout, stderr = pipe.communicate()
    return stdout, stderr

# %%
filename = 'OAs-OCR/06.06.2017 - Art 94(3).pdf'
args = ['pdftotext', filename, '-']

s, err = run(args)
print(s.decode("UTF-8"))
# Out:
# Europaisches
# Patentamt
#
# European Patent Office
# 80298 MUNICH
# GERMANY
# Tel: +49 89 2399 0
# Fax: +49 89 2399 4465
#
# European
# Patent Office
# Office europeen
# des brevets
#
# Formalities Officer
# Name: Abadie, Nathalie
# Tel: +49 89 2399 - 2746
# or call
# +31 (0)70 340 45 00
#
# Illllll lllll lllll lllll 111111111111111111111111111111111
# Zimmermann, Tankred Klaus
# Schoppe, Zimmermann, St6ckeler
# Zinkler, Schenk & Partner mbB
# Patentanwalte
# Radlkoferstrasse 2
# 81373 Munchen
# ALLEMAGNE
#
# Substantive Examiner
# Name: Peller, Ingrid
# Tel: +49 89 2399 - 7016
#
# L
#
# _J
#
# Application No.
#
# Ref.
#
# Date
#
# 13 883 570.7 - 1958
#
# HP130403PEP
#
# 06.06.2017
#
# I
#
# I
#
# Applicant
#
# Hewlett Packard Enterprise Development LP
#
# Communication pursuant to Article 94(3) EPC
# The examination of the above-identified application has revealed that it does not meet the requirements of the
# European Patent Convention for the reasons enclosed herewith. If the deficiencies indicated are not rectified
# the application may be refused pursuant to Article 97(2) EPC.
# You are invited to file your observations and insofar as the deficiencies are such as to be rectifiable, to correct
# the indicated deficiencies within a period
# of
#
# 4
#
# months
#
# from the notification of this communication, this period being computed in accordance with Rules 126(2) and
# 131(2) and (4) EPC. One set of amendments to the description, claims and drawings is to be filed within the
# said period on separate sheets (R. 50(1) EPC).
# If filing amendments, you must identify them and indicate the basis for them in the application as filed. Failure
# to meet either requirement may lead to a communication from the Examining Division requesting that you
# correct this deficiency (R. 137(4) EPC).
# In case you withdraw the application within the above-mentioned period, the examination fee will be refunded
# at a rate of 50% (Art. 11 (b) RFees).
# Failure to comply with this invitation in due time will result in the application being deemed to be
# withdrawn (Art. 94(4) EPC).
#
# Registered letter
# EPO Form 2001 11.16TRI
#
# Date 06.06.2017
#
# Sheet 2
#
# Peller, Ingrid
# Primary Examiner
# For the Examining Division
# Enclosure(s):
#
# Registered letter
# EPO Form 2001 11.16TRI
#
# 6 page/s reasons (Form 2906)
# US-8346777-B1
#
# Application No.: 13 883 570.7
#
# Datum
# Date
# Date
#
# 06.06.2017
#
# Blatt
# Sheet
# Feuille
#
# 1
#
# Anmelde-Nr:
# Application No:
# Demande n°:
#
# 13 8 8 3 5 7 0 . 7
#
# The examination is being carried out on the following application documents
# Description, Pages
#
# 1-16
#
# as published
#
# Claims, Numbers
#
# 1-15
#
# filed in electronic form on
#
# 15-02-2017
#
# Drawings, Sheets
#
# 1/4-4/4
#
# as published
#
# The following documents have been cited in the international search report; the
# numbering will be adhered to in the rest of the procedure.
# D1
#
# US 7 424 646 B2 (SMITH ALAN RAY) 9 September 2008 (2008-09-09)
#
# D2
#
# US 8 260 773 B2 (JENNINGS, Ill RAYMOND B. ET AL.) 4 September
# 2012 (2012-09-04)
#
# D3
#
# US 2008/154897 A 1 (MELIHA YETISGEN YILDIZ ET AL.) 26 June 2008
# (2008-06-26)
#
# D4
#
# US 7 849 030 B2 (ELLINGSWORTH MARTIN E.) 7 December 2010
# (201 0-12-07)
#
# The following document is cited by the Examiner. A copy of the document is annexed
# to the communication and the numbering will be adhered to in the rest of the
# procedure.
# D5
#
# US 8 346 777 B1 (AUERBACH DAVID BENJAMIN [US] ET AL) 1
# January 2013 (2013-01-01)
#
# EPO Form 2906 01 .91TRI
#
# Datum
# Date
# Date
#
# 1
#
# 06.06.2017
#
# Blatt
# Sheet
# Feuille
#
# 2
#
# Anmelde-Nr:
# Application No:
# Demande n°:
#
# 13 8 8 3 5 7 0 . 7
#
# Applicant arguments
#
# The applicant explained that the present invention permits to acknowledge
# the effective occurrence of an event which is scheduled in a calendar
# application a presented that "the present invention permits to link a calendar
# application with the effective occurrence of events with the calendar" as the
# alleged technical problem. The examiner is of the opinion that a calendar
# application is a piece of software, which is subject-matter excluded from
# patentability. To link the occurrence of events to a calendar is not regarded as
# a technical, but an administrative problem.
# The applicant pointed to paragraph [0021] the "sensing feature" which permits
# to detect either the position of a client device, or its motion or the presence of
# other client devices. The examiner is of the opinion that from paragraph
# [0021] it is clear that all technical means used for this "sensing feature" are
# integrated in any smart phone ("Here sensing feature may include a
# positioning feature that utilizes GPS, Wi-Fi, or other radio communication for
# triangulation. Sensing feature may also include short range wireless
# communication such as NFC (Near Field Communication) such that signal
# detection from another client device indicates relatively close proximity
# between the two. in another example, sensing feature may include the client
# device's microphone such that captured audible signals can be compared to
# audible signals captured by other client devices. When the audible signals
# captured by two or more devices match, it can be presumed that those client
# devices are in proximity and that a meeting is occurring. The device state is
# one in which the device's captured audible signal matches the audible signal
# captured by another device."). No details about the implementation or the
# technical difficulties arising can be found in the application. The examiner
# assumes the person skilled in the art would know how to implement this
# sensing feature. The examiner cited 05 as an example for smart phones as
# part of a general purpose network computer system.
#
# 2
#
# Article 56 EPC
#
# 2.1
#
# Claim 1
# Reading the claim in light of the description (see paragraph [0016] or Fig. 2) it
# is clear that the claim is of technical character in so far the subject-matter of
# the claim is directed to a memory having instructions to be executed by a
# processing resource. It is however clear from the whole application that the
# technical infrastructure employed amounts to no more than a general
#
# EPO Form 2906 01 .91TRI
#
# Datum
# Date
# Date
#
# 06.06.2017
#
# Blatt
# Sheet
# Feuille
#
# 3
#
# Anmelde-Nr:
# Application No:
# Demande n°:
#
# 13 8 8 3 5 7 0 . 7
#
# purpose networked computer system that was standard and well-known at
# the priority date of the application. No technical details beyond the mention of
# the use of common-place communication and data processing means are to
# be found in the application.
# To sense is not a technical feature per se. To implement sensing of a device
# in a technical environment is regarded as technical, but as can be seen from
# the description in paragraph [0021], the implementation is done with known
# technical means, which are contained in any smartphone. What the
# environmental sensing feature is is not disclosed in the application. The
# examiner assumes that the environmental sensing feature is only a synonym
# to the sensing feature.
# The non-technical features of claim 1 appear to be
# a memory resource storing instructions that 'Nhen e)(ecuted cause a
# processing resource (88) to implement a system for recording an unstructured
# event in context, the instructions comprising:
# an occurrence module (92) for detecting an occurrence of an event by
# identifying a first condition at a first time and a second condition at a second
# time, the first and second conditions indicative of a start and end of the event
# and identified utilizing a sensing feature (58) of a client device (46 50),
# wherein the sensing feature (58) is an environmental sensing feature for use
# in detecting at least one a position of the client device, motion of the client
# device, and a continued presence of other client devices;
# an activity module (90) for maintaining device activity data associated with a
# time period defined by the first and second times, the device activity data
# defining an event context; and
# an object module (94) for generating an event object for the time period, the
# event object including or otherwise associated with the device activity data.
# and define an abstract administrative method as such as it defines only steps
# for recording data.
# The method defines an abstract idea and is devoid of any technical
# consideration and therefore, when considered on its own, falls under the list
# of exclusions from patentability under Article 52(2) and (3) EPC.
# The technical character of the claim resides in that the data processing steps
# necessary for recording an unstructured event in context are executed by
# general purpose networked computer.
#
# EPO Form 2906 01 .91TRI
#
# Datum
# Date
# Date
#
# 06.06.2017
#
# Blatt
# Sheet
# Feuille
#
# 4
#
# Anmelde-Nr:
# Application No:
# Demande n°:
#
# 13 8 8 3 5 7 0 . 7
#
# Thus, the technical features of the claim amount to the definition of a general
# purpose networked computer system performing one of its commonly known
# functions.
# The application does not describe any technical interaction between the
# apparent non-technical features and the technical features presented above.
# Nor does the examiner identify any implicit technical inter-relationship. That is,
# the features of the method do not interact in any way with the group of
# remaining features of the claim (general purpose networked computer
# system) to alter the technical character of that general purpose networked
# computer system. Therefore the group of features defining the administrative
# method are considered to be non-technical.
# Such a general purpose networked computer system was so well known
# before the priority date of the present application as not to require written
# evidence. An example for smart phones having a calendar application and
# being capable of storing event data, forming part of a general purpose
# network computer system can be found in 05, Abstract, or Fig. 1 and
# description column 3-4.
# The closest prior art is therefore considered to be a general purpose
# networked computer system from which the subject-matter of claim 1 differs
# through the method described above running on that computer system.
# Features which cannot be seen to make any contribution, either
# independently or in combination with other features, to the solution of a
# technical problem are not relevant for assessing inventive step. The abstract
# administrative method described above is therefore not relevant for assessing
# inventive step. Therefore, it is necessary to examine what technical problem
# the skilled person, starting from a general purpose networked computer
# system, would encounter in order to arrive at the claimed subject-matter
# (Guidelines G-Vll, 5.4.1).
# The person skilled in the art of data processing would consider the
# implementation of non-technical methods in a computer system to be part of
# his daily work and therefore would consider it obvious to attempt to implement
# the abstract administrative method above in a general purpose networked
# computer system when presented with the method, for example, in the form
# of a requirements specification requesting the automation of the method.
# The application does not describe any problem to be solved. The application
# does also not give a definition for an "unstructured event in context".
#
# EPO Form 2906 01 .91TRI
#
# Datum
# Date
# Date
#
# 06.06.2017
#
# Blatt
# Sheet
# Feuille
#
# 5
#
# Anmelde-Nr:
# Application No:
# Demande n°:
#
# 13 8 8 3 5 7 0 . 7
#
# Further, the claimed subject-matter describes the use of technical features
# associated with a computerised non-technical process rather than describing
# the characteristics of the technical features themselves (e.g the particular
# technical features of the technical system that solve a particular technical
# problem). The claimed subject-matter merely describes what is to be
# accomplished by using known technology and remains independent of any
# particular technical implementation of the non-technical method. The
# examiner considers that the claimed subject-matter does not describe a
# combination of technical features that solve any technical problem.
# For the reasons given above, the examiner is unable to derive any technical
# problem from the claimed subject-matter. Indeed, the skilled person would
# translate the non-technical method into a general purpose networked
# computer system through use of standard data processing techniques as part
# of his normal daily work without encountering any technical problem. He
# would therefore arrive at the subject-matter of claim 1 without making an
# inventive step (Article 56 EPC).
# 2.2
#
# Independent claim 6 defines a system for performing the above abstract
# administrative method. Therefore the same objections arise. The subjectmatter of independent claim 6 does not involve an inventive step, contrary to
# the requirements of Article 56 EPC.
#
# 2.3
#
# Independent claim 11 defines the above abstract administrative method.
# Reading the claim in light of the description it is assumed that the method is
# running on a computer system. Therefore the same objections arise. The
# subject-matter of independent claim 11 does not involve an inventive step,
# contrary to the requirements of Article 56 EPC.
#
# 2.4
#
# The dependent claims do not appear to contain any additional features which,
# in combination with the features of any claim to which they refer, meet the
# requirements of the EPC with respect to inventive step, because the
# additional features relate either to commonly known general purpose
# networked computer system features and/or only to abstract administrative
# aspects.
#
# EPO Form 2906 01 .91TRI
#
# Datum
# Date
# Date
#
# 3
#
# 06.06.2017
#
# Blatt
# Sheet
# Feuille
#
# 6
#
# Anmelde-Nr:
# Application No:
# Demande n°:
#
# 13 8 8 3 5 7 0 . 7
#
# It is not at present apparent which part of the application could serve as a
# basis for a new, allowable claim. At least some of the objections raised above
# are such that there appears to be no possibility of overcoming them by
# amendment. Refusal of the application under Article 97(2) EPC is therefore to
# be expected.
# The Applicant is reminded of the possibility to request a decision according to
# the state of the file, pursuant to the Guidelines, cf. Guidelines C-V, 15.1. The
# decision according to Guidelines C-V, 15.1 is appealable. If the Applicant
# wishes to have such an appealable decision, the request shall be submitted in
# written form and accompanied by a withdrawal of the request of oral
# proceedings.
#
# EPO Form 2906 01 .91TRI

# %%
text = s.decode("UTF-8")
print(text[0:100])
# Out:
# Europaisches
# Patentamt
#
# European Patent Office
# 80298 MUNICH
# GERMANY
# Tel: +49 89 2399 0
# Fax: +49 89 2

# %%
import shutil
import six
from tempfile import mkdtemp

def extract_tesseract(filename):
    """Extract text from pdfs using tesseract (per-page OCR)."""
    temp_dir = mkdtemp()
    base = os.path.join(temp_dir, 'conv')
    contents = []
    try:
        stdout, _ = run(['pdftoppm', filename, base])

        for page in sorted(os.listdir(temp_dir)):
            page_path = os.path.join(temp_dir, page)
            page_content = run(['tesseract', page_path, 'stdout'])
            # Page content appears to be returning a tuple with a second blank b' '
            contents.append(page_content[0])
        return six.b('').join(contents).decode("UTF-8")
    finally:
        shutil.rmtree(temp_dir)

# %%
filename_nonocr = 'OAs/Search Opinion Positive.pdf'
text = extract_tesseract(filename_nonocr)

# %%
text
# Out:
# 'Eulopllxzhu European Paienl Oliice\npmmm\n\n80298 MUNiCH\n5:13:31.“ GERMANY\nUV?!" wwphn Tel. +49 (0)89 2395 - 0\n\n \n\ndo: mm:\n\nFax +49 (0)39 2399 , 4465\n\n|l|||||||||| l|||| llllllllll l||l| l|||| l||l|| lllll l||| 0,3..me\n\nName: Nesciobeili, Kainrzyne\nFlutter, Paula Tel 4790\n\n   \n\nEIP \' or call:\nFairfax House RECEiVED +31(0)70 340 45 00\n15 Fuiwood Place\n\nLondon\nGreater London WC1V6 U 1 1 MAY 2012\nROYAUME UNI\n\n  \n    \n\n”1.:\n\nEIF’\n\n \n\n—2012\n\n \n\n   \n  \n\ne arenas - Applismiun NcJFmen! No.\n\nE1338.800(F),EP 11160714 9 - 2224 / 2372552\n\npplicAnVProprielor\nIron Mountain |ncorporaied\n\n \n\n \n\n \n\nBRIEF COMMUNICATION\n\nSubiect: [N Ycurlerterof 05.04.2012\nEl Our telephone conversation of\n\n[:1 Communication of\n\nE]\n\nEncloeure(s): D Letter from the proprietor of the patent of\nEl Copy (copies)\nm Communication:\n\nPlease be informed that the European Search Opinion accompanying the European Search Report\ndated September 7, 2011 is indeed a positive one therefore contrary to the Invitation pursuant to\nRule 70a(1) EPC dated October 10,2011 no response thereto is required.\n\nPlease accepx our apologies for any inconvenience caused\n\nPlease take note‘\n\nFor the Examining Division\n\nas Pawn,\nQ4» *7/12,\n\n0? \'6‘\nK 6\na? e\na\n- m\ne g\n2 1:\n°\' 3:\n5 n:\na; 3\n,o o\n\no E?\n99% . ‘9‘\nme mm\n\nEl Registered letter\nepo Farms” 1207 (04/05/12) KT50794\n\n'

# %%
filename2 = 'OAs/06.06.2017 - Art 94(3).pdf'
text2 = extract_tesseract(filename2)
print(text2)
# Out:
# Eulopllsches
# menu-m European Patent Otllce
#
#
#
# 5...”... 50298 MUNlCH
#
# new ofﬁce GERMANY
#
# wkuumym Tel +49 as 2399 a
#
# des brevets Fax +49 89 2399 4465
#
# F 7 Formlities onicer
#
# Name Abadie,NathalIe
# Tel +49 89 2399 - 2746
# or Call
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# . ‘31 070 340 45 00
# Zimmermann, Tankred Klaus ( ’
#
# Schoppe. Zimmermann, Stockeler . .
# Zinkler, Schenk & Partner mbB i:%i":':'§i§.5ﬁ;ﬂ§“e'
# Patentanwﬁne Tel +49 89 2399 , 7015
# Radlkoferstrasse 2
#
# 81373 Miinchen
#
#
#
#
#
#
#
#
#
# ALLEMAGNE
# L 4
# Application No Rel Date
# 13 883 570.7 - 1958 HP130403PEP 06.06.2017
# Applicant
# Hewlett Packard Enterprise Development LP
#
#
#
#
#
#
#
# Communication pursuant to Article 94(3) EPC
#
# The examination of the above-identified application has revealed that it does not meet the requirements of the
# European Patent Convention for the reasons enclosed herewith. If the deficiencies indicated are not rectified
# the application may be refused pursuant to Article 97(2) EPC.
#
# You are invited to file your observations and insofar as the deficiencies are such as to be rectifiable, to correct
# the indicated deficiencies within a period
#
# of 4 months
#
# from the notification of this communication. this period being computed in accordance with Rules 126(2) and
# 131(2) and (4) EPC. One set of amendments to the description, claims and drawings is to be filed within the
# said period on separate sheets (R. 50(1) EPC).
#
# lf filing amendments, you must identify them and indicate the basis for them in the application as filed. Failure
# to meet either requirement may lead to a communication from the Examining Division requesting that you
# correct this deficiency (R. 137(4) EPC).
#
# In case you withdraw the application within the above-mentioned period, the examination fee will be refunded
# at a rate of 50% (Art. 11 (b) RFees).
#
# Failure to comply with this invitation in due time will result in the application being deemed to be
# withdrawn (Art. 94(4) EPC).
#
#
#
# Registered letter
#
# EPC Form 20m 11 16YRl
#
# Date 06.06.2017 Sheet 2 Application No.: 13 883 570.7
#
# “a!“ Parana?”
#
# $ .
# V
# s“ ‘2
# w %
# ' i
# ..
# 3 i
# 5 a
# 3 a
# % §
# .o
# o, N
#
# a
# ”‘71": acme ‘
#
# Peller. Ingrid
# Primary Examiner
# For the Examining Division
#
# Enclosure(s): 6 page/s reasons (Form 2906)
# US-8346777-B1
#
#
#
# Registered lener
#
# EPO Form 20m ii iGYRi
#
# Datum Elan Anmelde-Nr:
# Date 06.06.2017 Sheet 1 AppllcatlonNo: 13 883 570.7
# Date Feullle Demande n“:
#
#
#
# The examination is being carried out on the following application documents
#
# Description, Pages
#
# 1-16 as published
#
# Claims, Numbers
# 1-15 filed in electronic form on 15-02-2017
#
# Drawings, Sheets
# 1/4-4/4 as published
#
# The following documents have been cited in the international search report; the
# numbering will be adhered to in the rest of the procedure.
#
# D1 US 7 424 646 B2 (SMITH ALAN RAY) 9 September 2008 (2008-09-09)
#
# D2 US 8 260 773 B2 (JENNINGS, ||| RAYMOND B. ET AL.) 4 September
# 2012 (2012-09-04)
#
# D3 US 2008/154897 A1 (MELIHA YETISGEN YILDIZ ET AL.) 26 June 2008
# (2008-06-26)
#
# D4 us 7 849 030 32 (ELLINGSWORTH MARTIN E.) 7 December 2010
# (2010-12-07)
#
# The following document is cited by the Examiner. A copy of the document is annexed
# to the communication and the numbering will be adhered to in the rest of the
# procedure.
#
# D5 US 8 346 777 Bi (AUERBACH DAVID BENJAMIN [US] ET AL) 1
# January 2013 (2013-01-01)
#
#
#
# EPO Form 2905 DI stTRi
#
# Datum Blatt Anmelde-Nr:
#
#
#
# Date 06.06.2017 Sheet 2 AppllcatlonNo: 13 883 570.7
# Date Feullle Demande n“:
# 1 Applicant arguments
#
# The applicant explained that the present invention permits to acknowledge
# the effective occurrence of an event which is scheduled in a calendar
# application a presented that "the present invention permits to link a calendar
# application with the effective occurrence of events with the calendar" as the
# alleged technical problem. The examiner is of the opinion that a calendar
# application is a piece of software, which is subject-matter excluded from
# patentability. To link the occurrence of events to a calendar is not regarded as
# atechnical, but an administrative problem.
#
# The applicant pointed to paragraph [0021] the "sensing feature" which permits
# to detect either the position of a client device, or its motion or the presence of
# other client devices. The examiner is of the opinion that from paragraph
# [0021] it is clear that all technical means used for this "sensing feature“ are
# integrated in any smart phone (“Here sensing feature may include a
# positioning feature that utilizes GPS, Wi-Fi, or other radio communication for
# triangulation. Sensing feature may also include short range wireless
# communication such as NFC (Near Field Communication) such that signal
# detection from another client device indicates relatively close proximity
# between the two. in another example, sensing feature may include the client
# device's microphone such that captured audible signals can be compared to
# audible signals captured by other client devices. When the audible signals
# captured by two or more devices match, it can be presumed that those client
# devices are in proximity and that a meeting is occurring. The device state is
# one in which the device's captured audible signal matches the audible signal
# captured by another device“). No details about the implementation or the
# technical difficulties arising can be found in the application. The examiner
# assumes the person skilled in the art would know how to implement this
# sensing feature. The examiner cited D5 as an example for smart phones as
# part of a general purpose network computer system.
#
# 2 Article 56 EPC
# 2.1 Claim 1
#
# Reading the claim in light of the description (see paragraph [0016] or Fig. 2) it
# is clear that the claim is of technical character in so far the subject-matter of
# the claim is directed to a memory having instructions to be executed by a
# processing resource. It is however clear from the whole application that the
# technical infrastructure employed amounts to no more than a general
#
#
#
# EPO Form 2906 0191TFll
#
# Datum Blatt Anmelde-Nr:
# Date 06.06.2017 Sheet 3 AppllcatlonNo: 13 883 570.7
# Date Feullle Demands n“:
#
# purpose networked computer system that was standard and well-known at
# the priority date of the application. No technical details beyond the mention of
# the use of common-place communication and data processing means are to
# be found in the application.
#
# To sense is not a technical feature per se. To implement sensing of a device
# in a technical environment is regarded as technical, but as can be seen from
# the description in paragraph [0021], the implementation is done with known
# technical means, which are contained in any smartphone. What the
# environmental sensing feature is is not disclosed in the application. The
# examiner assumes that the environmental sensing feature is only a synonym
# to the sensing feature.
#
# The non-technical features of claim 1 appear to be
#
# amemeryeseurcsteringinstrutiensthatwhenexcutcd ausea
# preeeesing—Fesetaree-(sa—te—implement—a—eystem—fer recording an unstructured
#
# event in context, the instructions comprising:
#
# an—eeeerrenee—medule—(sa—fer detecting an occurrence of an event by
#
# identifying a first condition at a first time and a second condition at a second
# time, the first and second conditions indicative of a start and end of the event
#
# and identified ante-mg a sensing feature—(68) ef—a c—lient devise (46—59),
#
#
#
#
#
#
#
# an—aetMty—meelule—QeHer maIntaInIng device actIVIty data associated with a
#
# time period defined by the first and second times, the device activity data
# defining an event context; and
#
# an—ebjeet—meelule—(QQ—fer generating an event object for the time period, the
#
# event object including or otherwise associated with the device activity data.
#
# and define an abstract administrative method as such as it defines only steps
# for recording data.
#
# The method defines an abstract idea and is devoid of any technical
# consideration and therefore, when considered on its own, falls under the list
# of exclusions from patentability under Article 52(2) and (3) EPC.
#
# The technical character of the claim resides in that the data processing steps
# necessary for recording an unstructured event in context are executed by
# general purpose networked computer.
#
# EPO Form 2906 or etTFiI
#
# Datum Elan Anmelde-Nr:
# Date 06.06.2017 Sheet 4 ApplicationNo: 13 883 570.7
# Date Feullle Demande n“:
#
#
#
# Thus, the technical features of the claim amount to the definition of a general
# purpose networked computer system performing one of its commonly known
# functions.
#
# The application does not describe any technical interaction between the
# apparent non-technical features and the technical features presented above.
# Nor does the examiner identify any implicit technical inter-relationship. That is,
# the features of the method do not interact in any way with the group of
# remaining features of the claim (general purpose networked computer
# system) to alter the technical character of that general purpose networked
# computer system. Therefore the group of features defining the administrative
# method are considered to be non-technical.
#
# Such a general purpose networked computer system was so well known
# before the priority date of the present application as not to require written
# evidence. An example for smart phones having a calendar application and
# being capable of storing event data, forming part of a general purpose
# network computer system can be found in D5, Abstract, or Fig. 1 and
# description column 3-4.
#
# The closest prior art is therefore considered to be a general purpose
# networked computer system from which the subject-matter of claim 1 differs
# through the method described above running on that computer system.
#
# Features which cannot be seen to make any contribution, either
# independently or in combination with other features, to the solution of a
# technical problem are not relevant for assessing inventive step. The abstract
# administrative method described above is therefore not relevant for assessing
# inventive step. Therefore, it is necessary to examine what technical problem
# the skilled person, starting from a general purpose networked computer
# system, would encounter in order to arrive at the claimed subject-matter
# (Guidelines G-Vll, 5.4.1 ).
#
# The person skilled in the art of data processing would consider the
# implementation of non-technical methods in a computer system to be part of
# his daily work and therefore would consider it obvious to attempt to implement
# the abstract administrative method above in a general purpose networked
# computer system when presented with the method, for example, in the form
# of a requirements specification requesting the automation of the method.
#
# The application does not describe any problem to be solved. The application
# does also not give a definition for an “unstructured event in context".
#
#
#
# EPO Form 2905 DI QlTRl
#
# Datum Blatt Anmelde-Nr:
# Date 06.06.2017 Sheet 5 AppllcatlonNo: 13 883 570.7
# Date Feullle Demande n“:
#
#
#
# Further, the claimed subject-matter describes the use of technical features
# associated with a computerised non-technical process rather than describing
# the characteristics of the technical features themselves (e.g the particular
# technical features of the technical system that solve a particular technical
# problem). The claimed subject-matter merely describes what is to be
# accomplished by using known technology and remains independent of any
# particular technical implementation of the non-technical method. The
# examiner considers that the claimed subject-matter does not describe a
# combination of technical features that solve any technical problem.
#
# For the reasons given above, the examiner is unable to derive any technical
# problem from the claimed subject-matter. Indeed, the skilled person would
# translate the non-technical method into a general purpose networked
# computer system through use of standard data processing techniques as part
# of his normal daily work without encountering any technical problem. He
# would therefore arrive at the subject-matter of claim 1 without making an
# inventive step (Article 56 EPC).
#
# 2.2 Independent claim 6 defines a system for performing the above abstract
# administrative method. Therefore the same objections arise. The subject-
# matter of independent claim 6 does not involve an inventive step, contrary to
# the requirements of Article 56 EPC.
#
# 2.3 Independent claim 11 defines the above abstract administrative method.
# Reading the claim in light of the description it is assumed that the method is
# running on a computer system. Therefore the same objections arise. The
# subject-matter of independent claim 11 does not involve an inventive step,
# contrary to the requirements of Article 56 EPC.
#
# 2.4 The dependent claims do not appear to contain any additional features which.
# in combination with the features of any claim to which they refer, meet the
# requirements of the EPC with respect to inventive step, because the
# additional features relate either to commonly known general purpose
# networked computer system features and/or only to abstract administrative
# aspects.
#
#
#
# EPO Form 2905 Of 91TRI
#
# Datum Elan Anmelde-Nr:
#
#
#
# Date 06.06.2017 Sheet 6 ApplicationNo: 13 883 570.7
# Date Feullle Demande n“:
# 3 It is not at present apparent which part of the application could serve as a
#
# basis for a new. allowable claim. At least some of the objections raised above
# are such that there appears to be no possibility of overcoming them by
# amendment. Refusal of the application under Article 97(2) EPC is therefore to
# be expected.
#
# The Applicant is reminded of the possibility to request a decision according to
# the state of the file, pursuant to the Guidelines, cf. Guidelines C-V. 15.1. The
# decision according to Guidelines C-V, 15.1 is appealable. If the Applicant
# wishes to have such an appealable decision, the request shall be submitted in
# written form and accompanied by a withdrawal of the request of oral
# proceedings.
#
#
#
# EPO Form 2906 01911111

# %%
# Make a cleaner function
def get_text_from_pdf(ocred_pdf):
    """ Extract text from an OCRed PDF file called ocred_pdf"""
    args = ['pdftotext', ocred_pdf, '-']
    pipe = subprocess.Popen(
                args,
                stdout=subprocess.PIPE, stderr=subprocess.PIPE,
            )
    stdout, stderr = pipe.communicate()
    return stdout.decode("UTF-8")

# %%
ocred_pdf = os.listdir("OAs-OCR")[0]
print(ocred_pdf)
# Out:
# Article 94(3) EPC(2).pdf

# %%
get_text_from_pdf()
# Out:
# ''

# %% [markdown]
# ## Get Test Data
#
# Let's process the folders of example OAs to get a set of OA text to use for testing. We can get text for each of the already OCRed data and the Tesseract OCR data. Any cleaning functions should work on both.
#
# For now we'll use a simple dictionary to hold the data (we can build an object class later).

# %%
# Start with pre-ocred files - these will be faster
import pickle

filename = 'ocr_text.pkl'
folder = "OAs-OCR"

if os.path.isfile(filename):
    with open(filename, 'rb') as f:
        ocr_text = pickle.load(f)
else:
    ocrfiles = os.listdir(folder)
    
    # Generate a dict with the filename as key - we can iterate through later using items
    ocr_text = dict()
    for file in ocrfiles:
        ocr_text[file] = get_text_from_pdf(os.path.join(folder,file))
        
    with open(filename, 'wb') as f:
        pickle.dump(ocr_text, f)
# Out:
# OAs-OCR/Article 94(3) EPC(2).pdf
# OAs-OCR/Search Report(12).pdf
# OAs-OCR/2016-5-18 - Search report.pdf
# OAs-OCR/Extended Search Report(1).pdf
# OAs-OCR/Response to Art 94(3) EPC(4).pdf
# OAs-OCR/Response to Supplementary Search Report(2).pdf
# OAs-OCR/2016-08-26 - Search Report.pdf
# OAs-OCR/Article 94(3) EPC(3).pdf
# OAs-OCR/2016-11-23 - Article 94(3) EPC.pdf
# OAs-OCR/2016-06-20 - Search Report.pdf
# OAs-OCR/2016-05-04 - Search report(1).pdf
# OAs-OCR/11-07-2016 - Search Report.pdf
# OAs-OCR/Article 94(3) EPC(27).pdf
# OAs-OCR/Search Report(13).pdf
# OAs-OCR/Further Processing Notice (Exam Report).pdf
# OAs-OCR/Response to Article 94(3)(5).pdf
# OAs-OCR/Response to Article 94(3)(4).pdf
# OAs-OCR/Article 94(3)EPC(7).pdf
# OAs-OCR/Response to Article 94(3)(8).pdf
# OAs-OCR/Response to Art 94(3) as filed(1).pdf
# OAs-OCR/Article 94(3) EPC(5).pdf
# OAs-OCR/Search Report(21).pdf
# OAs-OCR/Response to Article 94(3) as filed(4).pdf
# OAs-OCR/Response to Art. 94(3) EPC(1).pdf
# OAs-OCR/2017-06-21 - Search Report.pdf
# OAs-OCR/Search Report(27).pdf
# OAs-OCR/Response to Exam Report(1).pdf
# OAs-OCR/Extended Search Report.pdf
# OAs-OCR/2016-12-06 - Search Report.pdf
# OAs-OCR/2017-02-28 - Article 94(3) EPC.pdf
# OAs-OCR/2017-08-08 - Article 94(3) EPC.pdf
# OAs-OCR/2016-10-12 - Article 94(3) EPC.pdf
# OAs-OCR/Search Report(22).pdf
# OAs-OCR/Response to Article 94(3)(7).pdf
# OAs-OCR/Response to Search Opinion(6).pdf
# OAs-OCR/Response to Search Opinion(7).pdf
# OAs-OCR/2017-06-19 - Search Report.pdf
# OAs-OCR/Search Report(36).pdf
# OAs-OCR/2017-07-04 - Article 94(3) EPC.pdf
# OAs-OCR/Article 94(3) EPC(12).pdf
# OAs-OCR/Response to Article 94(3) as filed(3).pdf
# OAs-OCR/Supplementary Search Report(4).pdf
# OAs-OCR/2016-08-17 - Article 94(3)EPC.pdf
# OAs-OCR/Search Report(24).pdf
# OAs-OCR/2016-4-18 - Search report.pdf
# OAs-OCR/Article 94(3) EPC(24).pdf
# OAs-OCR/Article 94(3) EPC(13).pdf
# OAs-OCR/Search report(4).pdf
# OAs-OCR/Response to Article 94(3)(1).pdf
# OAs-OCR/Response to Exam Report(2).pdf
# OAs-OCR/2017-01-25 - Search Report.pdf
# OAs-OCR/2017-06-26 - Search Report.pdf
# OAs-OCR/Search Report(10).pdf
# OAs-OCR/Response to Search Opinion(2).pdf
# OAs-OCR/Search Report(33).pdf
# OAs-OCR/2017-08-24 - Article 94(3) EPC.pdf
# OAs-OCR/Response to Search Opinion(10).pdf
# OAs-OCR/Response to Loss of Rights (Supp Search).pdf
# OAs-OCR/Article 94(3)EPC(1).pdf
# OAs-OCR/Search Opinion Positive.pdf
# OAs-OCR/Response to Search Report as Filed.pdf
# OAs-OCR/Search Report(26).pdf
# OAs-OCR/Article 94(3)(2).pdf
# OAs-OCR/Article 94(3) EPC(10).pdf
# OAs-OCR/Response to Search Opinion(9).pdf
# OAs-OCR/2016-11-01 Article 94(3) EPC.pdf
# OAs-OCR/Response to Supplementary Search Report.pdf
# OAs-OCR/Search report(3).pdf
# OAs-OCR/28.07.2016 - Supplementary Search Report.pdf
# OAs-OCR/Search Report(20).pdf
# OAs-OCR/2016-06-16 - Search Report.pdf
# OAs-OCR/Response to Supplementary Search(1).pdf
# OAs-OCR/Search report(2).pdf
# OAs-OCR/2016-08-30 - Search Report.pdf
# OAs-OCR/Article 94(3) EPC(16).pdf
# OAs-OCR/Article 94(3) EPC(22).pdf
# OAs-OCR/Response to Search Opinion(1).pdf
# OAs-OCR/Response to Art 94(3) EPC(6).pdf
# OAs-OCR/Response to Exam Report(3).pdf
# OAs-OCR/Search Report(7).pdf
# OAs-OCR/Article 94(3) EPC(21).pdf
# OAs-OCR/Article 94(3) EPC(11).pdf
# OAs-OCR/Article 94(3) EPC(9).pdf
# OAs-OCR/Response to Supplementary Search Opinion.pdf
# OAs-OCR/2016-11-14 - Search Report.pdf
# OAs-OCR/Response Re Enquiry Re Issuance of Exam Report.pdf
# OAs-OCR/Search Report(35).pdf
# OAs-OCR/Article 94(3)EPC(3).pdf
# OAs-OCR/E1335.700(T).EP - Search Report.pdf
# OAs-OCR/Article 94(3)EPC.pdf
# OAs-OCR/Search Report(19).pdf
# OAs-OCR/Response to Exam Report(4).pdf
# OAs-OCR/Article 94(3) EPC(6).pdf
# OAs-OCR/Search Report(11).pdf
# OAs-OCR/Article 94(3) EPC(8).pdf
# OAs-OCR/2016-10-13 - Search Report.pdf
# OAs-OCR/Search Report(16).pdf
# OAs-OCR/Article 94(3)EPC(8).pdf
# OAs-OCR/2016-09-27 - Search Report.pdf
# OAs-OCR/Response to Article 94(3) EPC.pdf
# OAs-OCR/Response to Search Opinion and Filing of General Authorisation.pdf
# OAs-OCR/2016-10-20 - Search Report.pdf
# OAs-OCR/Search Report(34).pdf
# OAs-OCR/Search Report(17).pdf
# OAs-OCR/Article 94(3) EPC(4).pdf
# OAs-OCR/2016-10-14 - Search Report..pdf
# OAs-OCR/Article 94(3) EPC(23).pdf
# OAs-OCR/Article 94(3) EPC(25).pdf
# OAs-OCR/Response to Art 94(3) as filed.pdf
# OAs-OCR/Response to Art 94(3) EPC.pdf
# OAs-OCR/2016-10-05 - Search Report.pdf
# OAs-OCR/Response to Art 94(3) EPC(5).pdf
# OAs-OCR/2016-11-07 - Search Report.pdf
# OAs-OCR/Response to Exam Report(7).pdf
# OAs-OCR/2017-06-16- Article 94(3)EPC.pdf
# OAs-OCR/Response to Article 94(3).pdf
# OAs-OCR/Supplementary Search Report.pdf
# OAs-OCR/Response to Supplementary Search.pdf
# OAs-OCR/2016-5-16 - Article 94(3)EPC.pdf
# OAs-OCR/Response to Exam Report(6).pdf
# OAs-OCR/2017-05-20 - Article 94(3) EPC.pdf
# OAs-OCR/Article 94(3) EPC(18).pdf
# OAs-OCR/Search Report(28).pdf
# OAs-OCR/2016-09-02 - Search Report.pdf
# OAs-OCR/Article 94(3) EPC(26).pdf
# OAs-OCR/2016-5-24 - Search report.pdf
# OAs-OCR/Search Report(31).pdf
# OAs-OCR/2017-09-01 - Article 94(3) EPC.pdf
# OAs-OCR/Search Report(32).pdf
# OAs-OCR/Search Report(30).pdf
# OAs-OCR/Art. 94(3).pdf
# OAs-OCR/Article 94(3) EPC.pdf
# OAs-OCR/2017-04-04 - Article 94(3) EPC.pdf
# OAs-OCR/Response to Search Opinion as filed.pdf
# OAs-OCR/2017-08-02 - Search Report.pdf
# OAs-OCR/2016-09-22 - Search Report.pdf
# OAs-OCR/Supplementary Search Report(3).pdf
# OAs-OCR/Search Report(18).pdf
# OAs-OCR/Search Report(23).pdf
# OAs-OCR/Response to Art. 94(3) EPC.pdf
# OAs-OCR/Article 94(3) EPC(15).pdf
# OAs-OCR/Search Report(29).pdf
# OAs-OCR/2017-06-23 - Search Report.pdf
# OAs-OCR/2016-08-26 - Article 94(3) EPC.pdf
# OAs-OCR/2016-11-28 - Article 94(3) EPC.pdf
# OAs-OCR/Search Report(8).pdf
# OAs-OCR/2017-02-07- Article 94(3)EPC.pdf
# OAs-OCR/Article 94(3)EPC(2).pdf
# OAs-OCR/2017-06-28 - Search Report.pdf
# OAs-OCR/2016-05-04 - Search report.pdf
# OAs-OCR/2017-01-23- Article 94(3) EPC.pdf
# OAs-OCR/Response to Supplementary Search Opinion(1).pdf
# OAs-OCR/Article 94(3)EPC(5).pdf
# OAs-OCR/Response to A94(3).pdf
# OAs-OCR/01-07-2016 - Article 94(3).EPC.txt
# OAs-OCR/Response to Search Opinion(11).pdf
# OAs-OCR/Article 94(3).pdf
# OAs-OCR/Response to Art. 94(3) EPC(2).pdf
# OAs-OCR/2017-02-21 - Search Report.pdf
# OAs-OCR/Search Report(14).pdf
# OAs-OCR/Response to Article 94(3) as filed.pdf
# OAs-OCR/Search Report.pdf
# OAs-OCR/Article 94(3) EPC(19).pdf
# OAs-OCR/2017-04-28 - Search Report.pdf
# OAs-OCR/2017-09-08- Search Report.pdf
# OAs-OCR/Search report(6).pdf
# OAs-OCR/Search report(1).pdf
# OAs-OCR/01-07-2016 - Article 94(3).EPC.pdf
# OAs-OCR/2017-01-05 - Search Report.pdf
# OAs-OCR/Response to Exam Report(5).pdf
# OAs-OCR/Supplementary Search Report(1).pdf
# OAs-OCR/2016-10-12 - Search Report.pdf
# OAs-OCR/Response to Article 94(3) as filed(1).pdf
# OAs-OCR/Article 94(3) EPC (1).pdf
# OAs-OCR/Article 94(3) EPC(1).pdf
# OAs-OCR/2017-01-04 - Article 94(3) EPC.pdf
# OAs-OCR/Article 94(3) and Rule 71(1).pdf
# OAs-OCR/2016-10-27 - Search Report.pdf
# OAs-OCR/Article 94(3)(1).pdf
# OAs-OCR/Response to Supplementary Search Report(3).pdf
# OAs-OCR/Response to Search Opinion.pdf
# OAs-OCR/Response to extended European Search Report.pdf
# OAs-OCR/06.06.2017 - Art 94(3).pdf
# OAs-OCR/Response to Article 94(3)(6).pdf
# OAs-OCR/Response to Search Opinion(4).pdf
# OAs-OCR/Search Report(25).pdf
# OAs-OCR/2017-04-28 - Search Report(1).pdf
# OAs-OCR/Response to Exam Report(8).pdf
# OAs-OCR/Response to Article 94(3)(2).pdf
# OAs-OCR/Article 94(3) EPC(20).pdf
# OAs-OCR/18-07-2016 - Article 94(3)EPC.pdf
# OAs-OCR/Article 94(3)EPC(9).pdf
# OAs-OCR/Search report(5).pdf
# OAs-OCR/Response to Art 94(3) EPC(2).pdf
# OAs-OCR/Search Opinion.pdf
# OAs-OCR/Response to Art 94(3)(1).pdf
# OAs-OCR/Response to Exam Report.pdf
# OAs-OCR/Response to Article 94(3) as filed(2).pdf
# OAs-OCR/Article 94(3) EPC(14).pdf
# OAs-OCR/2017-04-19 - Search Report.pdf
# OAs-OCR/Response to Search Opinion(5).pdf
# OAs-OCR/2017-07-18 - Article 94(3) EPC.pdf
# OAs-OCR/2016-10-07 - Search Report.pdf
# OAs-OCR/Enquiry RE Issuance of Search Report.pdf
# OAs-OCR/Search Report(9).pdf
# OAs-OCR/Response to A94(3) EPC.pdf
# OAs-OCR/Article 94(3)EPC(4).pdf
# OAs-OCR/Response to enquiry re issuance of exam report.pdf
# OAs-OCR/Article 94(3) EPC(7).pdf
# OAs-OCR/2015-07-13 Response to Search Opinion.pdf
# OAs-OCR/2017-07-17 - Article 94(3) EPC.pdf
# OAs-OCR/Response to Supplementary Search Report(4).pdf
# OAs-OCR/Search Report(15).pdf
# OAs-OCR/2016-08-22 - Search Report.pdf
# OAs-OCR/Response to Search Opinion(8).pdf
# OAs-OCR/Response to Supplementary Search Report(1).pdf
# OAs-OCR/2016-08-18 - Article 94(3) EPC.pdf
# OAs-OCR/Response to Article 94(3)(3).pdf
# OAs-OCR/2016-04-15 - Search report.pdf
# OAs-OCR/Article 94(3)EPC(6).pdf
# OAs-OCR/Response to A94(3) as filed.pdf
# OAs-OCR/Response to Art 94(3) EPC(3).pdf
# OAs-OCR/Article 94(3) EPC(17).pdf
# OAs-OCR/Response to Art 94(3).pdf
# OAs-OCR/Supplementary Search Report(2).pdf
# OAs-OCR/Response to Art 94(3) EPC(1).pdf
# OAs-OCR/Response to Search Opinion(3).pdf

# %%
ocr_text['2016-08-18 - Article 94(3) EPC.pdf']
# Out:
# 'European Patent Office\nPos1bus 5818\n2280 HV Rijswijk\nNETHERLANDS\nTel: +31 70 340 2040\nFax: +31 70 340 3016\n\nEuropaisches\nPatentamt\nEuropean\nPatent Office\nOffice europeen\ndes brevets\n\nFormalities Officer\nName: Sogno-Pabis, E\nTel: +31 70 340 - 2414\nor call\n+31 (0)70 340 45 00\n\nI llllll lllll lllll lllll 111111111111111111111111111111111\nMccann, Heather Alison\nEIP\nFairfax House\n15 Fulwood Place\nLondon WC1 V 6HU\nROYAUME-UNI\n\nSubstantive Examiner\nName: Bassanini, Anna\nTel: +31 70 340 - 2036\n\nApplication No.\n\nRef.\n\nDale\n\n07 844 381.9 - 1955\n\nE1129.651 (T)EPW\n\n18.08.2016\n\nApplicant\n\nTrading Technologies International, Inc.\n\nCommunication pursuant to Article 94(3) EPC\nThe examination of the above-identified application has revealed that it does not meet the requirements of the\nEuropean Patent Convention for the reasons enclosed herewith. If the deficiencies indicated are not rectified\nthe application may be refused pursuant to Article 97(2) EPC.\nYou are invited to file your observations and insofar as the deficiencies are such as to be rectifiable, to correct\nthe indicated deficiencies within a period\nof\n\n4\n\nmonths\n\nfrom the notification of this communication, this period being computed in accordance with Rules 126(2) and\n131(2) and (4) EPC. One set of amendments to the description, claims and drawings is to be filed within the\nsaid period on separate sheets (R. 50( 1) E PC).\nIf filing amendments, you must identify them and indicate the basis for them in the application as filed. Failure\nto meet either requirement may lead to a communication from the Examining Division requesting that you\ncorrect this deficiency (R. 137(4) EPC).\nFailure to comply with this invitation in due time will result in the application being deemed to be\nwithdrawn (Art. 94(4) EPC).\n\nRegistered letter\nEPO Form 2001 12.1ocsx\n\n\x0cDate 18.08.2016\n\nSheet 2\n\nBassanini, Anna\nPrimary Examiner\nFor the Examining Division\nEnclosure(s):\n\nRegistered letter\nEPO Form 2001 12.1 OCSX\n\n8 page/s reasons (Form 2906)\nUS-20060085320-A 1 , US-20040193526-A 1\n\nApplication No.: 07 844 381.9\n\n\x0cDatum\nDate\nDate\n\nAnmelde-Nr:\n\nBlatt\n\n18.08.2016\n\nSheet\nFeuille\n\n1\n\nApplication No:\nDemande n°:\n\n07 844 381. 9\n\nThe examination is being carried out on the following application documents\n\nDescription, Pages\n\n1-23\n\nas published\n\nClaims, Numbers\n\n1-24\n\nfiled in electronic form on\n\n20-06-2012\n\nDrawings, Sheets\n\n1/3-3/3\n\n1\n\nas published\n\nThe following documents are cited by the division. A copy of the documents is\nannexed to the communication and the numbering will be adhered to in the\nrest of the procedure.\n\n01\n\nUS 2006/085320 A 1 (OWENS FARLEY [US] ET AL) 20 April\n2006 (2006-04-20)\n\n02\n\nUS 2004/193526 A 1 (SINGER SCOTT F [US] ET AL) 30\nSeptember 2004 (2004-09-30)\n\n2\n\nAMENDMENTS (ARTICLE 123(2) EPC)\n\n2.1\n\nThe amended claims filed on 20.06.2012 appear to meet the requirements of\nArticle 123(2) EPC.\n\n3\n\nINVENTIVE STEP (ARTICLE 56 EPC)\n\n3.1\n\nThe present application does not meet the requirements of Article 52(1) EPC\nbecause the subject-matter of claims 1-24 does not involve an inventive step\nin the sense of Article 56 EPC.\n\nEPO Form 2906 01 .91TRI\n\n\x0cD~e\nDate\n\nAnmelde-Nr:\n\nBlatt\n\nDatum\n\n18.08.2016\n\nSheet\nFeuille\n\n2\n\nApplication No:\nDemands n°:\n\n0 7 8 4 4 3 81 . 9\n\n3.2\n\nThe subject-matter of the claims relates to processes comprised in the list of\nsubject-matter and activities excluded from patentability under Art. 52(2) and\n(3) EPC. In accordance with the established practice of the EPO, no search\nneed be performed in respect of those aspects of the claimed invention.\n\n3.3\n\nThe only identifiable technical aspects of the claimed invention are deemed to\nrelate to the use of standard data processing technology that was commonly\nknown and used in the business framework of the application at its date of\n ...

# %%
# Now the files we have ocred

filename = 'nonocr_text.pkl'
folder = "OAs"

if os.path.isfile(filename):
    with open(filename, 'rb') as f:
        nonocr_text = pickle.load(f)
else:
    nonocrfiles = os.listdir(folder)
    
    # Generate a dict with the filename as key - we can iterate through later using items
    nonocr_text = dict()
    for file in nonocrfiles:
        nonocr_text[file] = extract_tesseract(os.path.join(folder,file))
        
    with open(filename, 'wb') as f:
        pickle.dump(nonocr_text, f)

# %% [markdown]
# ## Cleaning EPO Office Action Data

# %% [markdown]
# ### Header Text
#
# We need to get rid of the text from the header of the letter.
#
# Basic heuristic - look for "\nEPO Form ... Date Feullle Demande n“:"

# %% [markdown]
# ```
# \n\nEPO Form 2906 01 .91TRI\n\n\x0cD~e\nDate\n\nAnmelde-Nr:\n\nBlatt\n\nDatum\n\n18.08.2016\n\nSheet\nFeuille\n\n8\n\nApplication No:\nDemande n°:\n\n0 7 8 4 4 3 81 . 9\n\n
# ```
# Can we look for "\n\n.?EPO Form*\[0-9].?\n\n"
# ```
# \n\n {0,3}EPO.*\d {0,3}\n\n
# ``` (but date has a number ending in two newlines)
#
# Need to remove headers before we remove newlines - as we may need the multiple newlines to spot the header.

# %% [markdown]
# ### Extra Newlines
#
# These can be stripped.

# %% [markdown]
# ### Garbage lines

# %%
def clean_letter_text(text):
    """ Cleans text from an OCRed office action. """
    pass

def strip_extra_newline(text):
    """ Strip extra newlines from text."""
    pass

def remove_header(text):
    """ Remove letter header text."""
    pass

# %% [markdown]
# ## Identifying Objections
#
# ### Naive Approach
# Just look for strings present in text - e.g. Article 56 EPC and "lack" or "contrary"
#
# ### Machine Learning Approach
# Label each office action. Use a bag of words classifier.

# %% [markdown]
# ## Identifying Legal Basis
#
# ### Naive Approach
# Just look for "Article 94(3)" in text. (May give false positives if reference is made to a previous communication.)
#
# Or look for line with string distance past a threshold with "Communication pursuant to Article 94(3) EPC"

# %%
text = ocr_text['2016-08-18 - Article 94(3) EPC.pdf']
print("94(3)" in text)
print("70(2)" in text)
# Out:
# True
# False

# %%
*Observations*

D1, D2 etc is sometimes extracted as 01, 02.

I am kind of doing sentiment analysis - I want to know if, for an objection, the office action is positive or negative. Do we extract text related to particular objections first then look at that subtext?



* Data to extract:
    * headings, paragraph numbers and paragraph text.
    * date of action (although could we get this from Register)
    * objections - which were outstanding and which were met
    * prior art (can we use regex at first?)
    * current state of application (e.g. pages as published or amended)
# Out:
#   File "<ipython-input-40-a5d848d3aa4e>", line 1
#     *Observations*
#                   ^
# SyntaxError: invalid syntax
