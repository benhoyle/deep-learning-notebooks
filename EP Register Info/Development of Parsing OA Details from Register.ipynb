# %% [markdown]
# # Developing Functions for EPO Register Retrieval
#
# Now let's build some data processing functions to strip out some of the noise from the returned data.
#
# These functions can be added to PatentData.
#
# We will retrieve XML because we can use Beautiful Soup to parse.

# %%
# Import OPS details
from epoops import EPOOPS_C_KEY, EPOOPS_C_SECRET

# Import BS4 for parsing
from bs4 import BeautifulSoup

# %%
import epo_ops

try:
    middlewares = [
                epo_ops.middlewares.Dogpile(),
                epo_ops.middlewares.Throttler(),
            ]
except:
    middlewares = [
                epo_ops.middlewares.Throttler()
            ]

client = epo_ops.Client(
            key=EPOOPS_C_KEY,
            secret=EPOOPS_C_SECRET,
            accept_type='xml',
            middlewares=middlewares)

# %% [markdown]
# ## Register Bibliographic Data
#
# From this we can get the applicant and representative on file.

# %%
publication_number = "EP2080165"
response = client.register(reference_type='publication', input=epo_ops.models.Epodoc(publication_number), constituents=['biblio'])

# %%
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <ops:world-patent-data xmlns:ops="http://ops.epo.org" xmlns:reg="http://www.epo.org/register" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:cpc="http://www.epo.org/cpcexport" xmlns:cpcdef="http://www.epo.org/cpcdefinition">
#     <ops:register-search total-result-count="1">
#         <ops:query syntax="CQL">publication=EP2080165</ops:query>
#         <ops:range begin="1" end="1"/>
#         <reg:register-documents produced-by="RO">
#             <reg:register-document date-produced="20170917" dtd-version="1.3.1" lang="en" produced-by="RO" status="The application has been withdrawn">
#                 <reg:ep-patent-statuses>
#                     <reg:ep-patent-status change-date="" status-code="9">The application has been withdrawn</reg:ep-patent-status>
#                 </reg:ep-patent-statuses>
#                 <reg:bibliographic-data country="EP" id="EP07844381P" lang="en" status="The application has been withdrawn">
#                     <reg:publication-reference change-gazette-num="2008/18">
#                         <reg:document-id lang="en">
#                             <reg:country>WO</reg:country>
#                             <reg:doc-number>2008051787</reg:doc-number>
#                             <reg:kind>A2</reg:kind>
#                             <reg:date>20080502</reg:date>
#                         </reg:document-id>
#                     </reg:publication-reference>
#                     <reg:publication-reference change-gazette-num="2009/30">
#                         <reg:document-id lang="en">
#                             <reg:country>EP</reg:country>
#                             <reg:doc-number>2080165</reg:doc-number>
#                             <reg:kind>A2</reg:kind>
#                             <reg:date>20090722</reg:date>
#                         </reg:document-id>
#                     </reg:publication-reference>
#                     <reg:classifications-ipcr change-date="20110826" change-gazette-num="2011/39">
#                         <reg:classification-ipcr id="CLASSIFICATION_13490616">
#                             <reg:text>G06Q30/00, G06Q40/00</reg:text>
#                         </reg:classification-ipcr>
#                     </reg:classifications-ipcr>
#                     <reg:classifications-ipcr change-date="20090619" change-gazette-num="2009/30">
#                         <reg:classification-ipcr id="CLASSIFICATION_13490617">
#                             <reg:text>G06Q40/00</reg:text>
#                         </reg:classification-ipcr>
#                     </reg:classifications-ipcr>
#                     <reg:application-reference change-gazette-num="2009/30">
#                         <reg:document-id>
#                             <reg:country>EP</reg:country>
#                             <reg:doc-number>07844381</reg:doc-number>
#                             <reg:date>20071018</reg:date>
#                         </reg:document-id>
#                     </reg:application-reference>
#                     <reg:application-reference>
#                         <reg:document-id>
#                             <reg:country>WO</reg:country>
#                             <reg:doc-number>WO2007US81749</reg:doc-number>
#                         </reg:document-id>
#                     </reg:application-reference>
#                     <reg:language-of-filing>en</reg:language-of-filing>
#                     <reg:priority-claims change-date="20090619" change-gazette-num="2009/30">
#                         <reg:priority-claim kind="national" sequence="1">
#                             <reg:country>US</reg:country>
#                             <reg:doc-number>20060551567</reg:doc-number>
#                             <reg:date>20061020</reg:date>
#                         </reg:priority-claim>
#                     </reg:priority-claims>
#                     <reg:parties>
#                         <reg:applicants change-date="20090619" change-gazette-num="N/P">
#                             <reg:applicant app-type="applicant" designation="all" sequence="1">
# <reg:addressbook cdsid="0101034879">
#     <reg:name>Trading Technologies International, Inc.</reg:name>
#     <reg:address>
#         <reg:address-1>222 S. Riverside Plaza, Suite 1100</reg:address-1>
#         <reg:address-2>Chicago, Illinois 60606</reg:address-2>
#         <reg:country>US</reg:country>
#     </reg:address>
# </reg:addressbook>
# <reg:nationality>
#     <reg:country></reg:country>
# </reg:nationality>
# <reg:residence>
#     <reg:country></reg:country>
# </reg:residence>
#                             </reg:applicant>
#                         </reg:applicants>
#                         <reg:applicants change-date="20090619" change-gazette-num="2009/30">
#                             <reg:applicant app-type="applicant" designation="all" sequence="1">
# <reg:addressbook cdsid="0101034879">
#     <reg:name>Trading Technologies International, Inc</reg:name>
#     <reg:address>
#         <reg:address-1>222 S. Riverside Plaza, Suite 1100</reg:address-1>
#         <reg:address-2>Chicago, Illinois 60606</reg:address-2>
#         <reg:country>US</reg:country>
#     </reg:address>
# </reg:addressbook>
# <reg:nationality>
#     <reg:country></reg:country>
# </reg:nationality>
# <reg:residence>
#     <reg:country></reg:country>
# </reg:residence>
#                             </reg:applicant>
#                         </reg:applicants>
#                         <reg:inventors change-date="20090619" change-gazette-num="2009/30">
#                             <reg:inventor sequence="01">
# <reg:addressbook>
#     <reg:name>DUQUETTE, Douglas R.</reg:name>
#     <reg:address>
#         <reg:address-1>1225 Colgate Street</reg:address-1>
#         <reg:address-2>Wilmette, IL 60091</reg:address-2>
#         <reg:country>US</reg:country>
#     </reg:address>
# </reg:addressbook>
#                             </reg:inventor>
#                             <reg:inventor sequence="02">
# <reg:addressbook>
#     <reg:name>WEST, Robert A.</reg:name>
#     <reg:address>
#         <reg:address-1>7059 North Wolcott</reg:address-1>
#         <reg:address-2>Chicago, IL 60626</reg:address-2>
#         <reg:country>US</reg:country>
#     </reg:address>
# </reg:addressbook>
#                             </reg:inventor>
#                         </reg:inventors>
#                         <reg:agents change-date="20100827" change-gazette-num="N/P">
#                             <reg:agent rep-type="agent" sequence="1">
# <reg:addressbook cdsid="0100989615">
#     <reg:name>McCann, Heather Alison, et al</reg:name>
#     <reg:address>
#         <reg:address-1>EIP</reg:address-1>
#         <reg:address-2>Fairfax House</reg:address-2>
#         <reg:address-3>15 Fulwood Place</reg:address-3>
#         <reg:address-4>London WC1V 6HU</reg:address-4>
#         <reg:country>GB</reg:country>
#     </reg:address>
# </reg:addressbook>
#                             </reg:agent>
#                         </reg:agents>
#                         <reg:agents change-date="20100827" change-gazette-num="2010/39">
#                             <reg:agent rep-type="agent" sequence="1">
# <reg:addressbook cdsid="0100989615">
#     <reg:name>McCann, Heather Alison, et al</reg:name>
#     <reg:address>
#         <reg:address-1>EIP Fairfax House 15 Fulwood Place</reg:address-1>
#         <reg:address-2>London WC1V 6HU</reg:address-2>
#         <reg:country>GB</reg:country>
#     </reg:address>
# </reg:addressbook>
#                             </reg:agent>
#                         </reg:agents>
#                         <reg:agents change-date="20090619" change-gazette-num="2009/30">
#                             <reg:agent rep-type="agent" sequence="1">
# <reg:addressbook cdsid="0100045376">
#     <reg:name>Walaski, Jan Filip, et al</reg:name>
#     <reg:address>
#         <reg:address-1>Venner Shipley LLP 20 Little Britain London</reg:address-1>
#         <reg:address-2>EC1A 7DH</reg:address-2>
#         <reg:country>GB</reg:country>
#     </reg:address>
# </reg:addressbook>
#                             </reg:agent>
#                         </reg:agents>
#                     </reg:parties>
#                     <reg:designation-of-states change-date="20090619" change-gazette-num="2009/30">
#                         <reg:designation-pct>
#                             <reg:regional>
# <reg:region>
#     <reg:country>EP</reg:country>
# </reg:region>
# <reg:country>AT</reg:country>
# <reg:country>BE</reg:country>
# <reg:country>BG</reg:country>
# <reg:country>CH</reg:country>
# <reg:country>CY</reg:country>
# <reg:country>CZ</reg:country>
# <reg:country>DE</reg:country>
# <reg:country>DK</reg:country>
# <reg:country>EE</reg:country>
# <reg:country>ES</reg:country>
# <reg:country>FI</reg:country>
# <reg:country>FR</reg:country>
# <reg:country>GB</reg:country>
# <reg:country>GR</reg:country>
# <reg:country>HU</reg:country>
# <reg:country>IE</reg:country>
# <reg:country>IS</reg:country>
# <reg:country>IT</reg:country>
# <reg:country>LI</reg:country>
# <reg:country>LT</reg:country>
# <reg:country>LU</reg:country>
# <reg:country>LV</reg:country>
# <reg:country>MC</reg:country>
# <reg:country>MT</reg:country>
# <reg:country>NL</reg:country>
# <reg:country>PL</reg:country>
# <reg:country>PT</reg:country>
# <reg:country>RO</reg:country>
# <reg:country>SE</reg:country>
# <reg:country>SI</reg:country>
# <reg:country>SK</reg:country>
# <reg:country>TR</reg:country>
#                             </reg:regional>
#                         </reg:designation-pct>
#                     </reg:designation-of-states>
#                     <reg:invention-title lang="de" change-date="20090619" change-gazette-num="2009/30">SYSTEM UND VERFAHREN FÜR PRIORISIERTE DATENLIEFERUNG IN EINER ELEKTRONISCHEN HANDELSUMGEBUNG</reg:invention-title>
#                     <reg:invention-title lang="fr" change-date="20090619" change-gazette-num="2009/30">SYSTÈME ET PROCÉDÉ DE DISTRIBUTION DE DONNÉES CLASSÉES PAR ORDRE DE PRIORITÉ DANS UN ENVIRONNEMENT DE COMMERCE ÉLECTRONIQUE</reg:invention-title>
#                     <reg:invention-title lang="en" change-date="20090619" change-gazette-num="2009/30">SYSTEM AND METHOD FOR PRIORITIZED DATA DELIVERY IN AN ELECTRONIC TRADING ENVIRONMENT</reg:invention-title>
#                     <reg:dates-rights-effective>
#                         <reg:request-for-examination change-gazette-num="2009/30">
#                             <reg:date>20090428</reg:date>
#                         </reg:request-for-examination>
#                         <reg:first-examination-report-despatched>
#                             <reg:date>20160818</reg:date>
#                         </reg:first-examination-report-despatched>
#                     </reg:dates-rights-effective>
#                     <reg:references-cited>
#                         <reg:citation id="cit_293097509" cited-phase="search" office="EP">
#                             <reg:nplcit>
# <reg:text>EPO, &quot;Mitteilung des Europäischen Patentamts vom 1. Oktober 2007 über Geschäftsmethoden = Notice from the European Patent Office dated 1 October 2007 concerning business methods = Communiqué de l'Office européen des brevets,en date du 1er octobre 2007, concernant les méthodes dans le domaine des activités&quot;, JOURNAL OFFICIEL DE L'OFFICE EUROPEEN DES BREVETS.OFFICIAL JOURNAL OF THE EUROPEAN PATENT OFFICE.AMTSBLATTT DES EUROPAEISCHEN PATENTAMTS, OEB, MUNCHEN, DE, (20071101), vol. 30, no. 11, ISSN 0170-9291, pages 592 - 593, XP007905525 [L] 1-14 * The claimed subject matter, with due regard to the description and drawings, relates to processes comprised in the list of subject matter and activities excluded from patentability under Art.52(2) and (3) EPC. The applicant is advised that in accordance with the established practice of the EPO, no search need be performed in respect of those aspects of the claimed invention.The only identifiable technical aspects of the claimed invention relate to the use of conventional, general-purpose data processing technology for processing data of an inherently non-technical nature. The information technology employed is considered to have been generally known as it was widely available to everyone at the date of filing/priority of the present application. The notoriety of such prior art cannot reasonably be contested. No documentary evidence was therefore considered required. *</reg:text>
#                             </reg:nplcit>
#                             <reg:category>L</reg:category>
#                         </reg:citation>
#                         <reg:citation id="cit_293097510" cited-phase="international-search-report" office="EP">
#                             <reg:patcit url="http://worldwide.espacenet.com/publicationDetails/biblio?CC=US&amp;NR=2007198397&amp;KC=&amp;locale=en_EP&amp;FT=E">
# <reg:document-id>
#     <reg:country>US</reg:country>
#     <reg:doc-number>2007198397</reg:doc-number>
# </reg:document-id>
# <reg:text>(MCGINLEY JOHN [GB], et al);</reg:text>
#                             </reg:patcit>
#                             <reg:category>PY</reg:category>
#                         </reg:citation>
#                         <reg:citation id="cit_293097511" cited-phase="international-search-report" office="EP">
#                             <reg:patcit url="http://worldwide.espacenet.com/publicationDetails/biblio?CC=US&amp;NR=7120113&amp;KC=&amp;locale=en_EP&amp;FT=E">
# <reg:document-id>
#     <reg:country>US</reg:country>
#     <reg:doc-number>7120113</reg:doc-number>
# </reg:document-id>
# <reg:text>(ZHANG SONG [US], et al);</reg:text>
#                             </reg:patcit>
#                             <reg:category>Y</reg:category>
#                         </reg:citation>
#                         <reg:citation id="cit_293097512" cited-phase="international-search-report" office="EP">
#                             <reg:patcit url="http://worldwide.espacenet.com/publicationDetails/biblio?CC=US&amp;NR=2006259399&amp;KC=&amp;locale=en_EP&amp;FT=E">
# <reg:document-id>
#     <reg:country>US</reg:country>
#     <reg:doc-number>2006259399</reg:doc-number>
# </reg:document-id>
# <reg:text>(MINTZ SAGY [US], et al);</reg:text>
#                             </reg:patcit>
#                             <reg:category>PY</reg:category>
#                         </reg:citation>
#                         <reg:citation id="cit_293097513" cited-phase="international-search-report" office="EP">
#                             <reg:patcit url="http://worldwide.espacenet.com/publicationDetails/biblio?CC=US&amp;NR=2007038549&amp;KC=&amp;locale=en_EP&amp;FT=E">
# <reg:document-id>
#     <reg:country>US</reg:country>
#     <reg:doc-number>2007038549</reg:doc-number>
# </reg:document-id>
# <reg:text>(JANOWSKI BRADEN S [US], et al);</reg:text>
#                             </reg:patcit>
#                             <reg:category>PY</reg:category>
#                         </reg:citation>
#                         <reg:citation id="cit_293097514" cited-phase="international-search-report" office="EP">
#                             <reg:patcit url="http://worldwide.espacenet.com/publicationDetails/biblio?CC=US&amp;NR=6732185&amp;KC=&amp;locale=en_EP&amp;FT=E">
# <reg:document-id>
#     <reg:country>US</reg:country>
#     <reg:doc-number>6732185</reg:doc-number>
# </reg:document-id>
# <reg:text>(REISTAD BRIAN [US]);</reg:text>
#                             </reg:patcit>
#                             <reg:category>Y</reg:category>
#                         </reg:citation>
#                         <reg:citation id="cit_293097515" cited-phase="international-search-report" office="EP">
#                             <reg:patcit url="http://worldwide.espacenet.com/publicationDetails/biblio?CC=US&amp;NR=2001049651&amp;KC=&amp;locale=en_EP&amp;FT=E">
# <reg:document-id>
#     <reg:country>US</reg:country>
#     <reg:doc-number>2001049651</reg:doc-number>
# </reg:document-id>
# <reg:text>(SELLECK MARK N [US]);</reg:text>
#                             </reg:patcit>
#                             <reg:category>Y</reg:category>
#                         </reg:citation>
#                         <reg:citation id="cit_293097516" cited-phase="international-search-report" office="EP">
#                             <reg:patcit url="http://worldwide.espacenet.com/publicationDetails/biblio?CC=US&amp;NR=5073180&amp;KC=&amp;locale=en_EP&amp;FT=E">
# <reg:document-id>
#     <reg:country>US</reg:country>
#     <reg:doc-number>5073180</reg:doc-number>
# </reg:document-id>
# <reg:text>(FAROOQ SHAJI [US], et al)</reg:text>
#                             </reg:patcit>
#                             <reg:category>Y</reg:category>
#                         </reg:citation>
#                     </reg:references-cited>
#                     <reg:date-application-withdrawn-by-applicant change-gazette-num="2016/45">
#                         <reg:date>20160930</reg:date>
#                     </reg:date-application-withdrawn-by-applicant>
#                     <reg:search-reports-information>
#                         <reg:search-report-information office="US" search-type="isr" declaration-of-no-search="not-determined" change-gazette-num="2008/18">
#                             <reg:search-report-publication>
# <reg:document-id lang="en">
#     <reg:country>WO</reg:country>
#     <reg:doc-number>2008051787</reg:doc-number>
#     <reg:kind>A2</reg:kind>
#     <reg:date>20080502</reg:date>
# </reg:document-id>
#                             </reg:search-report-publication>
#                         </reg:search-report-information>
#                         <reg:search-report-information office="EP" search-type="national-supplementary" declaration-of-no-search="not-determined">
#                             <reg:date-search-report-mailed>
# <reg:date>20111006</reg:date>
#                             </reg:date-search-report-mailed>
#                         </reg:search-report-information>
#                     </reg:search-reports-information>
#                 </reg:bibliographic-data>
#             </reg:register-document>
#         </reg:register-documents>
#     </ops:register-search>
# </ops:world-patent-data>

# %%
soup = BeautifulSoup(response.text, "xml")

# %%
# Need to narrow to applicants section first
applicant_sequence = soup.find("applicants")
print(applicant_sequence)
# Out:
# <reg:applicants change-date="20090619" change-gazette-num="N/P">
# <reg:applicant app-type="applicant" designation="all" sequence="1">
# <reg:addressbook cdsid="0101034879">
# <reg:name>Trading Technologies International, Inc.</reg:name>
# <reg:address>
# <reg:address-1>222 S. Riverside Plaza, Suite 1100</reg:address-1>
# <reg:address-2>Chicago, Illinois 60606</reg:address-2>
# <reg:country>US</reg:country>
# </reg:address>
# </reg:addressbook>
# <reg:nationality>
# <reg:country/>
# </reg:nationality>
# <reg:residence>
# <reg:country/>
# </reg:residence>
# </reg:applicant>
# </reg:applicants>

# %%
applicant_list = applicant_sequence.find_all('applicant')
print(applicant_list)
# Out:
# [<reg:applicant app-type="applicant" designation="all" sequence="1">
# <reg:addressbook cdsid="0101034879">
# <reg:name>Trading Technologies International, Inc.</reg:name>
# <reg:address>
# <reg:address-1>222 S. Riverside Plaza, Suite 1100</reg:address-1>
# <reg:address-2>Chicago, Illinois 60606</reg:address-2>
# <reg:country>US</reg:country>
# </reg:address>
# </reg:addressbook>
# <reg:nationality>
# <reg:country/>
# </reg:nationality>
# <reg:residence>
# <reg:country/>
# </reg:residence>
# </reg:applicant>]

# %%
# See here - https://stackoverflow.com/questions/26872311/using-beautifulsoup-to-parse-xml-to-a-dictionary
applicant_dict = {child.name: child.text for child in applicant_list[0].findChildren()}
print(applicant_dict)
# Out:
# {'residence': '\n\n', 'country': '', 'addressbook': '\nTrading Technologies International, Inc.\n\n222 S. Riverside Plaza, Suite 1100\nChicago, Illinois 60606\nUS\n\n', 'nationality': '\n\n', 'address': '\n222 S. Riverside Plaza, Suite 1100\nChicago, Illinois 60606\nUS\n', 'address-1': '222 S. Riverside Plaza, Suite 1100', 'address-2': 'Chicago, Illinois 60606', 'name': 'Trading Technologies International, Inc.'}

# %%
print(applicant_dict['name'], "\n", applicant_dict['address'])
# Out:
# Trading Technologies International, Inc.
#
# 222 S. Riverside Plaza, Suite 1100
# Chicago, Illinois 60606
# US

# %%
# Combining into a function
def get_applicant(client, number, numbertype='publication'):
    """ Return applicant details for an EP application."""
    #if numbertype == 'application':
        # number = self.get_publication_no(number, "EP")
    response = client.register(
            reference_type='publication',
            input=epo_ops.models.Epodoc(number),
            constituents=['biblio']
            )
    soup = BeautifulSoup(response.text, "xml")
    # Need to narrow to applicants section first
    applicant_sequence = soup.find("applicants")
    applicant_list = applicant_sequence.find_all('applicant')
    # This just returns the details for the first applicant
    # Check this is the most recent where changes have occurred
    applicant_dict = {
            child.name: child.text
            for child in applicant_list[0].findChildren()
            }
    return applicant_dict

# %%
ap = get_applicant(client, "EP123457")
print(ap['name'], "\n", ap['address'])
# Out:
# E. I. du Pont de Nemours and Company
#
# 1007 Market Street
# Wilmington, DE 19898
# US

# %%
# Adapt to get agent details - we can use a common parent function for this
def get_agent(client, number, numbertype='publication'):
    """ Return applicant details for an EP application."""
    #if numbertype == 'application':
        # number = self.get_publication_no(number, "EP")
    response = client.register(
            reference_type='publication',
            input=epo_ops.models.Epodoc(number),
            constituents=['biblio']
            )
    soup = BeautifulSoup(response.text, "xml")
    # Need to narrow to applicants section first
    applicant_sequence = soup.find("agents")
    applicant_list = applicant_sequence.find_all('agent')
    # This just returns the details for the first applicant
    # Check this is the most recent where changes have occurred
    applicant_dict = {
            child.name: child.text
            for child in applicant_list[0].findChildren()
            }
    return applicant_dict

# %%
ag = get_agent(client, "EP123457")
print(ag['name'], "\n", ag['address'])
# Out:
# Barnard, Eric Edward, et al
#
# Brookes Batchellor 102-108 Clerkenwell Road
# London EC1M 5SA
# GB

# %%
# General function to get applicant,inventor or agent details as list
def get_party_details(client, number, party, numbertype='publication'):
    """ Return applicant details for an EP application."""
    #if numbertype == 'application':
        # number = self.get_publication_no(number, "EP")
    response = client.register(
            reference_type='publication',
            input=epo_ops.models.Epodoc(number),
            constituents=['biblio']
            )
    soup = BeautifulSoup(response.text, "xml")
    # Need to narrow to applicants section first
    return [
        {
            child.name: child.text
            for child in entry.findChildren()
        }
        for entry in soup.find("{0}s".format(party)).find_all(party)
    ]

# %%
parties = get_party_details(client, "EP1234567", "agent")

# %%
parties
# Out:
# [{'address': '\nPartnerschaft von\nPatent- und Rechtsanwälten mbB\nBeselerstrasse 4\n22607 Hamburg\nDE\n',
#   'address-1': 'Partnerschaft von',
#   'address-2': 'Patent- und Rechtsanwälten mbB',
#   'address-3': 'Beselerstrasse 4',
#   'address-4': '22607 Hamburg',
#   'addressbook': '\nUexküll & Stolberg\n\nPartnerschaft von\nPatent- und Rechtsanwälten mbB\nBeselerstrasse 4\n22607 Hamburg\nDE\n\n',
#   'country': 'DE',
#   'name': 'Uexküll & Stolberg'}]

# %%
get_party_details(client, "EP1234567", "applicant")
# Out:
# [{'address': '\nBendererstrasse 2\n9494 Schaan\nLI\n',
#   'address-1': 'Bendererstrasse 2',
#   'address-2': '9494 Schaan',
#   'addressbook': '\nIvoclar Vivadent AG\n\nBendererstrasse 2\n9494 Schaan\nLI\n\n',
#   'country': '',
#   'name': 'Ivoclar Vivadent AG',
#   'nationality': '\n\n',
#   'residence': '\n\n'}]

# %% [markdown]
# ** Observations **
# * We could have an object per number to restrict multiple calls to the remote API - e.g. reg = EPRegister(number), reg.applicants > applicant list.
# * On init we fetch each of the three data sources.
# * We can use to quickly find the agents for a particular applicant - perform a search to get a number list per applicant and then send off register queries for each number.

# %% [markdown]
# ## Procedural Steps

# %%
publication_number = "EP2080165"
response2 = client.register(reference_type='publication', input=epo_ops.models.Epodoc(publication_number), constituents=['procedural-steps'])

# %%
print(response2.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <ops:world-patent-data xmlns:ops="http://ops.epo.org" xmlns:reg="http://www.epo.org/register" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:cpc="http://www.epo.org/cpcexport" xmlns:cpcdef="http://www.epo.org/cpcdefinition">
#     <ops:register-search total-result-count="1">
#         <ops:query syntax="CQL">publication=EP2080165</ops:query>
#         <ops:range begin="1" end="1"/>
#         <reg:register-documents produced-by="RO">
#             <reg:register-document date-produced="20170917" dtd-version="1.3.1" lang="en" produced-by="RO" status="The application has been withdrawn">
#                 <reg:ep-patent-statuses>
#                     <reg:ep-patent-status change-date="" status-code="9">The application has been withdrawn</reg:ep-patent-status>
#                 </reg:ep-patent-statuses>
#                 <reg:procedural-data>
#                     <reg:procedural-step id="RENEWAL_53183972" procedure-step-phase="undefined">
#                         <reg:procedural-step-code>RFEE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="YEAR">03</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20091026</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="RENEWAL_53183973" procedure-step-phase="undefined">
#                         <reg:procedural-step-code>RFEE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="YEAR">04</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20101025</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="RENEWAL_53183974" procedure-step-phase="undefined">
#                         <reg:procedural-step-code>RFEE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="YEAR">05</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20111025</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="RENEWAL_53183975" procedure-step-phase="undefined">
#                         <reg:procedural-step-code>RFEE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="YEAR">06</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20121025</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="RENEWAL_53183976" procedure-step-phase="undefined">
#                         <reg:procedural-step-code>RFEE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="YEAR">07</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20131028</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="RENEWAL_53183977" procedure-step-phase="undefined">
#                         <reg:procedural-step-code>RFEE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="YEAR">08</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20141027</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="RENEWAL_53183978" procedure-step-phase="undefined">
#                         <reg:procedural-step-code>RFEE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="YEAR">09</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20151027</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_21299536" procedure-step-phase="entry-regional-phase">
#                         <reg:procedural-step-code>FFEE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Payment of national basic fee</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20090428</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_21299537" procedure-step-phase="entry-regional-phase">
#                         <reg:procedural-step-code>SFEE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Payment of the fee for supplementary search</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20090428</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_21299538" procedure-step-phase="entry-regional-phase">
#                         <reg:procedural-step-code>DEST</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Payment of the first designation fee</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20090428</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_21299539" procedure-step-phase="entry-regional-phase">
#                         <reg:procedural-step-code>EXAM_PCT</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Payment of the fee for examination</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_PAYMENT">
#                             <reg:date>20090428</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_EXRE_11281116" procedure-step-phase="examination">
#                         <reg:procedural-step-code>EXRE</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Communication from the examining division</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_DISPATCH">
#                             <reg:date>20160818</reg:date>
#                         </reg:procedural-step-date>
#                         <reg:time-limit time-limit-unit="months">04</reg:time-limit>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_PROL_10501492" procedure-step-phase="examination">
#                         <reg:procedural-step-code>PROL</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Language of the procedure</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="procedure language">en</reg:procedural-step-text>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_ISAT_10445550" procedure-step-phase="entry-regional-phase">
#                         <reg:procedural-step-code>ISAT</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">International searching authority</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="searching authority">US</reg:procedural-step-text>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_ABEX_65178444" procedure-step-phase="examination">
#                         <reg:procedural-step-code>ABEX</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Amendments</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="Kind of amendment">(claims and/or description)</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_REQUEST">
#                             <reg:date>20120620</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_DDIV6347239" procedure-step-phase="examination">
#                         <reg:procedural-step-code>DDIV</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">First communication from the examining division</reg:procedural-step-text>
#                         <reg:procedural-step-text step-text-type="APPLICATION_NUMBER">07844381</reg:procedural-step-text>
#                         <reg:procedural-step-date step-date-type="DATE_OF_DISPATCH">
#                             <reg:date>20160818</reg:date>
#                         </reg:procedural-step-date>
#                     </reg:procedural-step>
#                     <reg:procedural-step id="STEP_IGRA_6175339" procedure-step-phase="examination">
#                         <reg:procedural-step-code>IGRA</reg:procedural-step-code>
#                         <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Intention to grant the patent</reg:procedural-step-text>
#                     </reg:procedural-step>
#                 </reg:procedural-data>
#             </reg:register-document>
#         </reg:register-documents>
#     </ops:register-search>
# </ops:world-patent-data>

# %%
soup2 = BeautifulSoup(response2.text, 'xml')

# %%
soup2.find_all("procedural-step-text")
# Out:
# [<reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="YEAR">03</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="YEAR">04</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="YEAR">05</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="YEAR">06</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="YEAR">07</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="YEAR">08</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Renewal fee payment</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="YEAR">09</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Payment of national basic fee</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Payment of the fee for supplementary search</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Payment of the first designation fee</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Payment of the fee for examination</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Communication from the examining division</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Language of the procedure</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="procedure language">en</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">International searching authority</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="searching authority">US</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Amendments</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="Kind of amendment">(claims and/or description)</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">First communication from the examining division</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="APPLICATION_NUMBER">07844381</reg:procedural-step-text>,
#  <reg:procedural-step-text step-text-type="STEP_DESCRIPTION">Intention to grant the patent</reg:procedural-step-text>]

# %% [markdown]
# ** Observations **
#
# This is like the front page register data. We want to look at (in particular), the "Examination Procedure" style information.
#
# There is a ```procedure-step-phase="examination"``` as an attribute for the tag - ```<procedural-step>```.

# %%
p_steps = [
        {
            child.name: child.text
            for child in step.findChildren()
        }
        for step in soup2.find_all(attrs={"procedure-step-phase":"examination"})
    ]

# %%
for s in p_steps:
    print(s, '\n')
# Out:
# {'date': '20160818', 'procedural-step-code': 'EXRE', 'time-limit': '04', 'procedural-step-text': 'Communication from the examining division', 'procedural-step-date': '\n20160818\n'}
#
# {'procedural-step-code': 'PROL', 'procedural-step-text': 'en'}
#
# {'date': '20120620', 'procedural-step-code': 'ABEX', 'procedural-step-text': '(claims and/or description)', 'procedural-step-date': '\n20120620\n'}
#
# {'date': '20160818', 'procedural-step-code': 'DDIV', 'procedural-step-text': '07844381', 'procedural-step-date': '\n20160818\n'}
#
# {'procedural-step-code': 'IGRA', 'procedural-step-text': 'Intention to grant the patent'}

# %% [markdown]
# Looking at the data I think I actually want "events" for examination events as set out below.

# %% [markdown]
# ## Events
#
# The following data would be useful:
# * Last office action (and is outstanding?).
# * History of office action and amendment.
# * Number of substantive office actions issued.
# * Number of susbtantive responses filed.

# %%
publication_number = "EP2080165"
response3 = client.register(reference_type='publication', input=epo_ops.models.Epodoc(publication_number), constituents=['events'])

# %%
print(response3.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <ops:world-patent-data xmlns:ops="http://ops.epo.org" xmlns:reg="http://www.epo.org/register" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:cpc="http://www.epo.org/cpcexport" xmlns:cpcdef="http://www.epo.org/cpcdefinition">
#     <ops:register-search total-result-count="1">
#         <ops:query syntax="CQL">publication=EP2080165</ops:query>
#         <ops:range begin="1" end="1"/>
#         <reg:register-documents produced-by="RO">
#             <reg:register-document date-produced="20170917" dtd-version="1.3.1" lang="en" produced-by="RO" status="The application has been withdrawn">
#                 <reg:ep-patent-statuses>
#                     <reg:ep-patent-status change-date="" status-code="9">The application has been withdrawn</reg:ep-patent-status>
#                 </reg:ep-patent-statuses>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507527" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20161007</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0009182</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Withdrawal of application</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2016/45</reg:gazette-num>
#                             <reg:date>20161109</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507528" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20160826</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOSNEXR2</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">New entry: Despatch of examination report + time limit</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507529" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20160819</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0009185</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">First examination report</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2016/38</reg:gazette-num>
#                             <reg:date>20160921</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507530" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20151103</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOSNRFE2</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507531" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20141030</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOSNRFE2</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507532" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20131105</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOSNRFE2</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507533" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20121030</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOSNRFE2</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507534" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20120622</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOS ABEX</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Amendment by applicant</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507535" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20111223</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0009199ENDS</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Change - date of supplementary search report</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2012/04</reg:gazette-num>
#                             <reg:date>20120125</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507536" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20111028</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOSNRFE2</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507537" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20110826</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0009016</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Supplementary search report</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2011/39</reg:gazette-num>
#                             <reg:date>20110928</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507538" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20110826</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0008199IPCL</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Change - classification</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2011/39</reg:gazette-num>
#                             <reg:date>20110928</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507539" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20110826</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0008199OBSC</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Change - classification</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2011/39</reg:gazette-num>
#                             <reg:date>20110928</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507540" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20101029</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOSNRFE2</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507541" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20100827</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0009199FREP</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Change - representative</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2010/39</reg:gazette-num>
#                             <reg:date>20100929</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507542" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20091225</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0009199EXPT</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Change - extension states</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2010/04</reg:gazette-num>
#                             <reg:date>20100127</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507543" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20091029</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOSNRFE2</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507544" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20090715</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOS ABEX</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Amendment by applicant</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507545" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20090619</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0009012</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Publication in section I.1 EP Bulletin</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2009/30</reg:gazette-num>
#                             <reg:date>20090722</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507546" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20090619</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>0009171</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">Request for examination filed</reg:event-text>
#                         <reg:gazette-reference>
#                             <reg:gazette-num>2009/30</reg:gazette-num>
#                             <reg:date>20090722</reg:date>
#                         </reg:gazette-reference>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507547" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20090529</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOS PCT</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507548" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20090511</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOS PCT</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507549" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20090428</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOS PCT</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507550" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20090129</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOS PCT</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507551" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20080516</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOS PCT</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507552" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20080510</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOS PCT</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#                 <reg:events-data>
#                     <reg:dossier-event id="EVT_275507553" event-type="new">
#                         <reg:event-date>
#                             <reg:date>20080104</reg:date>
#                         </reg:event-date>
#                         <reg:event-code>EPIDOS PCT</reg:event-code>
#                         <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
#                     </reg:dossier-event>
#                 </reg:events-data>
#             </reg:register-document>
#         </reg:register-documents>
#     </ops:register-search>
# </ops:world-patent-data>

# %% [markdown]
# ```<ep-patent-statuses>``` gives the current status - e.g. withdrawn or pending. For current actions we want to dobule check the case is still pending.
#
# Then we have a set of ```<events-data>``` tags in date order containing the activities.
#
# We can maybe ignore events with "PCT" (PCT events) and "RFE" (renewal fee events) in the event-code.
#
# Can we use a graph modelling library to draw a flow diagram?

# %%
soup3 = BeautifulSoup(response3.text, 'xml')
events = soup3.find_all("events-data")
print(events)
# Out:
# [<reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507527">
# <reg:event-date>
# <reg:date>20161007</reg:date>
# </reg:event-date>
# <reg:event-code>0009182</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Withdrawal of application</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2016/45</reg:gazette-num>
# <reg:date>20161109</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507528">
# <reg:event-date>
# <reg:date>20160826</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOSNEXR2</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">New entry: Despatch of examination report + time limit</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507529">
# <reg:event-date>
# <reg:date>20160819</reg:date>
# </reg:event-date>
# <reg:event-code>0009185</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">First examination report</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2016/38</reg:gazette-num>
# <reg:date>20160921</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507530">
# <reg:event-date>
# <reg:date>20151103</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOSNRFE2</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507531">
# <reg:event-date>
# <reg:date>20141030</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOSNRFE2</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507532">
# <reg:event-date>
# <reg:date>20131105</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOSNRFE2</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507533">
# <reg:event-date>
# <reg:date>20121030</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOSNRFE2</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507534">
# <reg:event-date>
# <reg:date>20120622</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOS ABEX</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Amendment by applicant</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507535">
# <reg:event-date>
# <reg:date>20111223</reg:date>
# </reg:event-date>
# <reg:event-code>0009199ENDS</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Change - date of supplementary search report</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2012/04</reg:gazette-num>
# <reg:date>20120125</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507536">
# <reg:event-date>
# <reg:date>20111028</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOSNRFE2</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507537">
# <reg:event-date>
# <reg:date>20110826</reg:date>
# </reg:event-date>
# <reg:event-code>0009016</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Supplementary search report</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2011/39</reg:gazette-num>
# <reg:date>20110928</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507538">
# <reg:event-date>
# <reg:date>20110826</reg:date>
# </reg:event-date>
# <reg:event-code>0008199IPCL</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Change - classification</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2011/39</reg:gazette-num>
# <reg:date>20110928</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507539">
# <reg:event-date>
# <reg:date>20110826</reg:date>
# </reg:event-date>
# <reg:event-code>0008199OBSC</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Change - classification</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2011/39</reg:gazette-num>
# <reg:date>20110928</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507540">
# <reg:event-date>
# <reg:date>20101029</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOSNRFE2</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507541">
# <reg:event-date>
# <reg:date>20100827</reg:date>
# </reg:event-date>
# <reg:event-code>0009199FREP</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Change - representative</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2010/39</reg:gazette-num>
# <reg:date>20100929</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507542">
# <reg:event-date>
# <reg:date>20091225</reg:date>
# </reg:event-date>
# <reg:event-code>0009199EXPT</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Change - extension states</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2010/04</reg:gazette-num>
# <reg:date>20100127</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507543">
# <reg:event-date>
# <reg:date>20091029</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOSNRFE2</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">New entry: Renewal fee paid</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507544">
# <reg:event-date>
# <reg:date>20090715</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOS ABEX</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Amendment by applicant</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507545">
# <reg:event-date>
# <reg:date>20090619</reg:date>
# </reg:event-date>
# <reg:event-code>0009012</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Publication in section I.1 EP Bulletin</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2009/30</reg:gazette-num>
# <reg:date>20090722</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507546">
# <reg:event-date>
# <reg:date>20090619</reg:date>
# </reg:event-date>
# <reg:event-code>0009171</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">Request for examination filed</reg:event-text>
# <reg:gazette-reference>
# <reg:gazette-num>2009/30</reg:gazette-num>
# <reg:date>20090722</reg:date>
# </reg:gazette-reference>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507547">
# <reg:event-date>
# <reg:date>20090529</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOS PCT</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507548">
# <reg:event-date>
# <reg:date>20090511</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOS PCT</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507549">
# <reg:event-date>
# <reg:date>20090428</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOS PCT</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507550">
# <reg:event-date>
# <reg:date>20090129</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOS PCT</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507551">
# <reg:event-date>
# <reg:date>20080516</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOS PCT</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507552">
# <reg:event-date>
# <reg:date>20080510</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOS PCT</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>, <reg:events-data>
# <reg:dossier-event event-type="new" id="EVT_275507553">
# <reg:event-date>
# <reg:date>20080104</reg:date>
# </reg:event-date>
# <reg:event-code>EPIDOS PCT</reg:event-code>
# <reg:event-text event-text-type="DESCRIPTION">PCT data prior to European publication</reg:event-text>
# </reg:dossier-event>
# </reg:events-data>]

# %%
events_dict = [
        {
            child.name: child.text
            for child in event.findChildren()
        }
    for event in soup3.find_all("events-data")
]

# %%
events_dict
# Out:
# [{'date': '20161109',
#   'dossier-event': '\n\n20161007\n\n0009182\nWithdrawal of application\n\n2016/45\n20161109\n\n',
#   'event-code': '0009182',
#   'event-date': '\n20161007\n',
#   'event-text': 'Withdrawal of application',
#   'gazette-num': '2016/45',
#   'gazette-reference': '\n2016/45\n20161109\n'},
#  {'date': '20160826',
#   'dossier-event': '\n\n20160826\n\nEPIDOSNEXR2\nNew entry: Despatch of examination report + time limit\n',
#   'event-code': 'EPIDOSNEXR2',
#   'event-date': '\n20160826\n',
#   'event-text': 'New entry: Despatch of examination report + time limit'},
#  {'date': '20160921',
#   'dossier-event': '\n\n20160819\n\n0009185\nFirst examination report\n\n2016/38\n20160921\n\n',
#   'event-code': '0009185',
#   'event-date': '\n20160819\n',
#   'event-text': 'First examination report',
#   'gazette-num': '2016/38',
#   'gazette-reference': '\n2016/38\n20160921\n'},
#  {'date': '20151103',
#   'dossier-event': '\n\n20151103\n\nEPIDOSNRFE2\nNew entry: Renewal fee paid\n',
#   'event-code': 'EPIDOSNRFE2',
#   'event-date': '\n20151103\n',
#   'event-text': 'New entry: Renewal fee paid'},
#  {'date': '20141030',
#   'dossier-event': '\n\n20141030\n\nEPIDOSNRFE2\nNew entry: Renewal fee paid\n',
#   'event-code': 'EPIDOSNRFE2',
#   'event-date': '\n20141030\n',
#   'event-text': 'New entry: Renewal fee paid'},
#  {'date': '20131105',
#   'dossier-event': '\n\n20131105\n\nEPIDOSNRFE2\nNew entry: Renewal fee paid\n',
#   'event-code': 'EPIDOSNRFE2',
#   'event-date': '\n20131105\n',
#   'event-text': 'New entry: Renewal fee paid'},
#  {'date': '20121030',
#   'dossier-event': '\n\n20121030\n\nEPIDOSNRFE2\nNew entry: Renewal fee paid\n',
#   'event-code': 'EPIDOSNRFE2',
#   'event-date': '\n20121030\n',
#   'event-text': 'New entry: Renewal fee paid'},
#  {'date': '20120622',
#   'dossier-event': '\n\n20120622\n\nEPIDOS ABEX\nAmendment by applicant\n',
#   'event-code': 'EPIDOS ABEX',
#   'event-date': '\n20120622\n',
#   'event-text': 'Amendment by applicant'},
#  {'date': '20120125',
#   'dossier-event': '\n\n20111223\n\n0009199ENDS\nChange - date of supplementary search report\n\n2012/04\n20120125\n\n',
#   'event-code': '0009199ENDS',
#   'event-date': '\n20111223\n',
#   'event-text': 'Change - date of supplementary search report',
#   'gazette-num': '2012/04',
#   'gazette-reference': '\n2012/04\n20120125\n'},
#  {'date': '20111028',
#   'dossier-event': '\n\n20111028\n\nEPIDOSNRFE2\nNew entry: Renewal fee paid\n',
#   'event-code': 'EPIDOSNRFE2',
#   'event-date': '\n20111028\n',
#   'event-text': 'New entry: Renewal fee paid'},
#  {'date': '20110928',
#   'dossier-event': '\n\n20110826\n\n0009016\nSupplementary search report\n\n2011/39\n20110928\n\n',
#   'event-code': '0009016',
#   'event-date': '\n20110826\n',
#   'event-text': 'Supplementary search report',
#   'gazette-num': '2011/39',
#   'gazette-reference': '\n2011/39\n20110928\n'},
#  {'date': '20110928',
#   'dossier-event': '\n\n20110826\n\n0008199IPCL\nChange - classification\n\n2011/39\n20110928\n\n',
#   'event-code': '0008199IPCL',
#   'event-date': '\n20110826\n',
#   'event-text': 'Change - classification',
#   'gazette-num': '2011/39',
#   'gazette-reference': '\n2011/39\n20110928\n'},
#  {'date': '20110928',
#   'dossier-event': '\n\n20110826\n\n0008199OBSC\nChange - classification\n\n2011/39\n20110928\n\n',
#   'event-code': '0008199OBSC',
#   'event-date': '\n20110826\n',
#   'event-text': 'Change - classification',
#   'gazette-num': '2011/39',
#   'gazette-reference': '\n2011/39\n20110928\n'},
#  {'date': '20101029',
#   'dossier-event': '\n\n20101029\n\nEPIDOSNRFE2\nNew entry: Renewal fee paid\n',
#   'event-code': 'EPIDOSNRFE2',
#   'event-date': '\n20101029\n',
#   'event-text': 'New entry: Renewal fee paid'},
#  {'date': '20100929',
#   'dossier-event': '\n\n20100827\n\n0009199FREP\nChange - representative\n\n2010/39\n20100929\n\n',
#   'event-code': '0009199FREP',
#   'event-date': '\n20100827\n',
#   'event-text': 'Change - representative',
#   'gazette-num': '2010/39',
#   'gazette-reference': '\n2010/39\n20100929\n'},
#  {'date': '20100127',
#   'dossier-event': '\n\n20091225\n\n0009199EXPT\nChange - extension states\n\n2010/04\n20100127\n\n',
#   'event-code': '0009199EXPT',
#   'event-date': '\n20091225\n',
#   'event-text': 'Change - extension states',
#   'gazette-num': '2010/04',
#   'gazette-reference': '\n2010/04\n20100127\n'},
#  {'date': '20091029',
#   'dossier-event': '\n\n20091029\n\nEPIDOSNRFE2\nNew entry: Renewal fee paid\n',
#   'event-code': 'EPIDOSNRFE2',
#   'event-date': '\n20091029\n',
#   'event-text': 'New entry: Renewal fee paid'},
#  {'date': '20090715',
#   'dossier-event': '\n\n20090715\n\nEPIDOS ABEX\nAmendment by applicant\n',
#   'event-code': 'EPIDOS ABEX',
#   'event-date': '\n20090715\n',
#   'event-text': 'Amendment by applicant'},
#  {'date': '20090722',
#   'dossier-event': '\n\n20090619\n\n0009012\nPublication in section I.1 EP Bulletin\n\n2009/30\n20090722\n\n',
#   'event-code': '0009012',
#   'event-date': '\n20090619\n',
#   'event-text': 'Publication in section I.1 EP Bulletin',
#   'gazette-num': '2009/30',
#   'gazette-reference': '\n2009/30\n20090722\n'},
#  {'date': '20090722',
#   'dossier-event': '\n\n20090619\n\n0009171\nRequest for examination filed\n\n2009/30\n20090722\n\n',
#   'event-code': '0009171',
#   'event-date': '\n20090619\n',
#   'event-text': 'Request for examination filed',
#   'gazette-num': '2009/30',
#   'gazette-reference': '\n2009/30\n20090722\n'},
#  {'date': '20090529',
#   'dossier-event': '\n\n20090529\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20090529\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20090511',
#   'dossier-event': '\n\n20090511\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20090511\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20090428',
#   'dossier-event': '\n\n20090428\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20090428\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20090129',
#   'dossier-event': '\n\n20090129\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20090129\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20080516',
#   'dossier-event': '\n\n20080516\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20080516\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20080510',
#   'dossier-event': '\n\n20080510\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20080510\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20080104',
#   'dossier-event': '\n\n20080104\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20080104\n',
#   'event-text': 'PCT data prior to European publication'}]

# %%
def get_events(client, number):
    """ Get prosecution events for an EP publication number."""
    response = client.register(reference_type='publication', input=epo_ops.models.Epodoc(number), constituents=['events'])
    soup = BeautifulSoup(response.text, 'xml')
    return [
        {
            child.name: child.text
            for child in event.findChildren()
        }
        for event in soup.find_all("events-data")
    ]

# %%
outstanding_pub = "EP3100185"
e = get_events(client, outstanding_pub)
e
# Out:
# [{'date': '20170719',
#   'dossier-event': '\n\n20170622\n\n0009016\nSupplementary search report\n\n2017/29\n20170719\n\n',
#   'event-code': '0009016',
#   'event-date': '\n20170622\n',
#   'event-text': 'Supplementary search report',
#   'gazette-num': '2017/29',
#   'gazette-reference': '\n2017/29\n20170719\n'},
#  {'date': '20170719',
#   'dossier-event': '\n\n20170616\n\n0008199IPCL\nChange - classification\n\n2017/29\n20170719\n\n',
#   'event-code': '0008199IPCL',
#   'event-date': '\n20170616\n',
#   'event-text': 'Change - classification',
#   'gazette-num': '2017/29',
#   'gazette-reference': '\n2017/29\n20170719\n'},
#  {'date': '20170719',
#   'dossier-event': '\n\n20170616\n\n0008199OBSC\nChange - classification\n\n2017/29\n20170719\n\n',
#   'event-code': '0008199OBSC',
#   'event-date': '\n20170616\n',
#   'event-text': 'Change - classification',
#   'gazette-num': '2017/29',
#   'gazette-reference': '\n2017/29\n20170719\n'},
#  {'date': '20170503',
#   'dossier-event': '\n\n20170331\n\n0009199EXPT\nChange - extension states\n\n2017/18\n20170503\n\n',
#   'event-code': '0009199EXPT',
#   'event-date': '\n20170331\n',
#   'event-text': 'Change - extension states',
#   'gazette-num': '2017/18',
#   'gazette-reference': '\n2017/18\n20170503\n'},
#  {'date': '20170201',
#   'dossier-event': '\n\n20170201\n\nEPIDOSNRFE2\nNew entry: Renewal fee paid\n',
#   'event-code': 'EPIDOSNRFE2',
#   'event-date': '\n20170201\n',
#   'event-text': 'New entry: Renewal fee paid'},
#  {'date': '20161207',
#   'dossier-event': '\n\n20161104\n\n0009012\nPublication in section I.1 EP Bulletin\n\n2016/49\n20161207\n\n',
#   'event-code': '0009012',
#   'event-date': '\n20161104\n',
#   'event-text': 'Publication in section I.1 EP Bulletin',
#   'gazette-num': '2016/49',
#   'gazette-reference': '\n2016/49\n20161207\n'},
#  {'date': '20161104',
#   'dossier-event': '\n\n20161104\n\nEPIDOSNEXAM52\nThe date on which the examining division becomes responsible has been established\n',
#   'event-code': 'EPIDOSNEXAM52',
#   'event-date': '\n20161104\n',
#   'event-text': 'The date on which the examining division becomes responsible has been established'},
#  {'date': '20161207',
#   'dossier-event': '\n\n20161104\n\n0009171\nRequest for examination filed\n\n2016/49\n20161207\n\n',
#   'event-code': '0009171',
#   'event-date': '\n20161104\n',
#   'event-text': 'Request for examination filed',
#   'gazette-num': '2016/49',
#   'gazette-reference': '\n2016/49\n20161207\n'},
#  {'date': '20160720',
#   'dossier-event': '\n\n20160720\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20160720\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20160702',
#   'dossier-event': '\n\n20160702\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20160702\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20160702',
#   'dossier-event': '\n\n20160702\n\nEPIDOSNRFE2\nNew entry: Renewal fee paid\n',
#   'event-code': 'EPIDOSNRFE2',
#   'event-date': '\n20160702\n',
#   'event-text': 'New entry: Renewal fee paid'},
#  {'date': '20160627',
#   'dossier-event': '\n\n20160627\n\nEPIDOS FREP\nChange - representative\n',
#   'event-code': 'EPIDOS FREP',
#   'event-date': '\n20160627\n',
#   'event-text': 'Change - representative'},
#  {'date': '20160627',
#   'dossier-event': '\n\n20160627\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20160627\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20150812',
#   'dossier-event': '\n\n20150812\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20150812\n',
#   'event-text': 'PCT data prior to European publication'},
#  {'date': '20150807',
#   'dossier-event': '\n\n20150807\n\nEPIDOS PCT\nPCT data prior to European publication\n',
#   'event-code': 'EPIDOS PCT',
#   'event-date': '\n20150807\n',
#   'event-text': 'PCT data prior to European publication'}]

# %% [markdown]
# Observations - this does not feature the R.70(2) communication.
#
# We also have an RSS feed of the application documents with the URL: ```https://register.epo.org/rssDocuments?application=EP14880554&proc=EP-PCT&lng=en```
#
# Also we have the link to the ZIP archive - https://register.epo.org/download?number=EP14880554&output=zip .
#
# Number in both cases is the application number minus the check digit - 14880554.2.

# %% [markdown]
# ## Downloading Prosecution History File
#
# The events data above is useful but for prosecution we are more interested in the "documents" section of the Register.
#
# The RSS feed contains links to each document - but we would need to activate the "Load All Pages" JS link.
#
# Or we could download the ZIP file.

# %%
import requests

url = "https://register.epo.org/download?number=EP14880554&output=zip"

response = requests.get(url)

with open('EP14880554.zip', 'wb') as f:
    f.write(response.content)

# %%
# Build Function
def get_prosecution(application_number):
    """ Download and save EP prosecution history for given application_number."""
    
    # Strip checkdigit
    if "." in application_number:
        application_number = application_number.split(".")[0]
       
    url = "https://register.epo.org/download?number=EP{0}&output=zip".format(application_number)

    response = requests.get(url)

    with open('EP{0}.zip'.format(application_number), 'wb') as f:
        f.write(response.content)
    print("Prosecution saved")

# %%
application_number = "14802601.6"
get_prosecution(application_number)
# Out:
# Prosecution saved

# %%
application_number = "14762986.9"
get_prosecution(application_number)
# Out:
# Prosecution saved

# %%
application_number = "07799914.2"
get_prosecution(application_number)
# Out:
# Prosecution saved

# %% [markdown]
# Need to search from bottom (i.e. newest) for first filename match according to legal basis.
#
# Extract date from filename.
#
# Can also locate office action for OCR!
#
# Filename mappings:
# * R161 - 14802601-2017-06-07-1226AA-Communication concerning correction of deficiencies in written opinion_amendment of application_payment of claims fee.pdf
# * R70(2) EPC - 14880554-2017-07-07-1224-Invitation to declare maintenance of the application and to correct deficiencies in the Written Opinion_amend application.pdf
# * A94(3) EPC - 14762986-2017-08-24-2001-Communication from the Examining Division.pdf
# * Oral Proc - 07799914-2017-05-08-2008-1-Summons to attend oral proceedings.pdf
#
# Ah can just use code mappings - after the date.
#
# We can use regex to parse the filenames and extract the components (looks for x in filename won't work as 2008 is likely in filenames dated in 2008). See https://regex101.com/r/A4uQ8N/1

# %%
import zipfile

filename = "EP14762986_2A943.zip"
with zipfile.ZipFile(filename, 'r') as myzip:
    files = myzip.namelist()
print(files)
# Out:
# ['14762986-2014-09-18-A1PAMPHLET-International publication of the A1 Pamphlet.pdf', '14762986-2014-09-18-ISR-Copy of the international search report.pdf', '14762986-2014-10-08-PRIODOC-X-Priority document (electronically transmitted).pdf', '14762986-2015-07-22-1201-1-Information on entry into European phase.pdf', '14762986-2015-08-20-1200P-Request for entry into the European phase.pdf', '14762986-2015-08-20-RECEIPT-OLF-(Electronic) Receipt.pdf', '14762986-2015-10-01-IPRP-Copy of the international preliminary report on patentability.pdf', '14762986-2015-10-21-1226CC-Communication regarding possible amendment of the application_payment of claims fee.pdf', '14762986-2015-10-19-1204-Communication to designated inventor.pdf', '14762986-2015-12-03-1038-Letter accompanying subsequently filed items.pdf', '14762986-2015-12-03-ABEX-Amendments received before examination.pdf', '14762986-2015-12-03-CLMSABEX-Amended claims filed after receipt of (European) search report.pdf', '14762986-2015-12-03-CLMS-HWA-Amended claims with annotations.pdf', '14762986-2015-12-03-RECEIPT-OLF-(Electronic) Receipt.pdf', '14762986-2015-12-23-1219-Notification on forthcoming publication of bibliographic data.pdf', '14762986-2016-10-03-SRCH-START-Search started.pdf', '14762986-2016-10-14-1507-Communication regarding the transmission of the European search report.pdf', '14762986-2016-10-14-1703-European search opinion.pdf', '14762986-2016-10-14-1503SS-Supplementary European search report.pdf', '14762986-2016-10-14-SRCHSTRAEP-Information on Search Strategy.pdf', '14762986-2016-11-02-1224-Invitation to declare maintenance of the application and to correct deficiencies in the Written Opinion_amend application.pdf', '14762986-2017-04-18-1038-Letter accompanying subsequently filed items.pdf', '14762986-2017-04-18-ABEX-Amendments received before examination.pdf', '14762986-2017-04-18-CLMSABEX-Amended claims filed after receipt of (European) search report.pdf', '14762986-2017-04-18-CLMS-HWA-Amended claims with annotations.pdf', '14762986-2017-04-18-DESCABEX-Amended description filed after receipt of (European) search report.pdf', '14762986-2017-04-18-DESC-HWA-Amended description with annotations.pdf', '14762986-2017-04-18-RECEIPT-OLF-(Electronic) Receipt.pdf', '14762986-2017-05-11-2913-Invitation to file a copy of search results(priority).pdf', '14762986-2017-06-09-1038-Letter accompanying subsequently filed items.pdf', '14762986-2017-06-09-PRSR-REPLY-Reply to invitation to file a copy of priority search results.pdf', '14762986-2017-06-09-PRSR-Priority search results.pdf', '14762986-2017-06-09-PRSR-Priority search results-2.pdf', '14762986-2017-06-09-RECEIPT-OLF-(Electronic) Receipt.pdf', '14762986-2017-08-24-2001-Communication from the Examining Division.pdf', '14762986-2017-08-24-2906-Annex to the communication.pdf', 'toc.xml']

# %%
import re
from datetime import datetime

test_str = files[0]
regex = r"(?P<app_no>\d{8})-(?P<date>\d{4}-\d{2}-\d{2})-(?P<number>[A-Z\-\d]+)-(?P<name>.+)\.pdf"

match = re.match(regex, test_str)
parsed_file = {
    'filename': test_str,
    'date': datetime.strptime(match.group(2), "%Y-%m-%d"),
    'code': match.group(3),
    'title': match.group(4)
}

print(parsed_file)
# Out:
# {'date': datetime.datetime(2014, 9, 18, 0, 0), 'code': 'A1PAMPHLET', 'filename': '14762986-2014-09-18-A1PAMPHLET-International publication of the A1 Pamphlet.pdf', 'title': 'International publication of the A1 Pamphlet'}

# %%
# Bring it together in a parsing function

def parse_filename(filename):
    """ Extract data from EPO Document Filename."""
    regex = r"(?P<app_no>\d{8})-(?P<date>\d{4}-\d{2}-\d{2})-(?P<number>[A-Z\-\d]+)-(?P<name>.+)\.pdf"
    match = re.match(regex, filename)
    if match:
        return {
            'filename': filename,
            'date': datetime.strptime(match.group(2), "%Y-%m-%d"),
            'code': match.group(3),
            'title': match.group(4)
        }
    else:
        return {'filename': filename}

# %%
mapping_dict = {
    '1226AA':'Communication pursuant to Rules 161(1) and 162 EPC',
    '1224':'Communication pursuant to Rules 70(2) and 70a(2) EPC',
    '2001':'Communication pursuant to Article 94(3) EPC',
    '2008':'Summons to attend Oral Proceedings pursuant to Rule 115(1) EPC'
}

for file in reversed(files):
    # print(file)
    parsed_data = parse_filename(file)
    # print(parsed_data)
    if parsed_data.get('code') in mapping_dict.keys():
        print(file)
        break
# Out:
# 14762986-2017-08-24-2001-Communication from the Examining Division.pdf

# %%
'2008' in mapping_dict.keys()
# Out:
# True

# %%
parsed_data
# Out:
# {'code': '2001',
#  'date': datetime.datetime(2017, 8, 24, 0, 0),
#  'filename': '14762986-2017-08-24-2001-Communication from the Examining Division.pdf',
#  'title': 'Communication from the Examining Division'}

# %%
letter_text = """
    The Applicant writes in response to the {communication} dated {date}.
"""
